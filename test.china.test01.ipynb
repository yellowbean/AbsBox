                    ['2032-12-31', 21899636.08, 3538573.26, 102853.4],
                    ['2033-01-31', 18703444.14, 3196191.94, 88536.12],
                    ['2033-02-28', 15892118.78, 2811325.36, 75650.63],
                    ['2033-03-31', 13509553.6, 2382565.18, 64300.2],
                    ['2033-04-30', 11384912.8, 2124640.8, 54784.46],
                    ['2033-05-31', 9403957.62, 1980955.17, 46294.48],
                    ['2033-06-30', 7538965.43, 1864992.2, 38269.44],
                    ['2033-07-31', 5816455.23, 1722510.2, 30742.34],
                    ['2033-08-31', 4286565.52, 1529889.71, 23775.46],
                    ['2033-09-30', 2933688.04, 1352877.49, 17541.67],
                    ['2033-10-31', 1714872.18, 1218815.86, 12031.45],
                    ['2033-11-30', 775403.48, 939468.7, 7039.81],
                    ['2033-12-31', 167806.84, 607596.64, 3233.51],
                    ['2034-01-31', 138400.48, 29406.36, 676.5],
                    ['2034-02-28', 118719.4, 19681.08, 560.62],
                    ['2034-03-31', 98985.22, 19734.18, 480.45],
                    ['2034-04-30', 83595.18, 15390.04, 400.06],
                    ['2034-05-31', 68169.56, 15425.63, 337.41],
                    ['2034-06-30', 52708.19, 15461.37, 274.6],
                    ['2034-07-31', 40775.42, 11932.77, 211.64],
                    ['2034-08-31', 28821.89, 11953.53, 163.82],
                    ['2034-09-30', 16847.5, 11974.38, 115.9],
                    ['2034-10-31', 4852.19, 11995.32, 67.9],
                    ['2034-11-30', 0.0, 4852.19, 29.74]]
        }
        ,(("本金分账户",{"余额":0})
        ,("储备账户",{"余额":0})
        ,("收入分账户",{"余额":0})
        ,("信托税收",{"余额":0}))
        ,(("A1",{"当前余额":mil(4000)
                                ,"当前利率":0.0373
                                ,"初始余额":mil(4000)
                                ,"初始利率":0.0373
                                ,"起息日":"2018-09-27"
                                ,"利率":{"浮动":[0.0373,"LPR5Y",-0.0006,["每年",3,1]]}
                                ,"债券类型":{"过手摊还":None}
                                ,"到期日":"2020-04-26"
                                })
        ,("A2",{"当前余额":mil(5000)
                                ,"当前利率":0.045
                                ,"初始余额":mil(5000)
                                ,"初始利率":0.045
                                ,"起息日":"2018-09-27"
                                ,"利率":{"浮动":[0.045,"LPR5Y",0.003,["每年",3,1]]}
                                ,"债券类型":{"过手摊还":None}
                                ,"到期日":"2024-05-26"
                                })
        ,("次级",{"当前余额":mil(1316.3855593)
                                ,"当前利率":0.00
                                ,"初始余额":mil(1316.3855593)
                                ,"初始利率":0.00
                                ,"起息日":"2018-09-27"
                                ,"利率":{"固定":0.0}
                                ,"债券类型":{"过手摊还":None}
                                ,"到期日":"2034-12-26"
                                }))
        ,(("增值税",{"类型":{"差额费用":[("*"
                                    ,("资产池累计",None,"利息"),0.0326)
                                    ,("费用支付总额",None,"增值税")]}})
        ,("服务商费用",{"类型":{"年化费率":[("资产池余额",),0.0055]}}))
        ,{"未违约":[
            ["payFee","收入分账户",["增值税"],{"support":["account","本金分账户",["AccountDraw", "PDLedger"]]}] # 1
            ,["计提支付费用","收入分账户",["服务商费用"],{"limit":{"余额百分比":0.5}
                                                ,"support":["account","本金分账户",["AccountDraw", "PDLedger"]]}] # 5
            ,["计提支付利息","收入分账户",["A1","A2"],{"support":["account","本金分账户",["AccountDraw", "PDLedger"]]}] # 6 
            ,["支付费用","收入分账户",["服务商费用"],{"support":["account","本金分账户",["AccountDraw", "PDLedger"]]}] # 7
            # 8,9
            ,['IfElse', ["status", "Accelerated"]
                  , [["账户转移","收入分账户","本金分账户"]]
                  , [["账户转移",'收入分账户','本金分账户',{"冲销":"PDLedger"}]]
                  ]
            ,["账户转移","收入分账户","本金分账户"] # 11
            # 本金账
            ,['IfElse', ["status", "Accelerated"]
                  , [["payPrin","本金分账户",["A1","A2"]]]
                  , [["payPrinBySeq","本金分账户",["A1","A2"]]]
                  ]            
            ,["支付本金","本金分账户",["次级"]]
            ,["支付收益","本金分账户","次级"]
            ],
        "Defaulted":[
            ["账户转移","收入分账户","本金分账户"]
            ,["calcAndPayFee","本金分账户",["增值税","服务商费用"]]
            ,["计提支付利息","本金分账户",["A1","A2"]]
            ,["payPrin","本金分账户",["A1","A2"]]

        ],
        "回款后":[["计提费用","增值税"]
                ,["簿记",
                    ["PDL",("资产池累计违约余额",),[("PDLedger",("债券余额",))]]]
          ],
        "cleanUp":[
            ["账户转移","收入分账户","本金分账户"]
            ,["calcAndPayFee","本金分账户",["增值税","服务商费用"]]
            ,["计提支付利息","本金分账户",["A1","A2"]]
            ,["payPrin","本金分账户",["A1","A2"]]     
            ,["支付本金","本金分账户",["次级"]]
            ,["支付收益","本金分账户","次级"]                   
        ]
        }
        ,(["利息回款","收入分账户"]
        ,["本金回款","本金分账户"]
        ,["早偿回款","本金分账户"]
        ,["回收回款","本金分账户"])
        ,None
        ,None
        ,None
        ,None
        ,("设计","摊销")
        ,None
        ,{"PDLedger":{"余额":0,"记录":None}}
    )

# %%
NONGYING1805.资产池
# Out:
# {'发行': {'资产池规模': 10316385600.0},
#  '归集表': [['2018-04-30', 10221948743.36, 94436815.94, 41416103.01],
#   ['2018-05-31', 10127246985.32, 94701758.05, 41035474.29],
#   ['2018-06-30', 10032279199.21, 94967786.1, 40653759.61],
#   ['2018-07-31', 9937058578.98, 95220620.24, 40270954.52],
#   ['2018-08-31', 9841585416.38, 95473162.6, 39887116.69],
#   ['2018-09-30', 9745853025.61, 95732390.76, 39502248.34],
#   ['2018-10-31', 9649862321.27, 95990704.34, 39116320.93],
#   ['2018-11-30', 9553622025.55, 96240295.73, 38729337.71],
#   ['2018-12-31', 9457136207.49, 96485818.06, 38341337.45],
#   ['2019-01-31', 9360443565.61, 96692641.88, 37952338.22],
#   ['2019-02-28', 9263543047.17, 96900518.44, 37562509.66],
#   ['2019-03-31', 9166450610.05, 97092437.12, 37171846.37],
#   ['2019-04-30', 9069188730.56, 97261879.49, 36780419.56],
#   ['2019-05-31', 8971695626.72, 97493103.84, 36388344.43],
#   ['2019-06-30', 8874018793.31, 97676833.41, 35995319.12],
# ...

# %%
{"归集日":["2023-05-31","2023-06-30"],"兑付日":["2023-06-26","2023-07-26"]
 ,"法定到期日":"2060-12-01","收款频率":"月末","付款频率":["每月",26]}
# Out:
# {'归集日': ['2023-05-31', '2023-06-30'],
#  '兑付日': ['2023-06-26', '2023-07-26'],
#  '法定到期日': '2060-12-01',
#  '收款频率': '月末',
#  '付款频率': ['每月', 26]}

# %%
r = localAPI.runDates("2021-06-01",["每月",26],"2022-01-01")

# %%
from lenses import lens

# %%
["A","B","C","D","E"] & lens.Each().set_many([1,2,3,4,4])
# Out:
# [1, 2, 3, 4, 4]

# %%
from absbox import API,EnginePath

localAPI = API("http://localhost:8081",check=False)
#localAPI = API("https://spv.run/api/dev",check=False)

r = localAPI.run(NONGYING1805
                 ,runAssump=[("interest"
                               ,("LPR5Y",0.04)
                               ,("SOFR3M",[["2021-01-01",0.025]
                                           ,["2022-08-01",0.029]]))]
                 ,read=True)
# Out:
# Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.26.4, server:0.28.5
# Warning Message from server:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       3 localAPI = API("http://localhost:8081",check=False)
#       4 #localAPI = API("https://spv.run/api/dev",check=False)
# ----> 6 r = localAPI.run(NONGYING1805
#       7                  ,runAssump=[("interest"
#       8                                ,("LPR5Y",0.04)
#       9                                ,("SOFR3M",[["2021-01-01",0.025]
#      10                                            ,["2022-08-01",0.029]]))]
#      11                  ,read=True)
#
# File ~/Projects/PyABS/absbox/client.py:353, in API.run(self, deal, poolAssump, runAssump, read, showWarning, debug)
#     350     console.print("Warning Message from server:\n"+"\n".join(list(rawWarnMsg)))
# ...

# %%
r['pool']['flow']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 r['pool']['flow']
#
# NameError: name 'r' is not defined

# %%
r['accounts']['收入分账户'].loc['2018-11-26']
# Out:
#                       余额           变动额  \
# 日期
# 2018-11-26  2.726926e+08 -9.189352e+06
# 2018-11-26  2.701939e+08 -2.498704e+06
# 2018-11-26  2.086816e+08 -6.151233e+07
# 2018-11-26  2.061829e+08 -2.498704e+06
# 2018-11-26  2.061829e+08  0.000000e+00
# 2018-11-26  0.000000e+00 -2.061829e+08
#
#                                                          备注
# 日期
# 2018-11-26                                  <SeqPayFee:增值税>
# 2018-11-26                                <SeqPayFee:服务商费用>
# 2018-11-26                                    <PayInt:A1A2>
# 2018-11-26                                <SeqPayFee:服务商费用>
# 2018-11-26  <TransferBy:收入分账户,本金分账户,ClearLedger "PDLedger">
# 2018-11-26                           <Transfer:收入分账户,本金分账户>

# %%
r['ledgers']['PDLedger']
# Out:
#             余额  变动额                     备注
# 日期
# 2018-09-27   0    0   <TxnDirection:Debit>
# 2018-09-30   0    0   <TxnDirection:Debit>
# 2018-10-31   0    0   <TxnDirection:Debit>
# 2018-11-26   0    0   <TxnDirection:Debit>
# 2018-11-26   0    0   <TxnDirection:Debit>
# ...         ..  ...                    ...
# 2034-12-26   0    0   <TxnDirection:Debit>
# 2034-12-26   0    0   <TxnDirection:Debit>
# 2034-12-26   0    0   <TxnDirection:Debit>
# 2034-12-26   0    0   <TxnDirection:Debit>
# 2034-12-26   0    0  <TxnDirection:Credit>
#
# [1166 rows x 3 columns]

# %%
from absbox import readBondsCf

# %%
r['fees']
# Out:
# {'增值税':             余额          支付  剩余支付
#  日期
#  2018-11-26   0  9189352.46     0
#  2018-12-26   0  1262576.41     0
#  2019-01-26   0  1249927.60     0
#  2019-02-26   0  1237246.22     0
#  2019-03-26   0  1224537.82     0
#  ...         ..         ...   ...
#  2034-09-26   0        5.34     0
#  2034-10-26   0        3.78     0
#  2034-11-26   0        2.22     0
#  2034-12-26   0        0.97     0
#  2034-12-31   0        0.00     0
#
#  [195 rows x 3 columns],
#  '服务商费用':              余额          支付  剩余支付
#  日期
#  2018-11-26  0.0  4997408.49     0
#  2018-12-26  0.0   581635.53     0
#  2019-01-26  0.0   719793.44     0
#  2019-02-26  0.0   712523.96     0
#  2019-03-26  0.0   282095.55     0
#  ...         ...         ...   ...
#  2034-09-26  0.0        3.07     0
#  2034-10-26  0.0        1.73     0
#  2034-11-26  0.0        1.26     0
#  2034-12-26  0.0        0.29     0
#  2034-12-31  0.0        0.00     0
#
#  [195 rows x 3 columns]}

# %%
r['bonds']['A1']
# Out:
#                  balance     interest     principal    rate          cash  \
# date
# 2018-11-26  3.129793e+09  24526027.39  8.702074e+08  0.0373  8.947334e+08
# 2018-12-26  3.025046e+09   9595172.31  1.047463e+08  0.0373  1.143415e+08
# 2019-01-26  2.921242e+09   9583180.91  1.038048e+08  0.0373  1.133879e+08
# 2019-02-26  2.817267e+09   9254333.09  1.039750e+08  0.0373  1.132294e+08
# 2019-03-26  2.709459e+09   8515091.52  1.078071e+08  0.0394  1.163222e+08
# 2019-04-26  2.604781e+09   9066667.69  1.046786e+08  0.0394  1.137453e+08
# 2019-05-26  2.498873e+09   8435207.85  1.059081e+08  0.0394  1.143433e+08
# 2019-06-26  2.393825e+09   8361981.13  1.050480e+08  0.0394  1.134100e+08
# 2019-07-26  2.287560e+09   7752056.99  1.062643e+08  0.0394  1.140163e+08
# 2019-08-26  2.182256e+09   7654866.60  1.053049e+08  0.0394  1.129598e+08
# 2019-09-26  2.076811e+09   7302484.68  1.054446e+08  0.0394  1.127471e+08
# 2019-10-26  1.970135e+09   6725453.40  1.066758e+08  0.0394  1.134012e+08
# ...

# %%
readBondsCf(r['bonds'])
# Out:
# Bond                  A1                                                 \
# Field            balance     interest     principal  rate          cash
# date
# 2018-11-26  3.132426e+09  19726027.39  8.675737e+08  0.03  8.872997e+08
# 2018-12-26  3.021944e+09   7723790.85  1.104819e+08  0.03  1.182057e+08
# 2019-01-26  2.912733e+09   7699748.61  1.092116e+08  0.03  1.169114e+08
# 2019-02-26  2.803373e+09   7421483.42  1.093600e+08  0.03  1.167815e+08
# 2019-03-26  2.705439e+09  10752662.45  9.793343e+07  0.05  1.086861e+08
# ...                  ...          ...           ...   ...           ...
# 2034-08-26           NaN          NaN           NaN   NaN           NaN
# 2034-09-26           NaN          NaN           NaN   NaN           NaN
# 2034-10-26           NaN          NaN           NaN   NaN           NaN
# 2034-11-26           NaN          NaN           NaN   NaN           NaN
# 2034-12-26           NaN          NaN           NaN   NaN           NaN
#
# ...
