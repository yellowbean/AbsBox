# %%
from absbox import API,Generic

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
test01 = Generic(
    "TEST01"
    ,{"cutoff":"2021-03-01","closing":"2021-03-01","firstPay":"2021-04-20"
     ,"payFreq":["DayOfMonth",20],"poolFreq":"MonthEnd","stated":"2030-01-01"}
    ,{'assets':[
        ["Loan"
          ,{"originBalance": 1200
            ,"originRate": ["fix",0.045]
            ,"originTerm": 12
            ,"freq": "Monthly"
            ,"type": "i_p"
            ,"originDate": "2021-03-01"}
          ,{"currentBalance": 1200
            ,"currentRate": 0.06
            ,"remainTerm": 12
            ,"status": "Current"}]
               ]
                }
    ,(("acc01",{"balance":0}),)
    ,(("A1",{"balance":1000
             ,"rate":0.07
             ,"originBalance":1000
             ,"originRate":0.07
             ,"startDate":"2020-01-03"
             ,"rateType":{"Fixed":0.08}
             ,"bondType":{"Sequential":None}})
      ,)
    ,tuple()
    ,{"amortizing":[]}
    ,[["CollectedInterest","acc01"]
      ,["CollectedPrincipal","acc01"]
      ,["CollectedPrepayment","acc01"]
      ,["CollectedRecoveries","acc01"]]
    ,None
    ,None
    ,None
    ,None
    ,("PreClosing","Amortizing")
    )

# %%
#localAPI = API("https://absbox.org/api/dev", check=False)
localAPI = API("http://localhost:8081", check=False)

r = localAPI.run(test01
               ,poolAssump = ("Pool",("Loan",None,None,None,None)
                                       ,None
                                       ,None)
               ,runAssump = None
               ,read=True)
# Out:
# Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.26.4, server:0.26.5
# Warning Message from server:
# Bond A1 is not paid off
# Account acc01 has cash to be distributed

# %%
r['pool']['flow']
# Out:
#             Balance  Principal  Interest  Prepayment  Default  Recovery  Loss  \
# Date
# 2021-03-01     1200          0      0.00           0        0         0     0
# 2021-03-31     1200          0      0.00           0        0         0     0
# 2021-04-30     1200          0      6.11           0        0         0     0
# 2021-05-31     1200          0      5.91           0        0         0     0
# 2021-06-30     1200          0      6.11           0        0         0     0
# 2021-07-31     1200          0      5.91           0        0         0     0
# 2021-08-31     1200          0      6.11           0        0         0     0
# 2021-09-30     1200          0      6.11           0        0         0     0
# 2021-10-31     1200          0      5.91           0        0         0     0
# 2021-11-30     1200          0      6.11           0        0         0     0
# 2021-12-31     1200          0      5.91           0        0         0     0
# ...

# %%
test02 = Generic(
    "TEST01"
    ,{"cutoff":"2021-03-01","closing":"2021-03-01","firstPay":"2021-04-20"
     ,"payFreq":["DayOfMonth",20],"poolFreq":"MonthEnd","stated":"2030-01-01"}
    ,{'assets':[
        ["Loan"
          ,{"originBalance": 1200
            ,"originRate": ["fix",0.045]
            ,"originTerm": 12
            ,"freq": "Monthly"
            ,"type": "i_p"
            ,"originDate": "2021-03-01"}
          ,{"currentBalance": 1200
            ,"currentRate": 0.06
            ,"remainTerm": 12
            ,"status": "Current"}]
               ]
                }
    ,(("acc01",{"balance":0}),)
    ,(("A1",{"balance":1000
             ,"rate":0.07
             ,"originBalance":1000
             ,"originRate":0.07
             ,"startDate":"2020-01-03"
             ,"rateType":{"Fixed":0.08}
             ,"bondType":{"Sequential":None}})
      ,)
    ,tuple()
    ,{"amortizing":[
        ["<=","20220601"]
    ]}
    ,[["CollectedInterest","acc01"]
      ,["CollectedPrincipal","acc01"]
      ,["CollectedPrepayment","acc01"]
      ,["CollectedRecoveries","acc01"]]
    ,None
    ,None
    ,None
    ,None
    ,("PreClosing","Amortizing")
    )
