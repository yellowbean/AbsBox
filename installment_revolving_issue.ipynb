# %%
from absbox import API, mkDeal,EnginePath
import pandas as pd 
localAPI = API(EnginePath.LOCAL, lang="english",check=False)



name = "Name"
dates = {
           "cutoff":"2024-09-30","closing":"2024-09-30","firstPay":"2024-10-31",
            "stated": "2027-06-12",
            "poolFreq": "MonthEnd",
            "payFreq": "MonthEnd",
        }

installment_assets = [['Installment', {'originBalance': 314136.13, 'feeRate': ['fix', 0.021666666666666667], 'originTerm': 5, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-09-16'}, {'currentBalance': 314136.13, 'remainTerm': 4, 'status': 'current'}], 
                      ['Installment', {'originBalance': 63762.0, 'feeRate': ['fix', 0.020833333333333332], 'originTerm': 6, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-09-18'}, {'currentBalance': 63762.0, 'remainTerm': 6, 'status': 'current'}], 
                      ['Installment', {'originBalance': 85470.0, 'feeRate': ['fix', 0.0225], 'originTerm': 7, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-04-26'}, {'currentBalance': 14274.67, 'remainTerm': 1, 'status': 'current'}], 
                      ['Installment', {'originBalance': 500000.0, 'feeRate': ['fix', 0.019166666666666665], 'originTerm': 9, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-05-03'}, {'currentBalance': 250416.51, 'remainTerm': 4, 'status': 'current'}], 
                      ['Installment', {'originBalance': 65000.0, 'feeRate': ['fix', 0.015833333333333335], 'originTerm': 1, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-09-30'}, {'currentBalance': 6540.67, 'remainTerm': 1, 'status': 'current'}], 
                      ['Installment', {'originBalance': 108992.0, 'feeRate': ['fix', 0.020833333333333332], 'originTerm': 10, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-02-15'}, {'currentBalance': 24291.09, 'remainTerm': 2, 'status': 'current'}], 
                      ['Installment', {'originBalance': 154000.0, 'feeRate': ['fix', 0.0225], 'originTerm': 10, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-02-20'}, {'currentBalance': 34322.04, 'remainTerm': 2, 'status': 'current'}], 
                      ['Installment', {'originBalance': 350000.0, 'feeRate': ['fix', 0.020833333333333332], 'originTerm': 8, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-04-25'}, {'currentBalance': 100208.31, 'remainTerm': 2, 'status': 'current'}], 
                      ['Installment', {'originBalance': 80000.0, 'feeRate': ['fix', 0.021666666666666667], 'originTerm': 8, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-04-15'}, {'currentBalance': 40766.45, 'remainTerm': 2, 'status': 'current'}], 
                      ['Installment', {'originBalance': 500000.0, 'feeRate': ['fix', 0.021666666666666667], 'originTerm': 9, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-03-19'}, {'currentBalance': 125312.57, 'remainTerm': 2, 'status': 'current'}]]

mortage_assets = [['Mortgage', {'originBalance': 200000.0, 'originRate': ['fix', 0.0], 'originTerm': 12, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2023-02-04'}, {'currentBalance': 127435.62, 'currentRate': 0.0, 'remainTerm': 1, 'status': 'Current'}], ['Mortgage', {'originBalance': 150000.0, 'originRate': ['fix', 0.0], 'originTerm': 12, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-04-01'}, {'currentBalance': 57797.85, 'currentRate': 0.0, 'remainTerm': 7, 'status': 'Current'}], ['Mortgage', {'originBalance': 75000.0, 'originRate': ['fix', 0.0], 'originTerm': 12, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2023-01-31'}, {'currentBalance': 28805.04, 'currentRate': 0.0, 'remainTerm': 1, 'status': 'Current'}], ['Mortgage', {'originBalance': 6000.0, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-11'}, {'currentBalance': 6000.0, 'currentRate': 0.21, 'remainTerm': 2, 'status': 'Current'}], ['Mortgage', {'originBalance': 6000.0, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-11'}, {'currentBalance': 6000.0, 'currentRate': 0.21, 'remainTerm': 2, 'status': 'Current'}], ['Mortgage', {'originBalance': 1099.32, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-07-31'}, {'currentBalance': 1099.32, 'currentRate': 0.21, 'remainTerm': 1, 'status': 'Current'}], ['Mortgage', {'originBalance': 1161.0, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-07-16'}, {'currentBalance': 1161.0, 'currentRate': 0.21, 'remainTerm': 1, 'status': 'Current'}], ['Mortgage', {'originBalance': 6333.0, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-18'}, {'currentBalance': 6333.0, 'currentRate': 0.21, 'remainTerm': 3, 'status': 'Current'}], ['Mortgage', {'originBalance': 4748.55, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-16'}, {'currentBalance': 4748.55, 'currentRate': 0.21, 'remainTerm': 3, 'status': 'Current'}], ['Mortgage', {'originBalance': 19215.92, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-19'}, {'currentBalance': 19215.92, 'currentRate': 0.21, 'remainTerm': 3, 'status': 'Current'}]]

j = {"pool_Installment": {'assets':installment_assets},"pool_Mortgage": {'assets':mortage_assets}}

accounts = {
            "collections_interest_installment": {"balance": 0},
            "collections_interest_mortgage": {"balance": 0},
            "collections_principal_installment": {"balance": 0},
            "collections_principal_mortgage": {"balance": 1_023_809.96},
            "collections_account_installment":{"balance":1_023_809.96},
            "collections_account_mortgage":{"balance":0},
            "revolBuyAcc_installment": {"balance": 0},
            "revolBuyAcc_mortgage":{"balance": 0},
        }
     

bonds_1 = {
    "A": {"A1": {
        "balance":  13_019_000.00,
        "rate": 0.1023,
        "originBalance": 50_000_000,
        "originRate": 0.1023,
        "startDate": "2024-06-12",
        "rateType":  {
            "floater": [0.03588, "EURIBOR1M", 0.085, "MonthEnd"],
            "dayCount": "DC_ACT_360",
        },
        "maturityDate": "2027-06-12",
        "bondType": {"Sequential": None},
    },},
    "B": {"B1": {
        "balance":   487_899.20,
        "rate": 0.175,
        "originBalance": 2_777_778.00,
        "originRate": 0.175,
        "startDate": "2024-06-12",
        "maturityDate": "2027-06-12",
        "rateType": {"Fixed": 0.175},
        "bondType": {"Sequential": None},
    },},
    "EQ": {
        "balance":  1_141_937.58,
        "rate": 0.0,
        "originBalance": 0.00,
        "originRate": 0.0,
        "startDate": "2024-06-12",
        "maturityDate": "2027-06-12",
        "rateType": {"Fixed": 0.00},
        "bondType": {"Equity": None},
    },
}
fees = {
    "technology_fee": {"type": {"annualPctFee": [("poolBalance",), 0.0005]}},
    "servicing_fee": {"type": {"annualPctFee": [("poolBalance",), 0.01]}}
}

waterfall = {
   "revolving": [
        ["calcIntByGroup", ["A", "B"]],
        ["transfer", "collections_interest_installment", "collections_account_installment"],
        ["transfer", "collections_interest_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_principal_installment", "collections_account_installment"],
        ["transfer", "collections_principal_mortgage", "collections_account_mortgage"],
        ["calcAndPayFee", "collections_account_installment", ["technology_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["transfer", "collections_account_installment", "revolBuyAcc_installment"],
        ["transfer", "collections_account_mortgage", "revolBuyAcc_mortgage"],
        ["buyAsset2",["Current|Defaulted", 1.0, 0],"revolBuyAcc_installment",None,"Pool1","pool_Installment"],
        ["buyAsset2",["Current|Defaulted", 1.0, 0],"revolBuyAcc_mortgage",None,"Pool2","pool_Mortgage"],
    ],
    "amortizing": [
        ["transfer", "collections_interest_installment", "collections_account_installment"],
        ["transfer", "collections_interest_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_principal_installment", "collections_account_installment"],
        ["transfer", "collections_principal_mortgage", "collections_account_mortgage"],
        ["calcIntByGroup", ["A", "B"]],
        ["calcAndPayFee", "collections_account_installment", ["technology_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["calcAndPayFee", "collections_account_installment", ["servicing_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["payIntResidual", "collections_account_installment", "EQ",{"support":["account","collections_account_mortgage"]}],
        ["payPrin", "collections_account_installment", ["EQ"],{"support":["account","collections_account_mortgage"]}],
    ],
    "cleanUp": [
        ["transfer", "revolBuyAcc_installment", "collections_account_installment"],
        ["transfer", "revolBuyAcc_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_principal_installment", "collections_account_installment"],
        ["transfer", "collections_principal_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_interest_installment", "collections_account_installment"],
        ["transfer", "collections_interest_mortgage", "collections_account_mortgage"],
        ["calcIntByGroup", ["A", "B"]],
        ["calcAndPayFee", "collections_account_installment", ["technology_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["calcAndPayFee", "collections_account_installment", ["servicing_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["payIntResidual", "collections_account_installment", "EQ",{"support":["account","collections_account_mortgage"]}],
        ["payPrin", "collections_account_installment", ["EQ"],{"support":["account","collections_account_mortgage"]}],
    ],
    "Defaulted": [
        ["transfer", "revolBuyAcc_installment", "collections_account_installment"],
        ["transfer", "revolBuyAcc_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_principal_installment", "collections_account_installment"],
        ["transfer", "collections_principal_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_interest_installment", "collections_account_installment"],
        ["transfer", "collections_interest_mortgage", "collections_account_mortgage"],
        ["calcIntByGroup", ["A", "B"]],
        ["calcAndPayFee", "collections_account_installment", ["technology_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["calcAndPayFee", "collections_account_installment", ["servicing_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["payIntResidual", "collections_account_installment", "EQ",{"support":["account","collections_account_mortgage"]}],
        ["payPrin", "collections_account_installment", ["EQ"],{"support":["account","collections_account_mortgage"]}],
    ],
}
collects = [
   [["pool_Installment"],"CollectedPrincipal", "collections_principal_installment"],
    [["pool_Installment"],"CollectedRecoveries", "collections_principal_installment"],
    [["pool_Installment"],"CollectedPrepayment", "collections_principal_installment"],
    [["pool_Installment"],"CollectedInterest", "collections_interest_installment"],
    [["pool_Mortgage"],"CollectedPrincipal", "collections_principal_mortgage"],
    [["pool_Mortgage"],"CollectedRecoveries", "collections_principal_mortgage"],
    [["pool_Mortgage"],"CollectedPrepayment", "collections_principal_mortgage"],
    [["pool_Mortgage"],"CollectedInterest", "collections_interest_mortgage"],
]
trigger = {
    "BeforeDistribution": {
        "amortization_trigger": {
            "condition": ["any", [">=", "2027-01-12"]],
            "effects": ("newStatus", "Amortizing"),
            "status": False,
            "curable": False,
        },
    }
}
deal_data = {
    "name": name,
    "dates": dates,
    "pool": j,
    "accounts": accounts,
    "fees": fees,
    "bonds": bonds_1,
    "waterfall": waterfall,
    "collect": collects,
    "trigger": trigger,
    "status": ("PreClosing","Revolving"),
}

deal = mkDeal(deal_data)

revol_asset1 = [['Installment',
  {'originBalance': 350583.6209365012,
   'feeRate': ['fix', 0.020826984419076017],
   'originTerm': 8,
   'freq': 'Monthly',
   'type': 'f_p',
   'originDate': '2024-01-16'},
  {'currentBalance': 152395.0074459817, 'remainTerm': 3, 'status': 'current'}]] # this is just the weighted average of all the relevant fields of the pool 
revol_asset2 = [['Mortgage',
  {'originBalance': 146161.910385964,
   'originRate': ['fix', 0.01992754906696362],
   'originTerm': 12,
   'freq': 'Monthly',
   'type': 'Level',
   'originDate': '2024-01-29'},
  {'currentBalance': 78421.96191231607,
   'currentRate': 0.01992754906696362,
   'remainTerm': 4,
   'status': 'current'}]]



revolvingPool1 = (["constant",*revol_asset1]
         ,("Pool",("Installment",{"CDR":0},None,None,None
                                                           )
           ,None
           ,None))
revolvingPool2 = (["constant",*revol_asset2]
                    ,("Pool",("Mortgage",{"CDR":0},None,None,None)
                    ,None
                    ,None))
installmentPoolAssump = ("Pool",("Installment",{"CDR":0},None,None,None)
                    ,None
                    ,None)
mortgagePoolAssump = ("Pool",("Mortgage",{"CDR":0},None,None,None)
                        ,None
                        ,None)
localAPI = API("http://localhost:8081/", lang="english")
r = localAPI.run(deal,
                                poolAssump = ("ByPoolId",
                                                    {"pool_Installment":installmentPoolAssump
                                                    ,"pool_Mortgage":mortgagePoolAssump}
                                                    ),
                        runAssump=[#tuple(trigger_inspect_creation(deal)),
                        ("interest", ("SONIA", 0.0519), ("EURIBOR1M", 0.03873)),
                            ("inspect",("MonthEnd",("bondBalance", "A1")),
                            ("MonthEnd",("curPoolCollectionStats", None, 0, "Principal")),
                            ("MonthEnd",("curPoolCollectionStats", None, 0, "Interest")),
                            ("MonthEnd",("curPoolCollectionStats", None, 0, "Defaults"))
                                            ),
                                            ("call", {"afterDate":"2027-06-01"}),
                                    ("revolving"
                                    ,{"Pool1":revolvingPool1,"Pool2":revolvingPool2})
                                                            ]
                        ,read=True)
# Out:
# Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.28.7, server:0.29.12
# Connecting engine server -> http://localhost:8081
# pls upgrade your api package by: pip -U absbox
# ---------------------------------------------------------------------------
# VersionMismatch                           Traceback (most recent call last)
# Cell In[3], line 226
#     220 installmentPoolAssump = ("Pool",("Installment",{"CDR":0},None,None,None)
#     221                     ,None
#     222                     ,None)
#     223 mortgagePoolAssump = ("Pool",("Mortgage",{"CDR":0},None,None,None)
#     224                         ,None
#     225                         ,None)
# --> 226 localAPI = API("http://localhost:8081/", lang="english")
#     227 r = localAPI.run(deal,
#     228                                 poolAssump = ("ByPoolId",
#     229                                                     {"pool_Installment":installmentPoolAssump
#    (...)
#     242                                                             ]
#     243                         ,read=True)
#
# File <string>:6, in __init__(self, url, lang, check)
#
# File ~/Projects/PyABS/absbox/client.py:238, in API.__post_init__(self)
#     236 if self.check and (self.version[1] != engine_version[1]):
#     237     console.print("pls upgrade your api package by: pip -U absbox")
# --> 238     raise VersionMismatch('.'.join(self.version), '.'.join(engine_version))
#     239 console.print(f"✅{MsgColor.Success.value}Connected, local lib:{'.'.join(self.version)}, server:{'.'.join(engine_version)}")
#     240 self.session = requests.Session()
#
# VersionMismatch: Failed to match version, lib support=0.28.7 but server version=0.29.12

# %%
r['pool']['flow']['pool_Installment']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 r['pool']['flow']['pool_Installment']
#
# NameError: name 'r' is not defined

# %%
# I believe interest is too high when revolving the weighted average remaining term of the revolving assets and the pool is the same which is 3 rounded up
1524773.6 * (1.021324)**12 /3 # this should be the monthly payment for 2024-12-31 if I'm not mistaken
# Out:
# 651597.7051975894

# %%
localAPI = API("http://localhost:8081/", lang="english")
r = localAPI.run(deal,
                                poolAssump = ("ByPoolId",
                                                    {"pool_Installment":installmentPoolAssump
                                                    ,"pool_Mortgage":mortgagePoolAssump}
                                                    ),
                        runAssump=[#tuple(trigger_inspect_creation(deal)),
                        ("interest", ("SONIA", 0.0519), ("EURIBOR1M", 0.03873)),
                            ("inspect",("MonthEnd",("bondBalance", "A1")),
                            ("MonthEnd",("poolBalance","pool_Installment")),
                            ("MonthEnd",("poolBalance","pool_Mortgage")),
                            ("MonthEnd",("curPoolCollectionStats", None, 0, "Principal")),
                            ("MonthEnd",("curPoolCollectionStats", None, 0, "Interest")),
                            ("MonthEnd",("curPoolCollectionStats", None, 0, "Defaults"))
                            ,("MonthEnd",("accountBalance","revolBuyAcc_installment","revolBuyAcc_mortgage",))
                                            ,("MonthEnd",("curPoolCollectionStats", None, 0, "BegBalance"))
                                            ,("MonthEnd",("ratio",("curPoolCollectionStats", None, 0, "Defaults"),("curPoolCollectionStats", None, 0, "BegBalance")))
                                            ,("MonthEnd",("ratio",("curPoolCollectionStats", None, -1, "Defaults"),("curPoolCollectionStats", None, -1, "BegBalance")))
                                            ,("MonthEnd",("ratio",("curPoolCollectionStats", None, -2, "Defaults"),("curPoolCollectionStats", None, -2, "BegBalance")))
                                            
                                            ),
                                            ("call", {"afterDate":"2027-06-01"}),
                                    ("revolving"
                                    ,{"Pool1":revolvingPool1,"Pool2":revolvingPool2})
                                                            ]
                        ,read=True) 



### This is the error I get: 
'''
2024-10-18 14:34:18 Run Deal end with
2024-10-18 14:34:18 src/Types.hs:(797,3)-(825,66): Non-exhaustive patterns in function toJSON
2024-10-18 14:34:18

'''
# Out:
# Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.29.9, server:0.29.10
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1368, in HTTPConnection.getresponse(self)
#    1367 try:
# -> 1368     response.begin()
#    1369 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:317, in HTTPResponse.begin(self)
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:286, in HTTPResponse._read_status(self)
#     283 if not line:
#     284     # Presumably, the server closed the connection before
#     285     # sending a valid response.
# --> 286     raise RemoteDisconnected("Remote end closed connection without"
#     287                              " response")
#     288 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1368, in HTTPConnection.getresponse(self)
#    1367 try:
# -> 1368     response.begin()
#    1369 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:317, in HTTPResponse.begin(self)
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:286, in HTTPResponse._read_status(self)
#     283 if not line:
#     284     # Presumably, the server closed the connection before
#     285     # sending a valid response.
# --> 286     raise RemoteDisconnected("Remote end closed connection without"
#     287                              " response")
#     288 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\absbox\client.py:913, in API._send_req(self, _req, _url, timeout, headers)
#     912 if self.session:
# --> 913     r = self.session.post(_url, data=_req.encode('utf-8'), headers=hdrs, verify=False, timeout=timeout)
#     914 else:
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\sessions.py:635, in Session.post(self, url, data, json, **kwargs)
#     625 r"""Sends a POST request. Returns :class:`Response` object.
#     626
#     627 :param url: URL for the new :class:`Request` object.
#    (...)
#     632 :rtype: requests.Response
#     633 """
# --> 635 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# AbsboxError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 localAPI = API("http://localhost:8081/", lang="english")
# ----> 2 r = localAPI.run(deal,
#       3                                 poolAssump = ("ByPoolId",
#       4                                                     {"pool_Installment":installmentPoolAssump
#       5                                                     ,"pool_Mortgage":mortgagePoolAssump}
#       6                                                     ),
#       7                         runAssump=[#tuple(trigger_inspect_creation(deal)),
#       8                         ("interest", ("SONIA", 0.0519), ("EURIBOR1M", 0.03873)),
#       9                             ("inspect",("MonthEnd",("bondBalance", "A1")),
#      10                             ("MonthEnd",("poolBalance","pool_Installment")),
#      11                             ("MonthEnd",("poolBalance","pool_Mortgage")),
#      12                             ("MonthEnd",("curPoolCollectionStats", None, 0, "Principal")),
#      13                             ("MonthEnd",("curPoolCollectionStats", None, 0, "Interest")),
#      14                             ("MonthEnd",("curPoolCollectionStats", None, 0, "Defaults"))
#      15                             ,("MonthEnd",("accountBalance","revolBuyAcc_installment","revolBuyAcc_mortgage",))
#      16                                             ,("MonthEnd",("curPoolCollectionStats", None, 0, "BegBalance"))
#      17                                             ,("MonthEnd",("ratio",("curPoolCollectionStats", None, 0, "Defaults"),("curPoolCollectionStats", None, 0, "BegBalance")))
#      18                                             ,("MonthEnd",("ratio",("curPoolCollectionStats", None, -1, "Defaults"),("curPoolCollectionStats", None, -1, "BegBalance")))
#      19                                             ,("MonthEnd",("ratio",("curPoolCollectionStats", None, -2, "Defaults"),("curPoolCollectionStats", None, -2, "BegBalance")))
#      20
#      21                                             ),
#      22                                             ("call", {"afterDate":"2027-06-01"}),
#      23                                     ("revolving"
#      24                                     ,{"Pool1":revolvingPool1,"Pool2":revolvingPool2})
#      25                                                             ]
#      26                         ,read=True)
#      30 ### This is the error I get:
#      31 '''
#      32 2024-10-18 14:34:18 Run Deal end with
#      33 2024-10-18 14:34:18 src/Types.hs:(797,3)-(825,66): Non-exhaustive patterns in function toJSON
#      34 2024-10-18 14:34:18
#      35
#      36 '''
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\absbox\client.py:371, in API.run(self, deal, poolAssump, runAssump, read, showWarning, debug)
#     369 # branching with pricing
#     370 if runAssump is None or searchByFst(runAssump, "pricing") is None:
# --> 371     result = self._send_req(req, url)
#     372 else:
#     373     result = self._send_req(req, url, timeout=30)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\absbox\client.py:917, in API._send_req(self, _req, _url, timeout, headers)
#     915         raise AbsboxError(f"❌: None type for session")
#     916 except (ConnectionRefusedError, ConnectionError):
# --> 917     raise AbsboxError(f"❌ Failed to talk to server {_url}")
#     918 except ReadTimeout:
#     919     raise AbsboxError(f"❌ Failed to get response from server")
#
# AbsboxError: ❌ Failed to talk to server http://localhost:8081/runDeal

# %%
from absbox import API, mkDeal
import pandas as pd 
localAPI = API("http://localhost:8081/", lang="english")



name = "Name"
dates = {
           "cutoff":"2024-09-30","closing":"2024-09-30","firstPay":"2024-10-31",
            "stated": "2027-06-12",
            "poolFreq": "MonthEnd",
            "payFreq": "MonthEnd",
        }

installment_assets = [['Installment', {'originBalance': 314136.13, 'feeRate': ['fix', 0.021666666666666667], 'originTerm': 5, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-09-16'}, {'currentBalance': 314136.13, 'remainTerm': 4, 'status': 'current'}], 
                      ['Installment', {'originBalance': 63762.0, 'feeRate': ['fix', 0.020833333333333332], 'originTerm': 6, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-09-18'}, {'currentBalance': 63762.0, 'remainTerm': 6, 'status': 'current'}], 
                      ['Installment', {'originBalance': 85470.0, 'feeRate': ['fix', 0.0225], 'originTerm': 7, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-04-26'}, {'currentBalance': 14274.67, 'remainTerm': 1, 'status': 'current'}], 
                      ['Installment', {'originBalance': 500000.0, 'feeRate': ['fix', 0.019166666666666665], 'originTerm': 9, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-05-03'}, {'currentBalance': 250416.51, 'remainTerm': 4, 'status': 'current'}], 
                      ['Installment', {'originBalance': 65000.0, 'feeRate': ['fix', 0.015833333333333335], 'originTerm': 1, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-09-30'}, {'currentBalance': 6540.67, 'remainTerm': 1, 'status': 'current'}], 
                      ['Installment', {'originBalance': 108992.0, 'feeRate': ['fix', 0.020833333333333332], 'originTerm': 10, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-02-15'}, {'currentBalance': 24291.09, 'remainTerm': 2, 'status': 'current'}], 
                      ['Installment', {'originBalance': 154000.0, 'feeRate': ['fix', 0.0225], 'originTerm': 10, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-02-20'}, {'currentBalance': 34322.04, 'remainTerm': 2, 'status': 'current'}], 
                      ['Installment', {'originBalance': 350000.0, 'feeRate': ['fix', 0.020833333333333332], 'originTerm': 8, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-04-25'}, {'currentBalance': 100208.31, 'remainTerm': 2, 'status': 'current'}], 
                      ['Installment', {'originBalance': 80000.0, 'feeRate': ['fix', 0.021666666666666667], 'originTerm': 8, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-04-15'}, {'currentBalance': 40766.45, 'remainTerm': 2, 'status': 'current'}], 
                      ['Installment', {'originBalance': 500000.0, 'feeRate': ['fix', 0.021666666666666667], 'originTerm': 9, 'freq': 'Monthly', 'type': 'f_p', 'originDate': '2024-03-19'}, {'currentBalance': 125312.57, 'remainTerm': 2, 'status': 'current'}]]

mortage_assets = [['Mortgage', {'originBalance': 200000.0, 'originRate': ['fix', 0.0], 'originTerm': 12, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2023-02-04'}, {'currentBalance': 127435.62, 'currentRate': 0.0, 'remainTerm': 1, 'status': 'Current'}], ['Mortgage', {'originBalance': 150000.0, 'originRate': ['fix', 0.0], 'originTerm': 12, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-04-01'}, {'currentBalance': 57797.85, 'currentRate': 0.0, 'remainTerm': 7, 'status': 'Current'}], ['Mortgage', {'originBalance': 75000.0, 'originRate': ['fix', 0.0], 'originTerm': 12, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2023-01-31'}, {'currentBalance': 28805.04, 'currentRate': 0.0, 'remainTerm': 1, 'status': 'Current'}], ['Mortgage', {'originBalance': 6000.0, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-11'}, {'currentBalance': 6000.0, 'currentRate': 0.21, 'remainTerm': 2, 'status': 'Current'}], ['Mortgage', {'originBalance': 6000.0, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-11'}, {'currentBalance': 6000.0, 'currentRate': 0.21, 'remainTerm': 2, 'status': 'Current'}], ['Mortgage', {'originBalance': 1099.32, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-07-31'}, {'currentBalance': 1099.32, 'currentRate': 0.21, 'remainTerm': 1, 'status': 'Current'}], ['Mortgage', {'originBalance': 1161.0, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-07-16'}, {'currentBalance': 1161.0, 'currentRate': 0.21, 'remainTerm': 1, 'status': 'Current'}], ['Mortgage', {'originBalance': 6333.0, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-18'}, {'currentBalance': 6333.0, 'currentRate': 0.21, 'remainTerm': 3, 'status': 'Current'}], ['Mortgage', {'originBalance': 4748.55, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-16'}, {'currentBalance': 4748.55, 'currentRate': 0.21, 'remainTerm': 3, 'status': 'Current'}], ['Mortgage', {'originBalance': 19215.92, 'originRate': ['fix', 0.21], 'originTerm': 3, 'freq': 'Monthly', 'type': 'Level', 'originDate': '2024-09-19'}, {'currentBalance': 19215.92, 'currentRate': 0.21, 'remainTerm': 3, 'status': 'Current'}]]

j = {"pool_Installment": {'assets':installment_assets},"pool_Mortgage": {'assets':mortage_assets}}

accounts = {
            "collections_interest_installment": {"balance": 0},
            "collections_interest_mortgage": {"balance": 0},
            "collections_principal_installment": {"balance": 0},
            "collections_principal_mortgage": {"balance": 0},
            "collections_account_installment":{"balance":0},
            "collections_account_mortgage":{"balance":0},
            "revolBuyAcc_installment": {"balance": 0},
            "revolBuyAcc_mortgage":{"balance": 0},
        }
     

bonds_1 = {
    "A": {"A1": {
        "balance":  13_019_000.00,
        "rate": 0.1023,
        "originBalance": 50_000_000,
        "originRate": 0.1023,
        "startDate": "2024-06-12",
        "rateType":  {
            "floater": [0.03588, "EURIBOR1M", 0.085, "MonthEnd"],
            "dayCount": "DC_ACT_360",
        },
        "maturityDate": "2027-06-12",
        "bondType": {"Sequential": None},
    },},
    "B": {"B1": {
        "balance":   487_899.20,
        "rate": 0.175,
        "originBalance": 2_777_778.00,
        "originRate": 0.175,
        "startDate": "2024-06-12",
        "maturityDate": "2027-06-12",
        "rateType": {"Fixed": 0.175},
        "bondType": {"Sequential": None},
    },},
    "EQ": {
        "balance":  1_141_937.58,
        "rate": 0.0,
        "originBalance": 0.00,
        "originRate": 0.0,
        "startDate": "2024-06-12",
        "maturityDate": "2027-06-12",
        "rateType": {"Fixed": 0.00},
        "bondType": {"Equity": None},
    },
}
fees = {
    "technology_fee": {"type": {"annualPctFee": [("poolBalance",), 0.0005]}},
    "servicing_fee": {"type": {"annualPctFee": [("poolBalance",), 0.01]}}
}

waterfall = {
   "revolving": [
        ["calcIntByGroup", ["A", "B"]],
        ["transfer", "collections_interest_installment", "collections_account_installment"],
        ["transfer", "collections_interest_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_principal_installment", "collections_account_installment"],
        ["transfer", "collections_principal_mortgage", "collections_account_mortgage"],
        ["calcAndPayFee", "collections_account_installment", ["technology_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["transfer", "collections_account_installment", "revolBuyAcc_installment"],
        ["transfer", "collections_account_mortgage", "revolBuyAcc_mortgage"],
        ["buyAsset2",["Current|Defaulted", 1.0, 0],"revolBuyAcc_installment",None,"Pool1","pool_Installment"],
        ["buyAsset2",["Current|Defaulted", 1.0, 0],"revolBuyAcc_mortgage",None,"Pool2","pool_Mortgage"],
    ],
    "amortizing": [
        ["transfer", "collections_interest_installment", "collections_account_installment"],
        ["transfer", "collections_interest_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_principal_installment", "collections_account_installment"],
        ["transfer", "collections_principal_mortgage", "collections_account_mortgage"],
        ["calcIntByGroup", ["A", "B"]],
        ["calcAndPayFee", "collections_account_installment", ["technology_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["calcAndPayFee", "collections_account_installment", ["servicing_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["payIntResidual", "collections_account_installment", "EQ",{"support":["account","collections_account_mortgage"]}],
        ["payPrin", "collections_account_installment", ["EQ"],{"support":["account","collections_account_mortgage"]}],
    ],
    "cleanUp": [
        ["transfer", "revolBuyAcc_installment", "collections_account_installment"],
        ["transfer", "revolBuyAcc_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_principal_installment", "collections_account_installment"],
        ["transfer", "collections_principal_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_interest_installment", "collections_account_installment"],
        ["transfer", "collections_interest_mortgage", "collections_account_mortgage"],
        ["calcIntByGroup", ["A", "B"]],
        ["calcAndPayFee", "collections_account_installment", ["technology_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["calcAndPayFee", "collections_account_installment", ["servicing_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["payIntResidual", "collections_account_installment", "EQ",{"support":["account","collections_account_mortgage"]}],
        ["payPrin", "collections_account_installment", ["EQ"],{"support":["account","collections_account_mortgage"]}],
    ],
    "Defaulted": [
        ["transfer", "revolBuyAcc_installment", "collections_account_installment"],
        ["transfer", "revolBuyAcc_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_principal_installment", "collections_account_installment"],
        ["transfer", "collections_principal_mortgage", "collections_account_mortgage"],
        ["transfer", "collections_interest_installment", "collections_account_installment"],
        ["transfer", "collections_interest_mortgage", "collections_account_mortgage"],
        ["calcIntByGroup", ["A", "B"]],
        ["calcAndPayFee", "collections_account_installment", ["technology_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "A", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["accrueAndPayIntByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["payPrinByGroup", "collections_account_installment", "B", "byStartDate",{"support":["account","collections_account_mortgage"]}],
        ["calcAndPayFee", "collections_account_installment", ["servicing_fee"],
            {"support":["account","collections_account_mortgage"]}],
        ["payIntResidual", "collections_account_installment", "EQ",{"support":["account","collections_account_mortgage"]}],
        ["payPrin", "collections_account_installment", ["EQ"],{"support":["account","collections_account_mortgage"]}],
    ],
}
collects = [
   [["pool_Installment"],"CollectedPrincipal", "collections_principal_installment"],
    [["pool_Installment"],"CollectedRecoveries", "collections_principal_installment"],
    [["pool_Installment"],"CollectedPrepayment", "collections_principal_installment"],
    [["pool_Installment"],"CollectedInterest", "collections_interest_installment"],
    [["pool_Mortgage"],"CollectedPrincipal", "collections_principal_mortgage"],
    [["pool_Mortgage"],"CollectedRecoveries", "collections_principal_mortgage"],
    [["pool_Mortgage"],"CollectedPrepayment", "collections_principal_mortgage"],
    [["pool_Mortgage"],"CollectedInterest", "collections_interest_mortgage"],
]
trigger = {
    "BeforeDistribution": {
        "amortization_trigger": {
            "condition": ["any", [">=", "2027-01-12"]],
            "effects": ("newStatus", "Amortizing"),
            "status": False,
            "curable": False,
        },
    }
}
deal_data = {
    "name": name,
    "dates": dates,
    "pool": j,
    "accounts": accounts,
    "fees": fees,
    "bonds": bonds_1,
    "waterfall": waterfall,
    "collect": collects,
    "trigger": trigger,
    "status": ("PreClosing","Revolving"),
}

deal = mkDeal(deal_data)

revol_asset1 = [['Installment',
  {'originBalance': 350583.6209365012,
   'feeRate': ['fix', 0.020826984419076017],
   'originTerm': 8,
   'freq': 'Monthly',
   'type': 'f_p',
   'originDate': '2024-01-16'},
  {'currentBalance': 152395.0074459817, 'remainTerm': 3, 'status': 'current'}]] # this is just the weighted average of all the relevant fields of the pool 
revol_asset2 = [['Mortgage',
  {'originBalance': 146161.910385964,
   'originRate': ['fix', 0.01992754906696362],
   'originTerm': 12,
   'freq': 'Monthly',
   'type': 'Level',
   'originDate': '2024-01-29'},
  {'currentBalance': 78421.96191231607,
   'currentRate': 0.01992754906696362,
   'remainTerm': 4,
   'status': 'current'}]]



revolvingPool1 = (["constant",*revol_asset1]
         ,("Pool",("Installment",{"CDR":0},None,None,None
                                                           )
           ,None
           ,None))
revolvingPool2 = (["constant",*revol_asset2]
                    ,("Pool",("Mortgage",{"CDR":0},None,None,None)
                    ,None
                    ,None))
installmentPoolAssump = ("Pool",("Installment",{"CDR":0},None,None,None)
                    ,None
                    ,None)
mortgagePoolAssump = ("Pool",("Mortgage",{"CDR":0},None,None,None)
                        ,None
                        ,None)
localAPI = API("http://localhost:8081/", lang="english")
r = localAPI.run(deal,
                                poolAssump = ("ByPoolId",
                                                    {"pool_Installment":installmentPoolAssump
                                                    ,"pool_Mortgage":mortgagePoolAssump}
                                                    ),
                        runAssump=[#tuple(trigger_inspect_creation(deal)),
                        ("interest", ("SONIA", 0.0519), ("EURIBOR1M", 0.03873)),
                            ("inspect",("MonthEnd",("bondBalance", "A1")),
                            ("MonthEnd",("curPoolCollectionStats", None, 0, "Principal")),
                            ("MonthEnd",("curPoolCollectionStats", None, 0, "Interest")),
                            ("MonthEnd",("curPoolCollectionStats", None, 0, "Defaults"))
                                            ),
                                            ("call", {"afterDate":"2027-06-01"}),
                                    ("revolving"
                                    ,{"Pool1":revolvingPool1,"Pool2":revolvingPool2})
                                                            ]
                        ,read=True)
'''
#ERROR I GET
2024-10-18 17:55:35 Run Deal end with
2024-10-18 17:55:35 Ratio has zero denominator'''
# Out:
# Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.29.9, server:0.29.5
# Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.29.9, server:0.29.5
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1368, in HTTPConnection.getresponse(self)
#    1367 try:
# -> 1368     response.begin()
#    1369 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:317, in HTTPResponse.begin(self)
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:286, in HTTPResponse._read_status(self)
#     283 if not line:
#     284     # Presumably, the server closed the connection before
#     285     # sending a valid response.
# --> 286     raise RemoteDisconnected("Remote end closed connection without"
#     287                              " response")
#     288 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1368, in HTTPConnection.getresponse(self)
#    1367 try:
# -> 1368     response.begin()
#    1369 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:317, in HTTPResponse.begin(self)
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:286, in HTTPResponse._read_status(self)
#     283 if not line:
#     284     # Presumably, the server closed the connection before
#     285     # sending a valid response.
# --> 286     raise RemoteDisconnected("Remote end closed connection without"
#     287                              " response")
#     288 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\absbox\client.py:913, in API._send_req(self, _req, _url, timeout, headers)
#     912 if self.session:
# --> 913     r = self.session.post(_url, data=_req.encode('utf-8'), headers=hdrs, verify=False, timeout=timeout)
#     914 else:
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\sessions.py:635, in Session.post(self, url, data, json, **kwargs)
#     625 r"""Sends a POST request. Returns :class:`Response` object.
#     626
#     627 :param url: URL for the new :class:`Request` object.
#    (...)
#     632 :rtype: requests.Response
#     633 """
# --> 635 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\requests\adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# AbsboxError                               Traceback (most recent call last)
# Cell In[27], line 227
#     223 mortgagePoolAssump = ("Pool",("Mortgage",{"CDR":0},None,None,None)
#     224                         ,None
#     225                         ,None)
#     226 localAPI = API("http://localhost:8081/", lang="english")
# --> 227 r = localAPI.run(deal,
#     228                                 poolAssump = ("ByPoolId",
#     229                                                     {"pool_Installment":installmentPoolAssump
#     230                                                     ,"pool_Mortgage":mortgagePoolAssump}
#     231                                                     ),
#     232                         runAssump=[#tuple(trigger_inspect_creation(deal)),
#     233                         ("interest", ("SONIA", 0.0519), ("EURIBOR1M", 0.03873)),
#     234                             ("inspect",("MonthEnd",("bondBalance", "A1")),
#     235                             ("MonthEnd",("curPoolCollectionStats", None, 0, "Principal")),
#     236                             ("MonthEnd",("curPoolCollectionStats", None, 0, "Interest")),
#     237                             ("MonthEnd",("curPoolCollectionStats", None, 0, "Defaults"))
#     238                                             ),
#     239                                             ("call", {"afterDate":"2027-06-01"}),
#     240                                     ("revolving"
#     241                                     ,{"Pool1":revolvingPool1,"Pool2":revolvingPool2})
#     242                                                             ]
#     243                         ,read=True)
#     244 '''2024-10-18 17:55:35 Run Deal end with
#     245 2024-10-18 17:55:35 Ratio has zero denominator'''
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\absbox\client.py:371, in API.run(self, deal, poolAssump, runAssump, read, showWarning, debug)
#     369 # branching with pricing
#     370 if runAssump is None or searchByFst(runAssump, "pricing") is None:
# --> 371     result = self._send_req(req, url)
#     372 else:
#     373     result = self._send_req(req, url, timeout=30)
#
# File c:\Users\AntonyJomon\Documents\Python_code\cashflow-model\.venv\lib\site-packages\absbox\client.py:917, in API._send_req(self, _req, _url, timeout, headers)
#     915         raise AbsboxError(f"❌: None type for session")
#     916 except (ConnectionRefusedError, ConnectionError):
# --> 917     raise AbsboxError(f"❌ Failed to talk to server {_url}")
#     918 except ReadTimeout:
#     919     raise AbsboxError(f"❌ Failed to get response from server")
#
# AbsboxError: ❌ Failed to talk to server http://localhost:8081/runDeal
