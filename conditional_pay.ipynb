# %% [markdown]
#  In [1]: %load_ext autoreload
#
#  In [2]: %autoreload 2
#
#  In [3]: from foo import some_function
#
#  In [4]: some_function()
#  Out[4]: 42
#
#  In [5]: # open foo.py in an editor and change some_function to return 43
#
#  In [6]: some_function()
#  Out[6]: 43
#
#
#  https://ipython.org/ipython-doc/3/config/extensions/autoreload.html

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from absbox.local.generic import Generic

test01 = Generic(
    "If in Waterfall"
    ,{"cutoff":"2021-03-01","closing":"2021-06-15","firstPay":"2021-07-26"
     ,"payFreq":["DayOfMonth",20],"poolFreq":"MonthEnd","stated":"2030-01-01"}
    ,{'assets':[["Mortgage"
        ,{"originBalance":2200,"originRate":["fix",0.045],"originTerm":30
          ,"freq":"Monthly","type":"Level","originDate":"2021-02-01"}
          ,{"currentBalance":2200
          ,"currentRate":0.08
          ,"remainTerm":20
          ,"status":"current"}]]}
    ,(("acc01",{"balance":0}),)
    ,(("A1",{"balance":500
             ,"rate":0.07
             ,"originBalance":500
             ,"originRate":0.07
             ,"startDate":"2020-01-03"
             ,"maturityDate":"2022-03-31"
             ,"rateType":{"Fixed":0.08}
             ,"bondType":{"Sequential":None}})
      ,("A2",{"balance":500
             ,"rate":0.07
             ,"originBalance":500
             ,"originRate":0.07
             ,"startDate":"2020-01-03"
             ,"rateType":{"Fixed":0.08}
             ,"bondType":{"Sequential":None}})
      ,("B",{"balance":1000
             ,"rate":0.0
             ,"originBalance":1000
             ,"originRate":0.07
             ,"startDate":"2020-01-03"
             ,"rateType":{"Fixed":0.00}
             ,"bondType":{"Equity":None}
             }))
    ,(("trusteeFee",{"type":{"fixFee":30}}),)
    ,{"amortizing":[
         ["payFee",["acc01"],['trusteeFee']]
         ,["payInt","acc01",["A1","A2"]]
         ,["条件执行"
           ,[("monthsTillMaturity","A1"),"<",3]
           ,["payPrin","acc01",["A1","A2"]]
           ]
         ,["payPrin","acc01",["B"]]
         ,["payResidual","acc01","B"]]
      }
    ,[["CollectedInterest","acc01"]
      ,["CollectedPrincipal","acc01"]
      ,["CollectedPrepayment","acc01"]
      ,["CollectedRecoveries","acc01"]]
    ,None
    ,None
    ,None
    ,None
    )

# %%
from absbox import API
#localAPI = API("https://absbox.org/api/dev")
localAPI = API("http://localhost:8081")

# %%
r = localAPI.run(test01
             ,assumptions=[]
             ,read=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 r = localAPI.run(test01
#       2              ,assumptions=[]
#       3              ,read=True)
#
# File ~/IdeaProjects/PyABS/absbox/client.py:113, in API.run(self, deal, assumptions, pricing, read, position, timing)
#     110         deal = pickle.loads(c)
#     112 # construct request
# --> 113 req = self.build_req(deal, assumptions, pricing)
#     115 #validate deal
#     116 val_result, err, warn = self.validate(req)
#
# File ~/IdeaProjects/PyABS/absbox/client.py:52, in API.build_req(self, deal, assumptions, pricing)
#      50 r = None
#      51 _assump = None
# ---> 52 _deal = deal.json
#      53 _pricing = mkPricingAssump(pricing) if pricing else None
#      54 if isinstance(assumptions, dict):
#
# File ~/IdeaProjects/PyABS/absbox/local/generic.py:48, in Generic.json(self)
#      35 closingDate = self.dates['closing']
#      36 """
#      37 get the json formatted string
#      38 """
#      39 _r = {
#      40     "dates": parsedDates,
#      41     "name": self.name,
#      42     "status":mkTag((self.status)),
#      43     "pool": {"assets": [mkAsset(x) for x in self.pool.get('assets', [])]
#      44              , "asOfDate": self.dates['cutoff']
#      45              , "issuanceStat": self.pool.get("issuanceStat")
#      46              , "futureCf":mkCf(self.pool.get('cashflow', [])) },
#      47     "bonds": { bn: mkBnd(bn,bo) for (bn,bo) in self.bonds},
# ---> 48     "waterfall": mkWaterfall({},self.waterfall.copy()),
#      49     "fees": {fn: mkFee(fo|{"name":fn},fsDate = closingDate)
#      50                          for (fn,fo) in self.fees},
#      51     "accounts": {an:mkAcc(an,ao) for (an,ao) in self.accounts},
#      52     "collects": [ mkCollection(c) for c in self.collection],
#      53     "rateSwap": { k:mkRateSwap(v) for k,v in self.currencySwap.items()} if self.rateSwap else None,
#      54     "currencySwap":None ,
#      55     "custom": {cn:mkCustom(co) for cn,co in self.custom.items()} if self.custom else None ,
#      56     "triggers": renameKs2(mapListValBy(self.trigger,mkTrigger),englishDealCycle) if self.trigger else None,
#      57     "liqProvider": {ln: mkLiqProvider(ln, lo | {"start":closingDate} )
#      58                        for ln,lo in self.liqFacility.items() } if self.liqFacility else None
#      59 }
#      61 _dealType = identify_deal_type(_r)
#      63 return mkTag((_dealType,_r))
#
# File ~/IdeaProjects/PyABS/absbox/local/component.py:629, in mkWaterfall(r, x)
#     611 match _k:
#     612     case ("兑付日", "加速清偿") | ("amortizing", "accelerated"):
#     613         _w_tag = f"DistributionDay (DealAccelerated Nothing)"
#    (...)
#     626     case _:
#     627         raise RuntimeError(f"Failed to match :{x}:mkWaterfall")
#     628 # r[_w_tag] = itertools.chain.from_iterable([mkAction(_a) for _a in _v])
# --> 629 r[_w_tag] = [mkAction(_a) for _a in _v]
#     630 return mkWaterfall(r, x)
#
# File ~/IdeaProjects/PyABS/absbox/local/component.py:629, in <listcomp>(.0)
#     611 match _k:
#     612     case ("兑付日", "加速清偿") | ("amortizing", "accelerated"):
#     613         _w_tag = f"DistributionDay (DealAccelerated Nothing)"
#    (...)
#     626     case _:
#     627         raise RuntimeError(f"Failed to match :{x}:mkWaterfall")
#     628 # r[_w_tag] = itertools.chain.from_iterable([mkAction(_a) for _a in _v])
# --> 629 r[_w_tag] = [mkAction(_a) for _a in _v]
#     630 return mkWaterfall(r, x)
#
# File ~/IdeaProjects/PyABS/absbox/local/component.py:498, in mkAction(x)
#     443 def mkAction(x):
#     444     match x:
#     445         case ["账户转移", source, target] | ["transfer", source, target]:
#     446             return mkTag(("Transfer", [source, target]))
#     447         case ["按公式账户转移", _limit, source, target] | ["transferBy", _limit, source, target]:
#     448             return mkTag(("TransferBy", [mkTransferLimit(_limit), source, target]))
#     449         case ["计提费用", *feeNames] | ["calcFee", *feeNames]:
#     450             return mkTag(("CalcFee", feeNames))
#     451         case ["计提利息", *bndNames] | ["calcInt", *bndNames]:
#     452             return mkTag(("CalcBondInt", bndNames))
#     453         case ["支付费用", source, target] | ["payFee", source, target]:
#     454             return mkTag(("PayFee", [source, target]))
#     455         case ["支付费用收益", source, target, _limit] | ["payFeeResidual", source, target, _limit]:
#     456             limit = mkAccountCapType(_limit)
#     457             return mkTag(("PayFeeResidual", [limit, source, target]))
#     458         case ["支付费用收益", source, target] | ["payFeeResidual", source, target]:
#     459             return mkTag(("PayFeeResidual", [None, source, target]))
#     460         case ["支付费用限额", source, target, _limit] | ["payFeeBy", source, target, _limit]:
#     461             limit = mkFeeCapType(_limit)
#     462             return mkTag(("PayFeeBy", [limit, source, target]))
#     463         case ["支付利息", source, target] | ["payInt", source, target]:
#     464             return mkTag(("PayInt", [source, target]))
#     465         case ["支付本金", source, target, _limit] | ["payPrin", source, target, _limit]:
#     466             pda = mkPDA(_limit)
#     467             return mkTag(("PayPrinBy", [pda, source, target]))
#     468         case ["支付本金", source, target] | ["payPrin", source, target]:
#     469             return mkTag(("PayPrin", [source, target]))
#     470         case ["支付剩余本金", source, target] | ["payPrinResidual", source, target]:
#     471             return mkTag(("PayPrinResidual", [source, target]))
#     472         case ["支付期间收益", source, target]:
#     473             return mkTag(("PayTillYield", [source, target]))
#     474         case ["支付收益", source, target, limit] | ["payResidual", source, target, limit]:
#     475             return mkTag(("PayResidual", [limit, source, target]))
#     476         case ["支付收益", source, target] | ["payResidual", source, target]:
#     477             return mkTag(("PayResidual", [None, source, target]))
#     478         case ["储备账户转移", source, target, satisfy] | ["transferReserve", source, target, satisfy]:
#     479             _map = {"源储备": "Source", "目标储备": "Target"}
#     480             return mkTag(("TransferReserve", [_map[satisfy], source, target]))
#     481         case ["出售资产", liq, target] | ["sellAsset", liq, target]:
#     482             return mkTag(("LiquidatePool", [mkLiqMethod(liq), target]))
#     483         case ["流动性支持", source, target, limit] | ["liqSupport", source, target, limit]:
#     484             return mkTag(("LiqSupport", [mkTag(("DS", mkDs(limit))), source, target]))
#     485         case ["流动性支持", source, target] | ["liqSupport", source, target]:
#     486             return mkTag(("LiqSupport", [None, source, target]))
#     487         case ["流动性支持偿还", rpt, source, target] | ["liqRepay", rpt, source, target]:
#     488             return mkTag(("LiqRepay", [None, mkLiqRepayType(rpt), source, target]))
#     489         case ["流动性支持偿还", source, target] | ["liqRepay",  source, target]:
#     490             return mkTag(("LiqRepay", [None, "bal", source, target]))
#     491         case ["流动性支持报酬", source, target] | ["liqRepayResidual", source, target]:
#     492             return mkTag(("LiqYield", [None, source, target]))
#     493         case ["流动性支持计提", target] | ["liqAccrue", target]:
#     494             return mkTag(("LiqAccrue", target))
#     495         case ["条件执行", pre, *actions] | ["If", pre, *actions]:
#     496             return mkTag(("ActionWithPre", [mkPre(pre), [mkAction(a) for a in actions] ] ))
#     497         case _:
# --> 498             raise RuntimeError(f"Failed to match :{x}:mkAction")
#
# RuntimeError: Failed to match :['条件执行1', [('monthsTillMaturity', 'A1'), '<', 3], ['payPrin', 'acc01', ['A1', 'A2']]]:mkAction

# %%
r['bonds']['A1']
# Out:
#             balance  interest  principal  rate   cash  \
# date
# 2021-07-26   500.00      3.93       0.00  0.07   3.93
# 2021-08-20   500.00      2.39       0.00  0.07   2.39
# 2021-09-20   500.00      2.97       0.00  0.07   2.97
# 2021-10-20   500.00      2.87       0.00  0.07   2.87
# 2021-11-20   500.00      2.97       0.00  0.07   2.97
# 2021-12-20   500.00      2.87       0.00  0.07   2.87
# 2022-01-20   444.04      2.97      55.96  0.07  58.93
# 2022-02-20   387.74      2.63      56.30  0.07  58.93
# 2022-03-20   330.89      2.08      56.85  0.07  58.93
# 2022-04-20   273.92      1.96      56.97  0.07  58.93
# 2022-05-20   216.56      1.57      57.36  0.07  58.93
# 2022-06-20   158.91      1.28      57.65  0.07  58.93
# 2022-07-20   100.89      0.91      58.02  0.07  58.93
# 2022-08-20    42.55      0.59      58.34  0.07  58.93
# 2022-09-20     0.00      0.25      42.55  0.07  42.80
#
#                                                          memo
# date
# 2021-07-26                          <PayInt:["A1"],Just 0.00>
# 2021-08-20                          <PayInt:["A1"],Just 0.00>
# 2021-09-20                          <PayInt:["A1"],Just 0.00>
# 2021-10-20                          <PayInt:["A1"],Just 0.00>
# 2021-11-20                          <PayInt:["A1"],Just 0.00>
# 2021-12-20                          <PayInt:["A1"],Just 0.00>
# 2022-01-20  [<PayInt:["A1"],Just 0.00>, <PayPrin:["A1"],Ju...
# 2022-02-20  [<PayInt:["A1"],Just 0.00>, <PayPrin:["A1"],Ju...
# 2022-03-20  [<PayInt:["A1"],Just 0.00>, <PayPrin:["A1"],Ju...
# 2022-04-20  [<PayInt:["A1"],Just 0.00>, <PayPrin:["A1"],Ju...
# 2022-05-20  [<PayInt:["A1"],Just 0.00>, <PayPrin:["A1"],Ju...
# 2022-06-20  [<PayInt:["A1"],Just 0.00>, <PayPrin:["A1"],Ju...
# 2022-07-20  [<PayInt:["A1"],Just 0.00>, <PayPrin:["A1"],Ju...
# 2022-08-20  [<PayInt:["A1"],Just 0.00>, <PayPrin:["A1"],Ju...
# 2022-09-20  [<PayInt:["A1"],Just 0.00>, <PayPrin:["A1"],Ju...
