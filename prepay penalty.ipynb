# %%
# %load_ext autoreload
# %autoreload 2

# %%
from absbox.local.china import SPV
from absbox import API
localAPI = API("http://localhost:8081",lang='english',check=False)


assets = [
        ["Mortgage"
          ,{"originBalance": 12000.0
            ,"originRate": ["fix",0.045]
            ,"originTerm": 36
            ,"freq": "Monthly"
            ,"type": "Level"
            ,"originDate": "2021-02-01"
            ,"prepayPenalty":{"stepDown":[(15,0.1),(5,0.05)]}
           }
          ,{"currentBalance": 10000.0
            ,"currentRate": 0.075
            ,"remainTerm": 24
            ,"status": "Current"}]
] 

(flow,st,p) = localAPI.runAsset("2021-04-01"
                              ,assets
                              ,poolAssump=("Pool"
                                            ,("Mortgage"
                                             ,None ,{"CPR":0.1}, None, None)
                                             ,None
                                             ,None)
                              ,read=True)
flow[["Prepayment","PrepayPenalty"]]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✅Connected, local lib:0.20.2, server:0.21.13
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             Prepayment  PrepayPenalty
# Date
# 2022-03-01       80.49           8.04
# 2022-04-01       84.94           8.49
# 2022-05-01       78.17           7.81
# 2022-06-01       76.66           3.83
# 2022-07-01       70.25           3.51
# 2022-08-01       68.57           3.42
# 2022-09-01       64.58           3.22
# 2022-10-01       58.68           2.93
# 2022-11-01       56.75           0.00
# 2022-12-01       51.19           0.00
# 2023-01-01       49.09           0.00
# 2023-02-01       45.31           0.00
# 2023-03-01       37.57           0.00
# 2023-04-01       37.93           0.00
# 2023-05-01       33.17           0.00
# 2023-06-01       30.68           0.00
# 2023-07-01       26.24           0.00
# 2023-08-01       23.59           0.00
# 2023-09-01       20.10           0.00
# 2023-10-01       16.12           0.00
# 2023-11-01       13.25           0.00
# 2023-12-01        9.56           0.00
# 2024-01-01        6.55           0.00
# 2024-02-01        3.25           0.00
