# %%
from absbox import API,save
from absbox.local.china import 信贷ABS,show,SPV
from absbox.local.util import *
from absbox.local.component import *
import pickle,os
import numpy as np
import pandas as pd 

#localAPI = API("http://localhost:8081")
remoteAPI = API("https://absbox.org/api/dev")
#dbox  = API("http://192.168.10.12:5000")
#init_jupyter()

# %%
test01 = SPV(
    "TEST01" 
    ,{"封包日":"2021-03-01","起息日":"2021-06-15","首次兑付日":"2021-07-26"
     ,"法定到期日":"2060-12-01","收款频率":"月末","付款频率":["每月",26]}  
    ,{'清单':[["按揭贷款"
        ,{"放款金额":120,"放款利率":["固定",0.045],"初始期限":30
          ,"频率":"每月","类型":"等额本金","放款日":"2021-02-01"}
          ,{"当前余额":120
          ,"当前利率":0.08
          ,"剩余期限":20
          ,"状态":"正常"}]]}
    ,(("账户01",{"余额":100
                ,"计息":{"周期":"月末"
                        ,"利率":0.03
                        ,"最近结息日":"2021-06-15"}})
    ,("账户02",{"余额":2000
                ,"计息":{"周期":"月末"
                        ,"利率":"LPR5Y"
                        ,"利差":0.01
                        ,"最近结息日":"2021-06-15"}}))
    ,(("A1",{"当前余额":100
             ,"当前利率":0.07
             ,"初始余额":100
             ,"初始利率":0.07
             ,"起息日":"2020-01-03"
             ,"利率":{"固定":0.08}
             ,"债券类型":{"过手摊还":None}})
      ,("B",{"当前余额":20
             ,"当前利率":0.0
             ,"初始余额":100
             ,"初始利率":0.07
             ,"起息日":"2020-01-03"
             ,"利率":{"固定":0.00}
             ,"债券类型":{"权益":None}
             }))
    ,(("信托费用",{"类型":{"自定义":[("2021-09-26",5)
                                 ,("2021-11-26",4)]}}),)
    ,{"未违约":[
         ["支付费用",["账户01"],['信托费用']]
         ,["支付利息","账户01",["A1"]]
         ,["支付本金","账户01",["A1"]]
         ,["支付本金","账户01",["B"]]
         ,["支付收益","账户01","B"]
     ]}
    ,(["利息回款","账户01"]
      ,["本金回款","账户01"]
      ,["早偿回款","账户01"]
      ,["回收回款","账户01"])
    ,None
    ,None
    ,None
)



myAssump = [
    {"利率":["LPR5Y",["2020-01-01",0.05]]}
    ,{"利率":["LPR1Y",["2020-01-01",0.04]]}
]


r = remoteAPI.run(test01
             ,assumptions=myAssump
             ,read=True)

# %%
r['fees']['信托费用']
# Out:
#             余额  支付  剩余支付
# 日期
# 2021-07-26   0   0     0
# 2021-08-26   0   0     0
# 2021-09-26   0   0     0
# 2021-10-26   0   5     0
# 2021-11-26   0   0     0
# 2021-12-26   0   4     0
# 2022-01-26   0   0     0
# 2022-02-26   0   0     0
# 2022-03-26   0   0     0
# 2022-04-26   0   0     0
# 2022-05-26   0   0     0
# 2022-06-26   0   0     0
# 2022-07-26   0   0     0
# 2022-08-26   0   0     0
# 2022-09-26   0   0     0
# 2022-10-26   0   0     0
# 2022-11-26   0   0     0
# 2022-12-26   0   0     0
# 2023-01-26   0   0     0
# 2023-02-26   0   0     0
# 2023-03-26   0   0     0
# 2023-04-26   0   0     0
# 2023-05-26   0   0     0
# 2023-06-26   0   0     0
# 2023-07-26   0   0     0
# 2023-08-26   0   0     0
# 2023-09-26   0   0     0
# 2023-10-26   0   0     0
# 2023-11-26   0   0     0
# 2023-12-26   0   0     0
# 2024-01-26   0   0     0
# 2024-02-26   0   0     0
# 2024-03-26   0   0     0
# 2024-04-26   0   0     0
# 2024-05-26   0   0     0
# ...

# %% [markdown]
# ### Save Benchmark

# %% [markdown]
# #### Save Deal

# %%
folder = r"/home/xiaoyu/IdeaProjects/PyABS/absbox/tests/benchmark/china"

# %%
output_deal = os.path.join(folder, "test07.obj")
save(d,output_deal )

# %% [markdown]
# #### Save Assumption

# %%
output_assump = os.path.join(folder, "empty_assumption.obj")
with open(output_assump,'wb') as _f:
    pickle.dump(a, _f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 output_assump = os.path.join(folder, "empty_assumption.obj")
#       2 with open(output_assump,'wb') as _f:
#       3     pickle.dump(a, _f)
#
# NameError: name 'os' is not defined

# %% [markdown]
# #### Save Output

# %%
overview_cf.to_pickle(os.path.join(folder,"test07_cf.obj"))

# %% [markdown]
# ### Read Benchmark

# %%
def read_bench(_api,_f,_d,_a):
    _deal = os.path.join(folder, _d)
    with open(_deal,'rb') as di:
        _d = pickle.load(di)
    _assump = os.path.join(folder, _a)
    with open(_assump,'rb') as ai:
        _a = pickle.load(ai)    
    _r = _api.run(_d,assumptions=_a,read=True)
    #_overview_cf = show(r)
    return _r
#remoteAPI
#localAPI
bench_r = read_bench(localAPI,folder,"test01.obj","empty_assumption.obj")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [11], line 13
#      10     return _r
#      11 #remoteAPI
#      12 #localAPI
# ---> 13 bench_r = read_bench(localAPI,folder,"test01.obj","empty_assumption.obj")
#
# Cell In [11], line 8, in read_bench(_api, _f, _d, _a)
#       6 with open(_assump,'rb') as ai:
#       7     _a = pickle.load(ai)
# ----> 8 _r = _api.run(_d,assumptions=_a,read=True)
#       9 #_overview_cf = show(r)
#      10 return _r
#
# File ~/IdeaProjects/PyABS/absbox/client.py:162, in API.run(self, deal, assumptions, pricing, custom_endpoint, read, position, timing)
#     158         c = _f.read()
#     159         deal = pickle.loads(c)
# --> 162 req = self.build_req(deal,assumptions,pricing)
#     164 #validate deal
#     165 deal_validate,err,warn = self.validate(req)
#
# ...

# %%
bench_r['fees']['信托费用']
# Out:
#             余额   支付  剩余支付
# 日期
# 2021-08-26   0 0.47     0
# 2021-09-26   0  0.2     0
# 2021-10-26   0 0.16     0
# 2021-11-26   0 0.16     0
# 2021-12-26   0 0.15     0
# 2022-01-26   0 0.14     0
# 2022-02-26   0 0.14     0
# 2022-03-26   0 0.12     0
# 2022-04-26   0 0.12     0
# 2022-05-26   0 0.11     0
# 2022-06-26   0 0.11     0
# 2022-07-26   0  0.1     0
# 2022-08-26   0  0.1     0
# 2022-09-26   0 0.09     0
# 2022-10-26   0 0.08     0
# 2022-11-26   0 0.08     0
# 2022-12-26   0 0.07     0
# 2023-01-26   0 0.06     0
# 2023-02-26   0 0.06     0
# 2023-03-26   0 0.04     0
# 2023-04-26   0 0.04     0
# 2023-05-26   0 0.03     0
# 2023-06-26   0 0.03     0
# 2023-07-26   0 0.02     0
# 2023-08-26   0 0.01     0
# 2023-09-26   0  0.0     0

# %%
bench_r = read_bench(localAPI,folder,"test05.obj","empty_assumption.obj")
bench_r['fees']['信托费用']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 bench_r = read_bench(localAPI,folder,"test05.obj","empty_assumption.obj")
#       2 bench_r['fees']['信托费用']
#
# NameError: name 'read_bench' is not defined

# %% [markdown]
# ### Coin a Scenario

# %%
def coin(f,d,a,r,dn,an,rn):

    output_deal = os.path.join(f, dn+".obj")
    save(d,output_deal)    

    output_assump = os.path.join(f, f"{an}.obj")
    with open(output_assump,'wb') as _f:
        pickle.dump(a, _f)
    
    r.to_pickle(os.path.join(f,f"{rn}.obj"))
    
    #save to csv

# %% [markdown]
# ### Regression

# %%
from absbox.tests import test_cn_regression

# %%
test_cn_regression.regression_on("http://localhost:8081",r"/home/xiaoyu/IdeaProjects/PyABS/absbox/tests/benchmark/china/regression.csv")
# Out:
# Testing deal TEST01
# Testing deal TEST01
# Testing deal Pct Fee on Pool Issuance Balance
# Testing deal Pct Fee on Pool Issuance Balance
# Testing deal Pct Fee on Bond Balance
# Testing deal Custom Pay Dates
# Testing deal Bank Account Interest
# []

# %%
test_cn_regression.regression_on("https://deal-bench.xyz/api",r"/home/xiaoyu/IdeaProjects/PyABS/absbox/tests/benchmark/china/regression.csv")
# Out:
# Testing deal TEST01
# Testing deal TEST01
# Testing deal Pct Fee on Pool Issuance Balance
# Testing deal Pct Fee on Pool Issuance Balance
# Testing deal Pct Fee on Bond Balance
# Testing deal Custom Pay Dates
# Testing deal Bank Account Interest
# []

# %%
match {"A":1,"B":2}:
    case {"A":a,**b}:
        print(b)
# Out:
# {'B': 2}
