# %%
import pandas as pd
pd.set_option("display.max_row", None)
# %load_ext autoreload
# %autoreload 2

# %%
myAsset = ["Mortgage"
  ,{"originBalance": 12000.0
    ,"originRate": ["fix",0.045]
    ,"originTerm": 12
    ,"freq": "Monthly"
    ,"type": ("NO_FirstN",6,"Level")
    ,"originDate": "2021-02-01"}
  ,{"currentBalance": 10000.0
    ,"currentRate": 0.075
    ,"remainTerm": 12
    ,"status": "Current"}]

# %%
from absbox import API
api = localAPI = API("http://localhost:8081", lang="english")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✅Connected, local lib:0.25.0, server:0.25.0

# %%
(cf,_,_) = api.runAsset("2020-08-02"
             ,[myAsset]
             ,poolAssump=("Pool",("Mortgage",{'CDR':0.01},None,None,None)
                                ,None
                                ,None)
             ,read=True)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
cf
# Out:
#              Balance  Principal  Interest  Prepayment  Default  Recovery  \
# Date
# 2021-02-01  10000.00       0.00      0.00           0     0.00         0
# 2021-03-01  10054.75     -62.45      0.00           0     7.70         0
# 2021-04-01  10108.96     -62.78      0.00           0     8.57         0
# 2021-05-01  10163.74     -63.12      0.00           0     8.34         0
# 2021-06-01  10218.53     -63.46      0.00           0     8.67         0
# 2021-07-01  10273.91     -63.81      0.00           0     8.43         0
# 2021-08-01  10329.30     -64.15      0.00           0     8.76         0
# 2021-09-01   8627.09    1693.40     64.50           0     8.81         0
# 2021-10-01   6917.39    1702.58     53.87           0     7.12         0
# 2021-11-01   5199.73    1711.76     43.19           0     5.90         0
# 2021-12-01   3474.41    1721.03     32.47           0     4.29         0
# 2022-01-01   1741.13    1730.32     21.69           0     2.96         0
# 2022-02-01      0.00    1739.65     10.87           0     1.48         0
#
#             Loss    WAC BorrowerNum PrepayPenalty  CumPrincipal  CumPrepay  \
# Date
# 2021-02-01  0.00  0.075        None          None          0.00          0
# 2021-03-01  7.70  0.075        None          None        -62.45          0
# 2021-04-01  8.57  0.075        None          None       -125.23          0
# 2021-05-01  8.34  0.075        None          None       -188.35          0
# 2021-06-01  8.67  0.075        None          None       -251.81          0
# 2021-07-01  8.43  0.075        None          None       -315.62          0
# 2021-08-01  8.76  0.075        None          None       -379.77          0
# 2021-09-01  8.81  0.075        None          None       1313.63          0
# 2021-10-01  7.12  0.075        None          None       3016.21          0
# 2021-11-01  5.90  0.075        None          None       4727.97          0
# 2021-12-01  4.29  0.075        None          None       6449.00          0
# 2022-01-01  2.96  0.075        None          None       8179.32          0
# 2022-02-01  1.48  0.075        None          None       9918.97          0
#
#             CumDelinq  CumDefault  CumRecovery  CumLoss
# Date
# 2021-02-01          0        0.00            0     0.00
# 2021-03-01          0        7.70            0     7.70
# 2021-04-01          0       16.27            0    16.27
# 2021-05-01          0       24.61            0    24.61
# 2021-06-01          0       33.28            0    33.28
# 2021-07-01          0       41.71            0    41.71
# 2021-08-01          0       50.47            0    50.47
# 2021-09-01          0       59.28            0    59.28
# 2021-10-01          0       66.40            0    66.40
# 2021-11-01          0       72.30            0    72.30
# 2021-12-01          0       76.59            0    76.59
# 2022-01-01          0       79.55            0    79.55
# 2022-02-01          0       81.03            0    81.03
