                 ['2027-04-30', 348594182.05, 21310218.04, 2479263.62],
                 ['2027-05-31', 327244689.26, 21349492.79, 2340456.3],
                 ['2027-06-30', 305830769.51, 21413919.75, 2201186.66],
                 ['2027-07-31', 284585774.4, 21244995.11, 2061327.89],
                 ['2027-08-31', 263519016.9, 21066757.5, 1922073.93],
                 ['2027-09-30', 242575459.03, 20943557.87, 1783472.9],
                 ['2027-10-31', 221781213.69, 20794245.34, 1645233.74],
                 ['2027-11-30', 201171499.97, 20609713.72, 1507585.84],
                 ['2027-12-31', 180747983.19, 20423516.78, 1370616.83],
                 ['2028-01-31', 160561088.11, 20186895.08, 1234388.59],
                 ['2028-02-29', 140724833.16, 19836254.95, 1099179.68],
                 ['2028-03-31', 121213369.35, 19511463.81, 965743.33],
                 ['2028-04-30', 101995882.61, 19217486.74, 833929.46],
                 ['2028-05-31', 82989176.72, 19006705.89, 703883.48],
                 ['2028-06-30', 65440307.0, 17548869.73, 575036.48],
                 ['2028-07-31', 49586000.75, 15854306.25, 455181.32],
                 ['2028-08-31', 35564284.98, 14021715.77, 345896.15],
                 ['2028-09-30', 23542969.76, 12021315.21, 248781.42],
                 ['2028-10-31', 13738235.28, 9804734.48, 165336.02],
                 ['2028-11-30', 6197524.38, 7540710.9, 97000.92],
                 ['2028-12-31', 1629196.25, 4568328.13, 44184.74],
                 ['2029-01-31', 0.0, 1629196.25, 11802.14]]
     }
    ,(("信托收付账户",{"余额":0 ,"计息":{"周期":["平移","季度末",-10]
                                     ,"利率":0.01
                                     ,"最近结息日":"2024-07-11"}})
      ,("优先支付账户",{"余额":0 })
      ,("流动性储备",{"余额":41_499_935.09
                    ,"类型":{"目标储备金额":[("资产池余额",),0.01]}
                    ,"计息":{"周期":["平移","季度末",-10] 
                            ,"利率":0.01
                            ,"最近结息日":"2024-07-11"}}))
    ,(("优先",{"当前余额":3_720_000_000.00
             ,"当前利率":0.0225
             ,"初始余额":3_720_000_000.00
             ,"初始利率":0.0225
             ,"起息日":"2024-07-11"
             ,"利率":{"固定":0.0225,"日历":"DC_30_360_US"}
             ,"债券类型":{"Sequential":None}})
      ,("次级",{"当前余额":210_000_000.00
             ,"当前利率":0.0
             ,"初始余额":210_000_000.00
             ,"初始利率":0.0
             ,"起息日":"2024-07-11"
             ,"利率":{"固定":0.00}
             ,"债券类型":{"权益":None}
             })
     )
    ,(("增值税",{"类型":{"差额费用":[("factor"
                                   ,("资产池累计","利息"),0.0326)
                                   ,("费用支付总额",None,"增值税")]}})
      ,("服务商费用",{"类型":{"年化费率":[("资产池余额",),0.0005]}})
      ,("兑付手续费",{"类型":{"差额费用":[("factor"
                                       ,("债券支付总额",None,"优先","次级"),0.00005)
                                       ,("费用支付总额",None,"兑付手续费")]}})
      ,("评级跟踪费用",{"类型":{"周期费用":[["每年",6,30],100000]}})
      ,("报销",{"类型":{"自定义":[]}})
     )
    ,{"未违约":[
         ["账户转移","流动性储备","信托收付账户"]
         ,["支付费用","信托收付账户",["增值税"]] 
         ,["支付费用","信托收付账户",["服务商费用"]]
         ,["支付费用","信托收付账户",["评级跟踪费用"]] 
         ,["计提支付费用","信托收付账户",["兑付手续费"]]
         ,["计提费用","报销"]
         ,["支付费用","信托收付账户",["报销"],{"应计费用上限":150_000}]         
#
         ,["计提支付利息","信托收付账户",["优先"]]
         ,["账户转移","信托收付账户","优先支付账户"
           ,{"公式":("floorWithZero"
                   ,("差额",("债券余额","优先"),("资产池余额",)))}]
         ,["支付本金","优先支付账户",["优先"]]
         ,["账户转移","信托收付账户","流动性储备",{"储备":"缺口"}] 
         ,["支付本金","信托收付账户",["优先"]]
         ,["支付费用","信托收付账户",["报销"]]
         ,["支付本金","信托收付账户",["次级"]]
         ,["支付收益","信托收付账户","次级"]
         ,["支付费用","信托收付账户",["报销"]]

      ]
     ,"回款后":[["计提费用","服务商费用","增值税"]]
     ,"清仓回购":[
                 ["出售资产",["正常|违约",1.0,0.0],"信托收付账户"]
                 ,["账户转移","流动性储备","信托收付账户"]
                 ,["支付费用","信托收付账户",["服务商费用","兑付手续费","增值税"]]
                 ,["计提支付利息","信托收付账户",["优先"]]
                 ,["支付本金","信托收付账户",["优先"]]
                 ,["支付本金","信托收付账户",["次级"]]
                 ,["支付收益","信托收付账户","次级"]
                 ]}
    ,(["利息回款","信托收付账户"]
      ,["本金回款","信托收付账户"]
      ,["早偿回款","信托收付账户"]
      ,["回收回款","信托收付账户"])
    ,None
    ,None
    ,None
    ,None
    ,("PreClosing","Amortizing")
)

# %%
from absbox import API,mkDeal,EnginePath
localAPI = API(EnginePath.LOCAL,check=False)

r = localAPI.run(FY_AUTO_2024_1
                 ,poolAssump = ("Pool"
                                ,("Mortgage"
                                 ,None,None, None, None)
                                 ,None
                                 ,None)
                 ,runAssump = [("call", ("if", [("poolFactor",),"<=",0.1])) ]
                 ,read=True)
# Out:
# Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.28.7, server:0.28.19
# Warning Message from server:

# %%
r['bonds']['优先']
# Out:
#                  balance     interest     principal    rate          cash  \
# date
# 2024-08-26  3.179447e+09  10462500.00  5.405534e+08  0.0225  5.510159e+08
# 2024-09-26  3.001115e+09   5961462.44  1.783313e+08  0.0225  1.842927e+08
# 2024-10-26  2.823181e+09   5627091.34  1.779346e+08  0.0225  1.835617e+08
# 2024-11-26  2.644908e+09   5293463.92  1.782731e+08  0.0225  1.835665e+08
# 2024-12-26  2.465803e+09   4959201.95  1.791044e+08  0.0225  1.840636e+08
# 2025-01-26  2.286841e+09   4623381.12  1.789622e+08  0.0225  1.835856e+08
# 2025-02-26  2.111439e+09   4287827.01  1.754021e+08  0.0225  1.796899e+08
# 2025-03-26  1.938605e+09   3958948.11  1.728339e+08  0.0225  1.767928e+08
# 2025-04-26  1.767786e+09   3634884.64  1.708190e+08  0.0225  1.744539e+08
# 2025-05-26  1.599016e+09   3314599.08  1.687705e+08  0.0225  1.720851e+08
# 2025-06-26  1.431778e+09   2998154.40  1.672372e+08  0.0225  1.702354e+08
# 2025-07-26  1.266985e+09   2684584.65  1.647938e+08  0.0225  1.674784e+08
# ...

# %%
r['result']['status']
# Out:
#            日期      旧状态       新状态
# 0  2024-07-11       设计        摊销
# 1  2027-02-26       摊销      清仓回购
# 2  2027-02-26  DealEnd  Clean Up

# %%
import numpy as np
from pyesg import NelsonSiegelInterpolator, SvenssonInterpolator

# 2024-07-02
y = [ _/100 for _ in [1.3913,1.4325,1.4425,1.5137,1.5429,1.6505,1.7998]]
X = np.array([0.083, 0.25, 0.5,0.75, 1, 2, 3])

# %%
import pyesg
nelson_siegel = pyesg.NelsonSiegelInterpolator()
nelson_siegel.fit(X, y)

# %%
from datetime import date, timedelta
import pandas as pd

numOfMonths = 36
# difference between current and previous date
ds = (pd.date_range(start=pd.Timestamp("2024-08-26")
                    , periods=numOfMonths, freq='MS') + pd.Timedelta(days=25)).strftime('%Y-%m-%d').to_list()
ds[:5]
# Out:
# ['2024-09-26', '2024-10-26', '2024-11-26', '2024-12-26', '2025-01-26']

# %%
rates = nelson_siegel.predict(np.arange(0.001, numOfMonths/12, 1/12))
rates[:5]
# Out:
# array([0.01386598, 0.01399127, 0.0141158 , 0.0142396 , 0.01436266])

# %%
pvCurve = {"date":"2024-07-11","curve":[ [x,y] for x,y in zip(ds,rates)]}

# %%
r = localAPI.run(FY_AUTO_2024_1
                 ,poolAssump = ("Pool"
                                ,("Mortgage"
                                 ,None,None, None, None)
                                 ,None
                                 ,None)
                 ,runAssump = [("call", ("if", [("poolFactor",),"<=",0.1]))
                               ,("pricing",pvCurve)]
                 ,read=True)

r['pricing']['summary'].loc["优先"][["票面估值"]].values[0]
# Out:
# 100.66672

# %%
possibleSeniorRates = [ x / 10000 for x in range(200,230,1)]
possibleSeniorMap = {str(x):x for x in possibleSeniorRates }
possibleSeniorMap.keys()
# Out:
# dict_keys(['0.02', '0.0201', '0.0202', '0.0203', '0.0204', '0.0205', '0.0206', '0.0207', '0.0208', '0.0209', '0.021', '0.0211', '0.0212', '0.0213', '0.0214', '0.0215', '0.0216', '0.0217', '0.0218', '0.0219', '0.022', '0.0221', '0.0222', '0.0223', '0.0224', '0.0225', '0.0226', '0.0227', '0.0228', '0.0229'])

# %%
from lenses import lens

possibleSeniorScenario = {k: FY_AUTO_2024_1 & lens.债券[0][1].Fork(lens["当前利率"],lens["初始利率"],lens["利率"]['固定']).set(v) 
                          for k,v in possibleSeniorMap.items()}

# %%
rs = localAPI.runStructs(possibleSeniorScenario
                     ,poolAssump = ("Pool"
                                    ,("Mortgage"
                                     ,None ,None, None, None)
                                     ,None
                                     ,None)
                     ,nonPoolAssump = [("call", ("if", [("poolFactor",),"<=",0.1]))
                                   ,("pricing",pvCurve)]
                     ,read=True)

# %%
{k: v['pricing']['summary'].loc["优先"][["票面估值"]].values[0] for k,v in rs.items() }
# Out:
# {'0.02': 100.451633,
#  '0.0201': 100.460203,
#  '0.0202': 100.468776,
#  '0.0203': 100.477352,
#  '0.0204': 100.48593,
#  '0.0205': 100.494511,
#  '0.0206': 100.503095,
#  '0.0207': 100.511682,
#  '0.0208': 100.520272,
#  '0.0209': 100.528864,
#  '0.021': 100.537459,
#  '0.0211': 100.546057,
#  '0.0212': 100.554658,
#  '0.0213': 100.563261,
#  '0.0214': 100.571868,
#  '0.0215': 100.580477,
#  '0.0216': 100.589089,
#  '0.0217': 100.597703,
#  '0.0218': 100.606321,
#  '0.0219': 100.614941,
#  '0.022': 100.623564,
#  '0.0221': 100.632189,
#  '0.0222': 100.640818,
#  '0.0223': 100.649449,
#  '0.0224': 100.658084,
#  '0.0225': 100.66672,
#  '0.0226': 100.67536,
#  '0.0227': 100.684003,
#  '0.0228': 100.692648,
#  '0.0229': 100.701296}

# %%
shiftedPvCurve = pvCurve & lens["curve"].Each()[1].modify(lambda x:x+0.006)

# %%
rs2 = localAPI.runStructs(possibleSeniorScenario
                     ,poolAssump = ("Pool"
                                    ,("Mortgage"
                                     ,{"CDR":0.005} ,None, None, None)
                                     ,None
                                     ,None)
                     ,nonPoolAssump = [("call", ("if", [("poolFactor",),"<=",0.1]))
                                   ,("pricing",shiftedPvCurve)]
                     ,read=True)

{k: v['pricing']['summary'].loc["优先"][["票面估值"]].values[0] for k,v in rs2.items() }
# Out:
# {'0.02': 99.963162,
#  '0.0201': 99.971668,
#  '0.0202': 99.980177,
#  '0.0203': 99.988688,
#  '0.0204': 99.997202,
#  '0.0205': 100.005719,
#  '0.0206': 100.014239,
#  '0.0207': 100.022761,
#  '0.0208': 100.031286,
#  '0.0209': 100.039814,
#  '0.021': 100.048345,
#  '0.0211': 100.056878,
#  '0.0212': 100.065414,
#  '0.0213': 100.073953,
#  '0.0214': 100.082495,
#  '0.0215': 100.091039,
#  '0.0216': 100.099587,
#  '0.0217': 100.108136,
#  '0.0218': 100.116689,
#  '0.0219': 100.125245,
#  '0.022': 100.133803,
#  '0.0221': 100.142364,
#  '0.0222': 100.150927,
#  '0.0223': 100.159494,
#  '0.0224': 100.168063,
#  '0.0225': 100.176635,
#  '0.0226': 100.18521,
#  '0.0227': 100.193787,
#  '0.0228': 100.202368,
#  '0.0229': 100.210951}
