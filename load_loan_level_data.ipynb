# %%
from absbox.local.generic import Generic

# %%
test01 = Generic(
    "TEST01"
    ,{"cutoff":"2021-03-01","closing":"2021-06-15","firstPay":"2021-07-26"
     ,"payFreq":["DayOfMonth",20],"poolFreq":"MonthEnd","stated":"2030-01-01"}
    ,{'assets':[["Mortgage"
        ,{"originBalance":2200,"originRate":["fix",0.045],"originTerm":30
          ,"freq":"Monthly","type":"Level","originDate":"2021-02-01"}
          ,{"currentBalance":2200
          ,"currentRate":0.08
          ,"remainTerm":20
          ,"status":"current"}]]}
    ,(("acc01",{"balance":0}),)
    ,(("A1",{"balance":1000
             ,"rate":0.07
             ,"originBalance":1000
             ,"originRate":0.07
             ,"startDate":"2020-01-03"
             ,"rateType":{"Fixed":0.08}
             ,"bondType":{"Sequential":None}})
      ,("B",{"balance":1000
             ,"rate":0.0
             ,"originBalance":1000
             ,"originRate":0.07
             ,"startDate":"2020-01-03"
             ,"rateType":{"Fixed":0.00}
             ,"bondType":{"Equity":None}
             }))
    ,(("trusteeFee",{"type":{"fixFee":30}}),)
    ,{"amortizing":[
         ["payFee",["acc01"],['trusteeFee']]
         ,["payInt","acc01",["A1"]]
         ,["payPrin","acc01",["A1"]]
         ,["payPrin","acc01",["B"]]
         ,["payResidual","acc01","B"]
     ]}
    ,[["CollectedInterest","acc01"]
      ,["CollectedPrincipal","acc01"]
      ,["CollectedPrepayment","acc01"]
      ,["CollectedRecoveries","acc01"]]
    ,None
    ,None)

# %%
from absbox import API
localAPI = API("https://absbox.org/api/latest")

# %%
import pandas as pd

loan_tape = pd.read_csv("~/Downloads/U90133_3132H3EE9_COLLAT_CURRENT.txt",sep="|",dtype={'First Payment Date':str})

# %%
loan_tape.columns.to_list()
# Out:
# ['Loan Identifier',
#  'Loan Correction Indicator',
#  'Prefix',
#  'Security Identifier',
#  'CUSIP',
#  'Mortgage Loan Amount',
#  'Issuance Investor Loan UPB',
#  'Current Investor Loan UPB',
#  'Amortization Type',
#  'Original Interest Rate',
#  'Issuance Interest Rate',
#  'Current Interest Rate',
#  'Issuance Net Interest Rate',
#  'Current Net Interest Rate',
#  'First Payment Date',
#  'Maturity Date',
#  'Loan Term',
#  'Remaining Months to Maturity',
#  'Loan Age',
#  'Loan-To-Value (LTV)',
#  'Combined Loan-To-Value (CLTV)',
#  'Debt-To-Income (DTI)',
#  'Borrower Credit Score',
#  'Filler',
#  'Filler.1',
#  'Filler.2',
#  'Number of Borrowers',
#  'First Time Home Buyer Indicator',
#  'Loan Purpose',
#  'Occupancy Status',
#  'Number of Units',
#  'Property Type',
#  'Channel',
#  'Property State',
#  'Seller Name',
#  'Servicer Name',
#  'Mortgage Insurance Percent',
#  'Mortgage Insurance Cancellation Indicator',
#  'Government Insured Guarantee',
#  'Assumability Indicator',
#  'Interest Only Loan Indicator',
#  'Interest Only First Principal and Interest Payment Date',
#  'Months to Amortization',
#  'Prepayment Penalty Indicator',
#  'Prepayment Penalty Total Term',
#  'Index',
#  'Mortgage Margin',
#  'MBS PC Margin',
#  'Interest Rate Adjustment Frequency',
#  'Interest Rate Lookback',
#  'Interest Rate Rounding Method',
#  'Interest Rate Rounding Method Percent',
#  'Convertibility Indicator',
#  'Initial Fixed Rate Period',
#  'Next Interest Rate Adjustment Date',
#  'Months to Next Interest Rate Adjustment Date',
#  'Life Ceiling Interest Rate',
#  'Life Ceiling Net Interest Rate',
#  'Life Floor Interest Rate',
#  'Life Floor Net Interest Rate',
#  'Initial Interest Rate Cap Up Percent',
#  'Initial Interest Rate Cap Down Percent',
#  'Periodic Interest Rate Cap Up Percent',
#  'Periodic Interest Rate Cap Down Percent',
#  'Modification Program',
#  'Modification Type',
#  'Number of Modifications',
#  'Total Capitalized Amount',
#  'Interest Bearing Mortgage Loan Amount',
#  'Original Deferred Amount',
#  'Current Deferred UPB',
#  'Loan Age As Of Modification',
#  'Estimated Loan-To-Value (ELTV)',
#  'Updated Credit Score',
#  'Filler.3',
#  'Interest Rate Step Indicator',
#  'Initial Step Fixed-Rate Period',
#  'Total Number of Steps',
#  'Number of Remaining Steps',
#  'Next Step Rate',
#  'Terminal Step Rate',
#  'Terminal Step Date',
#  'Step Rate Adjustment Frequency',
#  'Next Step Rate Adjustment Date',
#  'Months to Next Step Rate Adjustment Date',
#  'Periodic Step Cap Up Percent',
#  'Origination Mortgage Loan Amount',
#  'Origination Interest Rate',
#  'Origination Amortization Type',
#  'Origination Interest Only Loan Indicator',
#  'Origination First Payment Date',
#  'Origination Maturity Date',
#  'Origination Loan Term',
#  'Origination Loan-To-Value (LTV)',
#  'Origination Combined Loan-To-Value (CLTV)',
#  'Origination Debt-To-Income Ratio',
#  'Origination Credit Score',
#  'Filler.4',
#  'Filler.5',
#  'Filler.6',
#  'Origination Loan Purpose',
#  'Origination Occupancy Status',
#  'Origination Channel',
#  'Days Delinquent',
#  'Loan Performance History',
#  'Loan Participation Percent',
#  'Property Valuation Method',
#  'Alternative Delinquency Resolution',
#  'Number of Alternative Delinquency Resolutions',
#  'Total Deferral Amount',
#  'Borrower Assistance Plan',
#  'Seller City',
#  'Seller State',
#  'Servicer City',
#  'Servicer State',
#  'Special Eligibility Program']

# %%
loan_tape[loan_tape['Days Delinquent']!="Current"]['Days Delinquent']
# Out:
# 60     150-179
# 117     90-119
# 135      30-59
# 193      30-59
# Name: Days Delinquent, dtype: object

# %%
d = loan_tape[['Mortgage Loan Amount','Current Investor Loan UPB','Amortization Type','Original Interest Rate','First Payment Date','Loan Term','Remaining Months to Maturity','Index', 'Origination Mortgage Loan Amount','Origination Interest Rate','Current Interest Rate','Origination Loan Term','Days Delinquent']]

# %%
d['First Payment Date']
# Out:
# 0      082012
# 1      082012
# 2      082012
# 3      082012
# 4      082012
#         ...
# 263    082012
# 264    082012
# 265    082012
# 266    082012
# 267    092012
# Name: First Payment Date, Length: 268, dtype: object

# %%
pd.DateOffset(months=1)
# Out:
# <DateOffset: months=1>

# %%
pd.to_datetime(d['First Payment Date'])
# Out:
# 0     2012-08-20
# 1     2012-08-20
# 2     2012-08-20
# 3     2012-08-20
# 4     2012-08-20
#          ...
# 263   2012-08-20
# 264   2012-08-20
# 265   2012-08-20
# 266   2012-08-20
# 267   2012-09-20
# Name: First Payment Date, Length: 268, dtype: datetime64[ns]

# %%
pd.to_datetime(d['First Payment Date']) - pd.DateOffset(months=1)
# Out:
# 0     2012-07-20
# 1     2012-07-20
# 2     2012-07-20
# 3     2012-07-20
# 4     2012-07-20
#          ...
# 263   2012-07-20
# 264   2012-07-20
# 265   2012-07-20
# 266   2012-07-20
# 267   2012-08-20
# Name: First Payment Date, Length: 268, dtype: datetime64[ns]

# %%
# use an intermedia dataframe to speed up via vectorize computation 
size_of_loan_tape = loan_tape.shape[0]

mapped_df = pd.DataFrame()
mapped_df['originBalance'] = d['Mortgage Loan Amount']
mapped_df['originRate'] = [["fix",_/100] for _ in d['Original Interest Rate'].to_list() ]
mapped_df['originTerm'] = d['Loan Term']
mapped_df['freq'] = "Monthly" 
mapped_df['type'] = "Level"
mapped_df['originDate'] = (pd.to_datetime(d['First Payment Date']) - pd.DateOffset(months=1)).map(lambda x: x.strftime("%Y-%m-%d"))
mapped_df['currentBalance'] = d['Current Investor Loan UPB']
mapped_df['currentRate'] = d['Current Interest Rate']/100
mapped_df['remainTerm'] = d['Remaining Months to Maturity']
mapped_df['status'] =  d['Days Delinquent'].map(lambda x: "Current" if x=='Current' else "Defaulted")

# %%
origin_fields = set(['originBalance', 'originRate', 'originTerm', 'freq', 'type', 'originDate'])
current_fields = set(['currentBalance', 'currentRate', 'remainTerm', 'status'])

mortgages = [ ["Mortgage"
    ,{k:v for k,v in x.items() if k in origin_fields}
    ,{k:v for k,v in x.items() if k in current_fields}]
    for x in  mapped_df.to_dict(orient="records") ]

# %%
mortgages
# Out:
# [['Mortgage',
#   {'originBalance': 127000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 98530.54,
#    'currentRate': 0.045,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 128000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 87959.84,
#    'currentRate': 0.045,
#    'remainTerm': 191,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 135000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 94164.6,
#    'currentRate': 0.045,
#    'remainTerm': 194,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 119000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 90510.21,
#    'currentRate': 0.04375,
#    'remainTerm': 224,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 219000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 123331.11,
#    'currentRate': 0.045,
#    'remainTerm': 145,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 308000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 237269.54,
#    'currentRate': 0.045,
#    'remainTerm': 226,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 150000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 117549.84,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 104000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 81278.93,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 102000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 79357.46,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 318000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 247085.92,
#    'currentRate': 0.045,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 233000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 58429.43,
#    'currentRate': 0.045,
#    'remainTerm': 55,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 245000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 190020.44,
#    'currentRate': 0.04375,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 326000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 253201.3,
#    'currentRate': 0.045,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 142000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 109580.53,
#    'currentRate': 0.0425,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 238000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 167711.78,
#    'currentRate': 0.0425,
#    'remainTerm': 201,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 285000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 221163.18,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 168000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 130932.14,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 108000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 81917.63,
#    'currentRate': 0.04375,
#    'remainTerm': 222,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 125000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 97454.46,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 231000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 175742.6,
#    'currentRate': 0.0425,
#    'remainTerm': 224,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 150000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 96773.89,
#    'currentRate': 0.04375,
#    'remainTerm': 176,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 284000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 220385.98,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 199000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 155545.76,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 194000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-06-20'},
#   {'currentBalance': 149282.68,
#    'currentRate': 0.0425,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 205000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 160582.03,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 372000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 290643.61,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 226000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 176816.84,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 187000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 146324.96,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 242000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 188137.78,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 258000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 199598.53,
#    'currentRate': 0.04375,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 263000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 206169.37,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 217000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 166778.23,
#    'currentRate': 0.04375,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 215000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 168500.55,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 149000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 116319.63,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 80000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 62727.87,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 101000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 73499.6,
#    'currentRate': 0.04375,
#    'remainTerm': 208,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 170000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 130790.03,
#    'currentRate': 0.04375,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 163000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 127761.69,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 309000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 239882.24,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 138000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 108222.92,
#    'currentRate': 0.045,
#    'remainTerm': 231,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 86000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 65762.54,
#    'currentRate': 0.045,
#    'remainTerm': 225,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 139000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 106830.82,
#    'currentRate': 0.04375,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 217000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 165148.07,
#    'currentRate': 0.04375,
#    'remainTerm': 223,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 137000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 107430.88,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 237000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 186129.86,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 94000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 71578.74,
#    'currentRate': 0.045,
#    'remainTerm': 224,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 266000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 209308.77,
#    'currentRate': 0.045,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 193000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 151665.37,
#    'currentRate': 0.045,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 139000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 105528.12,
#    'currentRate': 0.045,
#    'remainTerm': 221,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 245000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 300,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 170787.05,
#    'currentRate': 0.0425,
#    'remainTerm': 172,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 250000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 196398.33,
#    'currentRate': 0.045,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 234000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 183713.65,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 306000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 238723.31,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 77000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 59518.43,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 183000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 33552.5,
#    'currentRate': 0.04375,
#    'remainTerm': 40,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 155000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 87049.84,
#    'currentRate': 0.045,
#    'remainTerm': 144,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 159000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 123848.16,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 389000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 284356.53,
#    'currentRate': 0.04375,
#    'remainTerm': 210,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 216000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 169097.71,
#    'currentRate': 0.045,
#    'remainTerm': 231,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 125000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 50176.69,
#    'currentRate': 0.04375,
#    'remainTerm': 96,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 306000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 238596.77,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Defaulted'}],
#  ['Mortgage',
#   {'originBalance': 333000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 261076.3,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 147000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 112625.64,
#    'currentRate': 0.04375,
#    'remainTerm': 225,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 173000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 134853.63,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 336000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 262201.16,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 231000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 179483.08,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 164000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 124202.67,
#    'currentRate': 0.04375,
#    'remainTerm': 222,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 118000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 300,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 59529.6,
#    'currentRate': 0.0425,
#    'remainTerm': 114,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 120000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 92358.59,
#    'currentRate': 0.045,
#    'remainTerm': 226,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 170000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 131477.38,
#    'currentRate': 0.04375,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 195000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 151720.24,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 152000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 300,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 105425.12,
#    'currentRate': 0.045,
#    'remainTerm': 170,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 279000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 208714.51,
#    'currentRate': 0.045,
#    'remainTerm': 216,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 86000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 67654.34,
#    'currentRate': 0.045,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 202000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 156797.06,
#    'currentRate': 0.045,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 176000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 137118.9,
#    'currentRate': 0.0425,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 344000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 237782.66,
#    'currentRate': 0.045,
#    'remainTerm': 192,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 201000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 157635.95,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 285000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 219445.12,
#    'currentRate': 0.0425,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 415000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 322185.64,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 153000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 120009.23,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 227000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 177760.68,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 124000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 94958.01,
#    'currentRate': 0.04375,
#    'remainTerm': 224,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 198000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 151971.08,
#    'currentRate': 0.045,
#    'remainTerm': 225,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 186000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 143183.42,
#    'currentRate': 0.0425,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 147000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 111006.82,
#    'currentRate': 0.04375,
#    'remainTerm': 222,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 200000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 156286.59,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 200000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 153651.12,
#    'currentRate': 0.045,
#    'remainTerm': 225,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 243000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 181981.67,
#    'currentRate': 0.04375,
#    'remainTerm': 218,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 218000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 158334.26,
#    'currentRate': 0.045,
#    'remainTerm': 207,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 180000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 140670.4,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 245000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 187970.4,
#    'currentRate': 0.045,
#    'remainTerm': 225,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 171000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 132492.55,
#    'currentRate': 0.045,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 151000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 83395.01,
#    'currentRate': 0.045,
#    'remainTerm': 141,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 202000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 155233.36,
#    'currentRate': 0.045,
#    'remainTerm': 224,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 246000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 192422.93,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 371000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 284545.5,
#    'currentRate': 0.0425,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 344000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 247075.74,
#    'currentRate': 0.045,
#    'remainTerm': 203,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 265000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 189942.31,
#    'currentRate': 0.04375,
#    'remainTerm': 204,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 301000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 236190.81,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 226000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 157689.45,
#    'currentRate': 0.045,
#    'remainTerm': 194,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 292000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 199971.35,
#    'currentRate': 0.0425,
#    'remainTerm': 192,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 173000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 135855.86,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 128000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 99784.16,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 148000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 115588.37,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 126000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 98662.96,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 225000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 157546.62,
#    'currentRate': 0.04375,
#    'remainTerm': 197,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 93000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 72799.88,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 85000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 64637.38,
#    'currentRate': 0.045,
#    'remainTerm': 221,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 142000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 110649.76,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 115000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 61622.44,
#    'currentRate': 0.04375,
#    'remainTerm': 137,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 60000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 47390.57,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 106000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 82379.58,
#    'currentRate': 0.04375,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 111000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 87047.45,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 116000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 90599.77,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 117000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 88337.04,
#    'currentRate': 0.04375,
#    'remainTerm': 220,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 101000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 79160.29,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 136000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 101773.24,
#    'currentRate': 0.04375,
#    'remainTerm': 219,
#    'status': 'Defaulted'}],
#  ['Mortgage',
#   {'originBalance': 139000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 108769.02,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 112000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 84978.12,
#    'currentRate': 0.04375,
#    'remainTerm': 221,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 353000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 271977.9,
#    'currentRate': 0.04375,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 157000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 120147.51,
#    'currentRate': 0.0425,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 109000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 85561.26,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 186000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 138726.07,
#    'currentRate': 0.04375,
#    'remainTerm': 216,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 195000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 151756.91,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 197000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 152311.09,
#    'currentRate': 0.04375,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 145000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 106253.01,
#    'currentRate': 0.04375,
#    'remainTerm': 212,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 145000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 113200.76,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 97000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 71879.82,
#    'currentRate': 0.045,
#    'remainTerm': 212,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 86000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 64820.65,
#    'currentRate': 0.045,
#    'remainTerm': 220,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 183000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 142942.24,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 287000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 223141.57,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 234000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 181648.76,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 255000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 199057.61,
#    'currentRate': 0.0425,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 130000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 95304.93,
#    'currentRate': 0.04375,
#    'remainTerm': 212,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 194000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 150600.17,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Defaulted'}],
#  ['Mortgage',
#   {'originBalance': 138000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 76962.44,
#    'currentRate': 0.04375,
#    'remainTerm': 145,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 231000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 142005.66,
#    'currentRate': 0.045,
#    'remainTerm': 163,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 178000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 139466.86,
#    'currentRate': 0.04375,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 108000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 82794.88,
#    'currentRate': 0.0425,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 139000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 108366.82,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 120000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 93693.35,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 87000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 67492.95,
#    'currentRate': 0.045,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 143000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 111894.4,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 159000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 121100.33,
#    'currentRate': 0.045,
#    'remainTerm': 223,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 166000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 129536.41,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 164000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 127903.49,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 132000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 89394.97,
#    'currentRate': 0.04375,
#    'remainTerm': 189,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 251000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 191117.3,
#    'currentRate': 0.045,
#    'remainTerm': 222,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 251000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 194414.16,
#    'currentRate': 0.0425,
#    'remainTerm': 231,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 197000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 152571.16,
#    'currentRate': 0.04375,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 162000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 112778.56,
#    'currentRate': 0.045,
#    'remainTerm': 193,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 159000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 124596.82,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 245000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 300,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 170432.73,
#    'currentRate': 0.04375,
#    'remainTerm': 171,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 168000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 87046.21,
#    'currentRate': 0.04375,
#    'remainTerm': 131,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 121000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 94126.39,
#    'currentRate': 0.04375,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 314000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 300,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 211195.07,
#    'currentRate': 0.0425,
#    'remainTerm': 164,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 142000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 110354.8,
#    'currentRate': 0.045,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 203000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 157733.45,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 297000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 231960.61,
#    'currentRate': 0.045,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 126000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 92305.39,
#    'currentRate': 0.04375,
#    'remainTerm': 210,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 322000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 242108.33,
#    'currentRate': 0.045,
#    'remainTerm': 217,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 245000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 190306.74,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 99000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 76037.13,
#    'currentRate': 0.045,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 125000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 97559.73,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 253000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 196619.69,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 124000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 97305.51,
#    'currentRate': 0.04375,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 132000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 102451.59,
#    'currentRate': 0.04375,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 121000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 94367.69,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 112000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 85138.61,
#    'currentRate': 0.0425,
#    'remainTerm': 226,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 211000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 163548.56,
#    'currentRate': 0.045,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 237000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 161823.22,
# ...
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 148000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 109465.02,
#    'currentRate': 0.04375,
#    'remainTerm': 213,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 89000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 69964.64,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 209000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 129936.2,
#    'currentRate': 0.045,
#    'remainTerm': 165,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 401000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 313631.57,
#    'currentRate': 0.04375,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 216000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 169154.55,
#    'currentRate': 0.045,
#    'remainTerm': 231,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 121000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 94750.67,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 102000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 62592.11,
#    'currentRate': 0.04375,
#    'remainTerm': 164,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 252000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 193896.28,
#    'currentRate': 0.04375,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 60000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 46719.84,
#    'currentRate': 0.045,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 211000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 146078.47,
#    'currentRate': 0.0425,
#    'remainTerm': 196,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 108000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 84386.62,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 92000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 71794.35,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 181000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 140196.16,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 283000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 219846.27,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 201000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 135283.91,
#    'currentRate': 0.0425,
#    'remainTerm': 189,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 165000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 121094.18,
#    'currentRate': 0.0425,
#    'remainTerm': 214,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 118000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 91892.37,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 199000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 152872.78,
#    'currentRate': 0.0425,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 158000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 117068.25,
#    'currentRate': 0.0425,
#    'remainTerm': 216,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 52000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 40435.87,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 147000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 111775.86,
#    'currentRate': 0.04375,
#    'remainTerm': 222,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 117000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 89890.64,
#    'currentRate': 0.04375,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 167000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 129755.83,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 113000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 87620.72,
#    'currentRate': 0.04375,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 180000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 139758.33,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 105000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 80150.0,
#    'currentRate': 0.04375,
#    'remainTerm': 224,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 180000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 140852.65,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 270000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 209578.12,
#    'currentRate': 0.04375,
#    'remainTerm': 231,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 329000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 256474.76,
#    'currentRate': 0.0425,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 363000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 283269.2,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 264000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 204033.23,
#    'currentRate': 0.04375,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 193000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 150404.91,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 330000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 256241.06,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 323000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 251225.52,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 128000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 99940.05,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 160000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 102584.23,
#    'currentRate': 0.04375,
#    'remainTerm': 174,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 143000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 110289.1,
#    'currentRate': 0.04375,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 211000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 163718.19,
#    'currentRate': 0.04375,
#    'remainTerm': 231,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 90000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 66444.97,
#    'currentRate': 0.045,
#    'remainTerm': 212,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 260000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 199228.56,
#    'currentRate': 0.04375,
#    'remainTerm': 225,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 103000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 79487.93,
#    'currentRate': 0.045,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 119000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 92565.18,
#    'currentRate': 0.045,
#    'remainTerm': 228,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 185000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 141569.89,
#    'currentRate': 0.04375,
#    'remainTerm': 225,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 237000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 184734.32,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 206000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 148983.09,
#    'currentRate': 0.0425,
#    'remainTerm': 208,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 202000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 157292.44,
#    'currentRate': 0.0425,
#    'remainTerm': 233,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 263000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 204955.89,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 269000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 207024.54,
#    'currentRate': 0.04375,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 396000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 307568.38,
#    'currentRate': 0.0425,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 268000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 209886.36,
#    'currentRate': 0.045,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 176000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 136205.36,
#    'currentRate': 0.045,
#    'remainTerm': 227,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 299000.0,
#    'originRate': ['fix', 0.045],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 232438.2,
#    'currentRate': 0.045,
#    'remainTerm': 229,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 183000.0,
#    'originRate': ['fix', 0.0425],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 141373.45,
#    'currentRate': 0.0425,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 233000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 180465.03,
#    'currentRate': 0.04375,
#    'remainTerm': 230,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 191000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 148702.51,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 237000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-07-20'},
#   {'currentBalance': 184771.43,
#    'currentRate': 0.04375,
#    'remainTerm': 232,
#    'status': 'Current'}],
#  ['Mortgage',
#   {'originBalance': 149000.0,
#    'originRate': ['fix', 0.04375],
#    'originTerm': 360,
#    'freq': 'Monthly',
#    'type': 'Level',
#    'originDate': '2012-08-20'},
#   {'currentBalance': 114833.51,
#    'currentRate': 0.04375,
#    'remainTerm': 229,
#    'status': 'Current'}]]

# %%
loan_level_deal = Generic(
    "loan_level_deal"
    ,{"cutoff":"2023-03-01","closing":"2023-02-15","firstPay":"2023-04-20"
     ,"payFreq":["DayOfMonth",20],"poolFreq":"MonthEnd","stated":"2042-01-01"}
    ,{'assets':mortgages}  #<<<<<--- here
    ,(("acc01",{"balance":0}),)
    ,(("A1",{"balance":37498392.54
             ,"rate":0.03
             ,"originBalance":1000
             ,"originRate":0.07
             ,"startDate":"2020-01-03"
             ,"rateType":{"Fixed":0.08}
             ,"bondType":{"Sequential":None}}),)
    ,(("trusteeFee",{"type":{"fixFee":30}}),)
    ,{"amortizing":[
         ["payFee",["acc01"],['trusteeFee']]
         ,["payInt","acc01",["A1"]]
         ,["payPrin","acc01",["A1"]]
     ]}
    ,[["CollectedInterest","acc01"]
      ,["CollectedPrincipal","acc01"]
      ,["CollectedPrepayment","acc01"]
      ,["CollectedRecoveries","acc01"]]
    ,None
    ,None)

# %%
r = localAPI.run(loan_level_deal ,assumptions=[] ,read=True)
r['pool']['flow']
# Out:
#                 Balance  Principal   Interest  Prepayment  Default  Recovery  \
# Date
# 2023-03-31  37725124.62  124231.49  129083.05           0        0         0
# 2023-04-30  37614262.48  110862.14  142452.40           0        0         0
# 2023-05-31  37498392.54  115869.94  137444.60           0        0         0
# 2023-06-30  37386674.31  111718.23  141596.31           0        0         0
# 2023-07-31  37269972.85  116701.46  136613.08           0        0         0
# ...                 ...        ...        ...         ...      ...       ...
# 2041-08-31   1898370.55  183353.14    7854.84           0        0         0
# 2041-09-30   1711315.89  179981.18    7135.62           0        0         0
# 2041-10-31   1529018.57  178995.91    6235.38           0        0         0
# 2041-11-30   1346262.11  175119.07    5738.95           0        0         0
# 2041-12-31   1165023.53  169346.68    4869.65           0        0         0
#
#             Loss       WAC BorrowerNum
# Date
# 2023-03-31     0  0.043790        None
# 2023-04-30     0  0.043790        None
# 2023-05-31     0  0.043789        None
# 2023-06-30     0  0.043789        None
# 2023-07-31     0  0.043789        None
# ...          ...       ...         ...
# 2041-08-31     0  0.043778        None
# 2041-09-30     0  0.043775        None
# 2041-10-31     0  0.043774        None
# 2041-11-30     0  0.043774        None
# 2041-12-31     0  0.043766        None
#
# [226 rows x 9 columns]
