# %% [markdown]
# ### Run Deal

# %%
from absbox import API,EnginePath

localAPI = API(EnginePath.DEV, lang='english', check=False)
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #### Single Run

# %%
from absbox import examples
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
myAssumption = ("Pool",("Mortgage",{"CDR":0.01},None,None,None)
                                ,None
                                ,None)


r = localAPI.run(examples.test01
                ,poolAssump=myAssumption
                ,read=True)

# %% [markdown]
# the result `r` returned by API function `run()`.

# %% [markdown]
# #### Pool Sensitivity Run

# %% [markdown]
# User can build a pool performance map and call the API function `runByScenarios`

# %%
myAssumption = ("Pool",("Mortgage",{"CDR":0.01},None,None,None)
                                ,None
                                ,None)

myAssumption2 = ("Pool",("Mortgage",None,{"CPR":0.01},None,None)
                                ,None
                                ,None)

r = localAPI.runByScenarios(examples.test01
                            ,poolAssump={"00":myAssumption
                                        ,"stressed":myAssumption2}
                            ,read=True)

# %% [markdown]
# The result `r` is a dict whose keys came fromt he pool assumpiton map

# %%
r['00']['pool']['flow']
# Out:
#             Balance  Principal  Interest  Prepayment  Default  Recovery  Loss  \
# Date
# 2021-04-01  1989.69     206.84     28.60           0     3.47         0  3.47
# 2021-05-01  1883.73     104.32     13.25           0     1.64         0  1.64
# 2021-06-01  1777.20     104.93     12.54           0     1.60         0  1.60
# 2021-07-01  1670.20     105.54     11.83           0     1.46         0  1.46
# 2021-08-01  1562.63     106.15     11.12           0     1.42         0  1.42
# 2021-09-01  1454.53     106.77     10.40           0     1.33         0  1.33
# 2021-10-01  1345.93     107.40      9.68           0     1.20         0  1.20
# 2021-11-01  1236.77     108.02      8.96           0     1.14         0  1.14
# 2021-12-01  1127.10     108.65      8.23           0     1.02         0  1.02
# 2022-01-01  1016.86     109.28      7.50           0     0.96         0  0.96
# 2022-02-01   906.09     109.91      6.77           0     0.86         0  0.86
# 2022-03-01   794.84     110.56      6.03           0     0.69         0  0.69
# 2022-04-01   682.97     111.20      5.29           0     0.67         0  0.67
# 2022-05-01   570.55     111.86      4.54           0     0.56         0  0.56
# 2022-06-01   457.57     112.50      3.80           0     0.48         0  0.48
# 2022-07-01   344.03     113.17      3.04           0     0.37         0  0.37
# 2022-08-01   229.92     113.82      2.29           0     0.29         0  0.29
# 2022-09-01   115.25     114.48      1.53           0     0.19         0  0.19
# 2022-10-01     0.00     115.16      0.76           0     0.09         0  0.09
#
#              WAC BorrowerNum PrepayPenalty  CumPrincipal  CumPrepay  \
# Date
# 2021-04-01  0.08        None          None        206.84          0
# 2021-05-01  0.08        None          None        311.16          0
# 2021-06-01  0.08        None          None        416.09          0
# 2021-07-01  0.08        None          None        521.63          0
# 2021-08-01  0.08        None          None        627.78          0
# 2021-09-01  0.08        None          None        734.55          0
# 2021-10-01  0.08        None          None        841.95          0
# 2021-11-01  0.08        None          None        949.97          0
# 2021-07-01  0.08        None          None        521.63       8.17
# 2021-08-01  0.08        None          None        627.78       9.59
# 2021-09-01  0.08        None          None        734.55      10.92
# 2021-10-01  0.08        None          None        841.95      12.12
# 2021-11-01  0.08        None          None        949.97      13.26
# 2021-12-01  0.08        None          None       1058.62      14.28
# 2022-01-01  0.08        None          None       1167.90      15.24
# 2022-02-01  0.08        None          None       1277.81      16.10
# 2022-03-01  0.08        None          None       1388.37      16.79
# 2022-04-01  0.08        None          None       1499.57      17.46
# 2022-05-01  0.08        None          None       1611.43      18.02
# 2022-06-01  0.08        None          None       1723.93      18.50
# 2022-07-01  0.08        None          None       1837.10      18.87
# 2022-08-01  0.08        None          None       1950.92      19.16
# 2022-09-01  0.08        None          None       2065.40      19.35
# 2022-10-01  0.08        None          None       2180.56      19.44
#
#             CumDelinq  CumDefault  CumRecovery  CumLoss
# Date
# 2021-04-01          0           0            0        0
# 2021-05-01          0           0            0        0
# 2021-06-01          0           0            0        0
# 2021-07-01          0           0            0        0
# 2021-08-01          0           0            0        0
# 2021-09-01          0           0            0        0
# 2021-10-01          0           0            0        0
# 2021-11-01          0           0            0        0
# 2021-12-01          0           0            0        0
# 2022-01-01          0           0            0        0
# 2022-02-01          0           0            0        0
# 2022-03-01          0           0            0        0
# 2022-04-01          0           0            0        0
# 2022-05-01          0           0            0        0
# 2022-06-01          0           0            0        0
# 2022-07-01          0           0            0        0
# 2022-08-01          0           0            0        0
# 2022-09-01          0           0            0        0
# 2022-10-01          0           0            0        0

# %% [markdown]
# #### Structure Senstivity Run

# %% [markdown]
# To run mulitple deals with same pool/deal run assumption , user can call `runStructs()` from the API.
#
# The function will return the result as a map.

# %%
r = localAPI.runStructs({"A":examples.test01
                         ,"B":examples.test02}
                        ,read=True)

# %%
r['A']['bonds']['A1']
# Out:
#             balance  interest  principal  rate    cash   factor  \
# date
# 2021-06-20   543.90     15.34     456.10  0.07  471.44  0.54390
# 2021-07-20   429.17      3.12     114.73  0.07  117.85  0.42917
# 2021-08-20   313.86      2.55     115.31  0.07  117.86  0.31386
# 2021-09-20   197.87      1.86     115.99  0.07  117.85  0.19787
# 2021-10-20    81.15      1.13     116.72  0.07  117.85  0.08115
# 2021-11-20     0.00      0.48      81.15  0.07   81.63  0.00000
#
#                                    memo
# date
# 2021-06-20  [<PayInt:A1>, <PayPrin:A1>]
# 2021-07-20  [<PayInt:A1>, <PayPrin:A1>]
# 2021-08-20  [<PayInt:A1>, <PayPrin:A1>]
# 2021-09-20  [<PayInt:A1>, <PayPrin:A1>]
# 2021-10-20  [<PayInt:A1>, <PayPrin:A1>]
# 2021-11-20  [<PayInt:A1>, <PayPrin:A1>]

# %%
r['B']['bonds']['A1']
# Out:
#             balance  interest  principal  rate    cash   factor  \
# date
# 2021-06-20   340.83     12.27     459.17  0.07  471.44  0.34083
# 2021-07-20   224.94      1.96     115.89  0.07  117.85  0.22494
# 2021-08-20   108.41      1.33     116.53  0.07  117.86  0.10841
# 2021-09-20     0.00      0.64     108.41  0.07  109.05  0.00000
#
#                                    memo
# date
# 2021-06-20  [<PayInt:A1>, <PayPrin:A1>]
# 2021-07-20  [<PayInt:A1>, <PayPrin:A1>]
# 2021-08-20  [<PayInt:A1>, <PayPrin:A1>]
# 2021-09-20  [<PayInt:A1>, <PayPrin:A1>]
