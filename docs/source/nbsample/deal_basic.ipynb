# %% [markdown]
# ### Sample1

# %%
from absbox import API,EnginePath

localAPI = API(EnginePath.DEV, lang='english',check=False)
# Out:
# Connecting engine server -> https://absbox.org/api/dev
# ✅Connected, local lib:0.26.8, server:0.26.5

# %% [markdown]
# #### Include examples

# %%
from absbox import examples
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from absbox import examples
#
# ImportError: cannot import name 'examples' from 'absbox' (/opt/homebrew/lib/python3.11/site-packages/absbox/__init__.py)

# %% [markdown]
# #### Run with non-stress scenario
#
# Run result will be return by a call to `run()`

# %%
r = localAPI.run(examples.test01
               ,poolAssump = ("Pool",("Mortgage",None,None,None,None)
                                       ,None
                                       ,None)
               ,runAssump = None
               ,read=True)

# %% [markdown]
# #### Getting Cashflow Result

# %% [markdown]
# ##### Pool Cashflow
#
# Pool cashflow can be retrieved from key `pool` and `flow`

# %%
list(r['pool']['flow'].to_records())[:10]

# %% [markdown]
# #### Bond Cashflow
#
# Bond cashflow can be retrieved via key `bonds` and bond name

# %%
list(r['bonds']['A1'].to_records())
# Out:
# Running cells with 'Python 3.11.6' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
