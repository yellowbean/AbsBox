# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from absbox import API
from absbox.local.china import SPV
import numpy as np
import pandas as pd 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
pd.options.display.float_format = '{:,}'.format

JSD_AUTO_2022_3 = SPV(
    "吉时代2022年第三期个人汽车抵押贷款资产支持证券"
    ,{"封包日":"2022-06-30","起息日":"2022-08-31","首次兑付日":"2022-10-26"
     ,"法定到期日":"2060-12-01","收款频率":"月末","付款频率":["每月",26]} 
    ,{'发行':{'资产池规模':4_057_999_932.76}
      ,'清单':[]
      ,'归集表':[
         ["2022-07-31",3865848481,192151451.7,6676623.4]
        ,["2022-08-31",3673121853,192726628.5,11568584.83]
        ,["2022-09-30",3479817133,193304719.2,10990495.43]
        ,["2022-10-31",3286727077,193090056.2,10409475.38]
        ,["2022-11-30",3093860236,192866841,9828387.99]
        ,["2022-12-31",2901500383,192359852.8,9247292.41]
        ,["2023-01-31",2724074597,177425786.2,8667432.22]
        ,["2023-02-28",2562373714,161700882.7,8151667.93]
        ,["2023-03-31",2403463658,158910056,7698615.26]
        ,["2023-04-30",2253325738,150137920.3,7250780.97]
        ,["2023-05-31",2113157309,140168429.2,6828165.67]
        ,["2023-06-30",1981925930,131231378.5,6436655.5]
        ,["2023-07-31",1859496503,122429427.8,6080160.47]
        ,["2023-08-31",1737227069,122269434,5757585.57]
        ,["2023-09-30",1617432791,119794277.5,5435688.38]
        ,["2023-10-31",1499954657,117478133.8,5116405.39]
        ,["2023-11-30",1384048082,115906575.7,4800564.48]
        ,["2023-12-31",1268923680,115124401.2,4487931.47]
        ,["2024-01-31",1154993485,113930195.7,4179070.83]
        ,["2024-02-29",1042177559,112815925.9,3875613.73]
        ,["2024-03-31",941455847.9,100721710.9,3577012.82]
        ,["2024-04-30",852960381.9,88495466.06,3288218.96]
        ,["2024-05-31",773365036.5,79595345.38,3011870.31]
        ,["2024-06-30",695507252.6,77857783.91,2747470.16]
        ,["2024-07-31",619580937.2,75926315.33,2492027.29]
        ,["2024-08-31",543830971.2,75749966.08,2246666.07]
        ,["2024-09-30",468401419.6,75429551.56,2001962.25]
        ,["2024-10-31",393448317.9,74953101.74,1758903.98]
        ,["2024-11-30",319034554.7,74413763.2,1518146.62]
        ,["2024-12-31",245203995.4,73830559.27,1280007.42]
        ,["2025-01-31",172304852.1,72899143.3,1044437.97]
        ,["2025-02-28",119443655.6,52861196.47,813317.99]
        ,["2025-03-31",83405580.69,36038074.93,638418.41]
        ,["2025-04-30",63128229.33,20277351.36,503828.17]
        ,["2025-05-31",53667660.16,9460569.17,411316.35]
        ,["2025-06-30",44918162.06,8749498.1,348244.85]
        ,["2025-07-31",37100686.28,7817475.78,290226.08]
        ,["2025-08-31",30237510.9,6863175.38,238875.15]
        ,["2025-09-30",23720257.01,6517253.89,194399.26]
        ,["2025-10-31",17459765.98,6260491.03,152388.78]
        ,["2025-11-30",11400979.8,6058786.18,112191.1]
        ,["2025-12-31",6532273.37,4868706.43,73316]
        ,["2026-01-31",3186667.2,3345606.17,42037.96]
        ,["2026-02-28",1500528.78,1686138.42,20510.72]
        ,["2026-03-31",435006.28,1065522.5,9676.28]
        ,["2026-04-30",0,435006.28,2827.09]
      ]
     }
    ,(("信托收付账户",{"余额":0 })
      ,("流动性储备",{"余额":15_757_708.38
                    ,"类型":{"较高":[{"目标储备金额":["资产池余额",0.009]}
                                   ,{"目标储备金额":[["合计"
                                                   ,("债券已付利息","优先A1","优先A2")
                                                    ,("已付费用",'服务商费用')
                                                    ,("债券待付利息","优先A1","优先A2")
                                                    ,("待付费用",'服务商费用')]
                                                  , 3.0]
                                    }]}})
     )
    ,(("优先A1",{"当前余额":1_500_000_000.00
             ,"当前利率":0.018
             ,"初始余额":1_500_000_000.00
             ,"初始利率":0.018
             ,"起息日":"2022-09-30"
             ,"利率":{"固定":0.018}
             ,"债券类型":{"固定摊还":[["2022-10-26",1350000000.00]
                                    ,["2022-11-26",1200000000.00]
                                    ,["2022-12-26",1050000000.00]
                                    ,["2023-01-26",900000000.00]
                                    ,["2023-02-26",780000000.00]
                                    ,["2023-03-26",660000000.00]
                                    ,["2023-04-26",540000000.00]
                                    ,["2023-05-26",420000000.00]
                                    ,["2023-06-26",315000000.00]
                                    ,["2023-07-26",210000000.00]
                                    ,["2023-08-26",105000000.00]
                                    ,["2023-09-26",0]
                             ]}
             })
      ,("优先A2",{"当前余额":1_990_000_000.00
             ,"当前利率":0.0205
             ,"初始余额":1_990_000_000.00
             ,"初始利率":0.0205
             ,"起息日":"2022-09-30"
             ,"利率":{"固定":0.0205}
             ,"债券类型":{"过手摊还":None}
             })
      ,("次级",{"当前余额":567_999_932.76
             ,"当前利率":0.0
             ,"初始余额":567_999_932.76
             ,"初始利率":0.0
             ,"起息日":"2022-09-30"
             ,"利率":{"固定":0.00}
             ,"债券类型":{"权益":None}
             })
     )
    ,(("增值税",{"类型":{"百分比费率":["资产池回款","利息",0.0326]},"计算日":"2022-06-30"})
      ,("服务商费用",{"类型":{"年化费率":["资产池余额",0.0012]}}),
      #,("报销",{"类型":{"周期费用":["每月",60000]}})
     )
    ,{"未违约":[
         ["账户转移","流动性储备","信托收付账户"]
         ,["支付费用",["信托收付账户"],["服务商费用"]]
         ,["支付费用",["信托收付账户"],["增值税"]] 
         #,["支付费用限额",["收入分账户"],["报销"],{"应计费用上限":50000}]
         ,["支付利息","信托收付账户",["优先A1","优先A2"]]
         ,["储备账户转移","信托收付账户","流动性储备","目标储备"]
         ,["支付本金","信托收付账户",["优先A1"]]
         ,["支付本金","信托收付账户",["优先A2"]]
         ,["If"
           ,["balance",">",0]
           ,["支付本金","信托收付账户",["优先A1"]]
           ,["支付本金","信托收付账户",["优先A2"]]]
         ,["支付剩余本金","信托收付账户",["优先A1"]]
        #,["支付费用限额",["收入分账户"],["报销"],{"应计费用上限":50000}]
         ,["支付本金","信托收付账户",["次级"]]
         ,["支付收益","信托收付账户","次级"]
      ]
     ,"回款后":[["计提费用","服务商费用","增值税"]
              ,["IfElse"
               ,["Balance",">>>",0]
               ,[["支付利息","信托收付账户",["优先A1"]]
                ,["支付本金","信托收付账户",["优先A2"]]]
               ,[["支付本金","信托收付账户",["次级"]]
                ,["支付收益","信托收付账户","次级"]]]]
     ,"清仓回购":[
                 ["出售资产",["正常|违约",1.0,0.0],"信托收付账户"]
                 ,["账户转移","流动性储备","信托收付账户"]
                 ,["支付费用",["信托收付账户"],["服务商费用"]]
                ,["支付利息","信托收付账户",["优先A1"]]
                ,["支付本金","信托收付账户",["优先A2"]]
                ,["支付本金","信托收付账户",["次级"]]
                ,["支付收益","信托收付账户","次级"]
             ]
     }
    ,(["利息回款","信托收付账户"]
      ,["本金回款","信托收付账户"]
      ,["早偿回款","信托收付账户"]
      ,["回收回款","信托收付账户"])
    ,None
    ,None
    ,None
)
# Out:
# /var/folders/pb/0lsr_g9s0x340sd74jhjdhj40000gn/T/ipykernel_44857/3988995106.py:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
from absbox.local.chart import viz

viz(JSD_AUTO_2022_3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[270], line 3
#       1 from absbox.local.chart import viz
# ----> 3 viz(JSD_AUTO_2022_3)
#
# File ~/Projects/PyABS/absbox/local/chart.py:127, in viz(x)
#     124     head_of_waterfalls = [build_subwaterfall(d, ds, waterfall[ds]) for ds in deal_status]
#     125     return head_of_waterfalls
# --> 127 dot = graphviz.Digraph('round-table', comment="", name=x.name, format='svg')
#     128 build_agg(dot, agg)
#     129 head_of_waterfalls = build_waterfall(dot, waterfall)
#
# AttributeError: 'SPV' object has no attribute 'name'

# %%
德宝天元202301 = SPV(
    "德宝天元之信2023年第一期个人汽车抵押贷款资产支持证券"
    ,{"封包日":"2022-09-30","起息日":"2023-04-07","首次兑付日":"2023-05-26"
     ,"法定到期日":"2060-12-01","收款频率":"月末","付款频率":["每月",26]}      
    ,{"清单":[]
      ,'发行':{'资产池规模':8000000001.8}
      ,'归集表':
        [["2022-10-28",7703073351,296926650.8,39621199.84]
        ,["2022-11-28",7404682416,298390935.6,38239799.05]
        ,["2022-12-28",7068698297,335984118.4,36851240.88]
        ,["2023-01-28",6754588776,314109521.1,35270038.62]
        ,["2023-02-28",6484198542,270390234,33782877.37]
        ,["2023-03-28",6213847967,270350575.7,32518759.42]
        ,["2023-04-28",5948509320,265338646.5,31253463.48]
        ,["2023-05-28",5688705557,259803763.2,30007334.46]
        ,["2023-06-28",5428759464,259946092.9,28787675.09]
        ,["2023-07-28",5175901751,252857713.1,27564949.08]
        ,["2023-08-28",4928990804,246910947.3,26372771.15]
        ,["2023-09-28",4685294315,243696488.3,25204562.17]
        ,["2023-10-28",4448845810,236448505.8,24048073.72]
        ,["2023-11-28",4215182466,233663343.6,22921167.01]
        ,["2023-12-28",3985947347,229235118.7,21803634.86]
        ,["2024-01-28",3759360916,226586431.3,20702493.3]
        ,["2024-02-28",3538894353,220466563.4,19610562.99]
        ,["2024-03-28",3323113360,215780992.7,18542390.48]
        ,["2024-04-28",3113335758,209777601.8,17492785.73]
        ,["2024-05-28",2907923173,205412585.4,16466179.14]
        ,["2024-06-28",2703346681,204576491.7,15458135.54]
        ,["2024-07-28",2511363265,191983415.7,14454511.7]
        ,["2024-08-28",2328011947,183351318.5,13500336.9]
        ,["2024-09-28",2154558970,173452976.8,12579982.71]
        ,["2024-10-28",1987657739,166901231.6,11699767.21]
        ,["2024-11-28",1826757367,160900371.7,10848388.31]
        ,["2024-12-28",1672568344,154189022.8,10025127.3]
        ,["2025-01-28",1523301145,149267198.8,9233666.38]
        ,["2025-02-28",1391357178,131943966.8,8465915.05]
        ,["2025-03-28",1265990068,125367110.5,7781807.72]
        ,["2025-04-28",1148751455,117238613.1,7127147.05]
        ,["2025-05-28",1036382880,112368574.8,6509482.45]
        ,["2025-06-28",936394625.7,99988254.23,5914372.72]
        ,["2025-07-28",851012123.3,85382502.47,5381543.83]
        ,["2025-08-28",778711315.7,72300807.56,4921856.54]
        ,["2025-09-28",721110322.3,57600993.4,4521948.54]
        ,["2025-10-28",665295441.8,55814880.46,4193570.1]
        ,["2025-11-28",610860431.7,54435010.17,3874600.17]
        ,["2025-12-28",558006506.8,52853924.88,3562862.69]
        ,["2026-01-28",506302198.1,51704308.72,3259695.55]
        ,["2026-02-28",457913355.7,48388842.39,2962622.7]
        ,["2026-03-28",410739506.7,47173848.94,2683796.57]
        ,["2026-04-28",365271282,45468224.78,2411532.19]
        ,["2026-05-28",321236485.9,44034796.02,2148403.47]
        ,["2026-06-28",279263716.2,41972769.71,1893121.68]
        ,["2026-07-28",240177960.2,39085756.02,1648962.9]
        ,["2026-08-28",203790300.9,36387659.26,1420731.37]
        ,["2026-09-28",170218846,33571454.92,1206970.51]
        ,["2026-10-28",139622059.2,30596786.79,1008386.32]
        ,["2026-11-28",111766649.5,27855409.75,826711.04]
        ,["2026-12-28",86949691.98,24816957.49,661149.47]
        ,["2027-01-28",64671479.97,22278212,513593.06]
        ,["2027-02-28",48386675.38,16284804.59,381046.4]
        ,["2027-03-28",34169784.81,14216890.57,284519.48]
        ,["2027-04-28",22935717.42,11234067.39,200345.49]
        ,["2027-05-28",13354353.39,9581364.03,133877.2]
        ,["2027-06-28",6283905.88,7070447.52,77370.71]
        ,["2027-07-28",1919297.32,4364608.56,35979.93]
        ,["2027-08-28",0,1919297.32,10964.13]
      ]}
      ,(("分配分账户",{"余额":0})
       ,("现金储备分账户",{"余额":80_000_000.02
                         ,"类型":{"固定储备金额":80_000_000.02}})
       ,("持续购买分账户",{"余额":0}))
    ,(("A",{"当前余额":6_940_000_000
          ,"当前利率":0.027
          ,"初始余额":6_940_000_000.00
          ,"初始利率":0.027
          ,"起息日":"2023-04-03"
          ,"利率":{"固定":0.027}
          ,"债券类型":{"过手摊还":None}
                            })
      ,("次级",{"当前余额":1_060_000_002.17
             ,"当前利率":0.0
             ,"初始余额":1_060_000_002.17
             ,"初始利率":0.00
             ,"起息日":"2023-04-03"
             ,"利率":{"固定":0.0}
             ,"债券类型":{"权益":None}
                            }))
    ,(("宝马金融服务商费用",{"类型":{"年化费率":["资产池余额",0.01]}})
      ,("宝马金融",{"类型":{"固定费用":0}})
      ,("执行费用", {"类型":{"周期费用":["月初",15000]}}))
    ,{"未违约":[
          ["账户转移",'持续购买分账户',"分配分账户"]
         ,["账户转移",'现金储备分账户',"分配分账户"]
         ,["支付费用",["分配分账户",'现金储备分账户'],["执行费用"]]
         ,["支付费用",["分配分账户",'现金储备分账户'],["宝马金融服务商费用"]]
         #,["支付费用",["分配分账户",'现金储备分账户'],["服务商费用"]]
         ,["支付利息","分配分账户",["A"]]
         ,["支付利息","现金储备分账户",["A"]]
         ,["条件执行"
          ,[("账户余额","分配分账户"),"<",("债券余额","A")] 
          ,["储备账户转移","分配分账户",'现金储备分账户',"目标储备"]]
         
         ,["条件执行"  # 循环期条件
           ,["同时满足"
             ,["<=","2024-05-26"]
             ,[("资产池累计违约率",) ,"<=",0.016]]
           ,["按公式账户转移",{"公式":("差额",("债券余额",),("资产池余额",))}
                           ,"分配分账户",'持续购买分账户']
           ,["购买资产",["Current|Defaulted",1.0,0],"持续购买分账户",None]
           ,["支付收益","分配分账户","次级"] ]
         ,["条件执行" # 循环期结束后的分配
           ,["任一满足"
             ,[">","2024-05-26"]
             ,[("资产池累计违约率",) ,">",0.016]]
            ,["支付本金","分配分账户",["A"]]
            ,["支付本金","分配分账户",["次级"]]
            ,["支付费用收益", "分配分账户", "宝马金融"]]
    ]
     ,"回款后":[["计提费用","宝马金融服务商费用"]]
     ,"清仓回购":[["出售资产", ["Current|Defaulted",1.0,0], "分配分账户"]
                 ,["支付利息","分配分账户",["A"]]
                 ,["支付本金","分配分账户",["A"]]
                 ,["支付本金","分配分账户",["次级"]]
                 ,["支付费用收益", "分配分账户", "宝马金融"]]
     }
    ,(["利息回款","分配分账户"]
      ,["本金回款","分配分账户"]
      ,["早偿回款","分配分账户"]
      ,["回收回款","分配分账户"])
    ,None
    ,None
    ,None
)

# %%
viz(德宝天元202301)

# %%
from absbox.local.generic import Generic

BMW202301 = Generic(
    "BMW Auto"
    ,{"cutoff":"2022-09-30","closing":"2023-04-07","firstPay":"2023-05-26"
     ,"stated":"2060-12-01","poolFreq":"MonthEnd","payFreq":["DayOfMonth",26]}      
    ,{"assets":[]
      ,'issuanceStat':{'IssuanceBalance':8000000001.8}
      ,'cashflow':
        [["2022-10-28",7703073351,296926650.8,39621199.84]
        ,["2022-11-28",7404682416,298390935.6,38239799.05]
        ,["2022-12-28",7068698297,335984118.4,36851240.88]
        ,["2023-01-28",6754588776,314109521.1,35270038.62]
        ,["2023-02-28",6484198542,270390234,33782877.37]
        ,["2023-03-28",6213847967,270350575.7,32518759.42]
        ,["2023-04-28",5948509320,265338646.5,31253463.48]
        ,["2023-05-28",5688705557,259803763.2,30007334.46]
        ,["2023-06-28",5428759464,259946092.9,28787675.09]
        ,["2023-07-28",5175901751,252857713.1,27564949.08]
        ,["2023-08-28",4928990804,246910947.3,26372771.15]
        ,["2023-09-28",4685294315,243696488.3,25204562.17]
        ,["2023-10-28",4448845810,236448505.8,24048073.72]
        ,["2023-11-28",4215182466,233663343.6,22921167.01]
        ,["2023-12-28",3985947347,229235118.7,21803634.86]
        ,["2024-01-28",3759360916,226586431.3,20702493.3]
        ,["2024-02-28",3538894353,220466563.4,19610562.99]
        ,["2024-03-28",3323113360,215780992.7,18542390.48]
        ,["2024-04-28",3113335758,209777601.8,17492785.73]
        ,["2024-05-28",2907923173,205412585.4,16466179.14]
        ,["2024-06-28",2703346681,204576491.7,15458135.54]
        ,["2024-07-28",2511363265,191983415.7,14454511.7]
        ,["2024-08-28",2328011947,183351318.5,13500336.9]
        ,["2024-09-28",2154558970,173452976.8,12579982.71]
        ,["2024-10-28",1987657739,166901231.6,11699767.21]
        ,["2024-11-28",1826757367,160900371.7,10848388.31]
        ,["2024-12-28",1672568344,154189022.8,10025127.3]
        ,["2025-01-28",1523301145,149267198.8,9233666.38]
        ,["2025-02-28",1391357178,131943966.8,8465915.05]
        ,["2025-03-28",1265990068,125367110.5,7781807.72]
        ,["2025-04-28",1148751455,117238613.1,7127147.05]
        ,["2025-05-28",1036382880,112368574.8,6509482.45]
        ,["2025-06-28",936394625.7,99988254.23,5914372.72]
        ,["2025-07-28",851012123.3,85382502.47,5381543.83]
        ,["2025-08-28",778711315.7,72300807.56,4921856.54]
        ,["2025-09-28",721110322.3,57600993.4,4521948.54]
        ,["2025-10-28",665295441.8,55814880.46,4193570.1]
        ,["2025-11-28",610860431.7,54435010.17,3874600.17]
        ,["2025-12-28",558006506.8,52853924.88,3562862.69]
        ,["2026-01-28",506302198.1,51704308.72,3259695.55]
        ,["2026-02-28",457913355.7,48388842.39,2962622.7]
        ,["2026-03-28",410739506.7,47173848.94,2683796.57]
        ,["2026-04-28",365271282,45468224.78,2411532.19]
        ,["2026-05-28",321236485.9,44034796.02,2148403.47]
        ,["2026-06-28",279263716.2,41972769.71,1893121.68]
        ,["2026-07-28",240177960.2,39085756.02,1648962.9]
        ,["2026-08-28",203790300.9,36387659.26,1420731.37]
        ,["2026-09-28",170218846,33571454.92,1206970.51]
        ,["2026-10-28",139622059.2,30596786.79,1008386.32]
        ,["2026-11-28",111766649.5,27855409.75,826711.04]
        ,["2026-12-28",86949691.98,24816957.49,661149.47]
        ,["2027-01-28",64671479.97,22278212,513593.06]
        ,["2027-02-28",48386675.38,16284804.59,381046.4]
        ,["2027-03-28",34169784.81,14216890.57,284519.48]
        ,["2027-04-28",22935717.42,11234067.39,200345.49]
        ,["2027-05-28",13354353.39,9581364.03,133877.2]
        ,["2027-06-28",6283905.88,7070447.52,77370.71]
        ,["2027-07-28",1919297.32,4364608.56,35979.93]
        ,["2027-08-28",0,1919297.32,10964.13]
      ]}
      ,(("distAcc",{"balance":0})
       ,("cashReserve",{"balance":80_000_000.02
                         ,"type":{"fixReserve":80_000_000.02}})
       ,("revolBuyAcc",{"balance":0}))
    ,(("A",{"balance":6_940_000_000
          ,"rate":0.027
          ,"originBalance":6_940_000_000.00
          ,"originRate":0.027
          ,"startDate":"2023-04-03"
          ,"rateType":{"Fixed":0.027}
          ,"bondType":{"Sequential":None}})
      ,("Sub",{"balance":1_060_000_002.17
             ,"rate":0.0
             ,"originBalance":1_060_000_002.17
             ,"originRate":0.00
             ,"startDate":"2023-04-03"
             ,"rateType":{"Fixed":0.0}
             ,"bondType":{"Equity":None}}))
    ,(("serviceFee",{"type":{"annualPctFee":["CurrentPoolBalance",0.01]}})
      ,("bmwFee",{"type":{"fixFee":0}})
      ,("admFee", {"type":{"recurFee":["MonthFirst",15000]}}))
    ,{"default":[
          ["transfer",'revolBuyAcc',"distAcc"]
         ,["transfer",'cashReserve',"distAcc"]
         ,["payFee",["distAcc",'cashReserve'],["admFee"]]
         ,["payFee",["distAcc",'cashReserve'],["serviceFee"]]
         ,["payInt","distAcc",["A"]]
         ,["payInt","cashReserve",["A"]]
        
         ,["runTrigger",0] # update the trigger status during the waterfall
        
         ,["If"
          ,[("trigger","InDistribution",0),False]  # if it was triggered 
          ,["transferReserve","distAcc",'cashReserve',"Target"]] # trasnfer amt to cash reserver account
        
         ,["IfElse"  
           ,["status","Revolving"] # acitons in the revolving period
           ,[["transferBy",{"formula":("substract",("bondBalance",),("poolBalance",))}
                          ,"distAcc",'revolBuyAcc']
            ,["buyAsset",["Current|Defaulted",1.0,0],"revolBuyAcc",None] # buy asset with 1:1 if asset with performing
            ,["payResidual","distAcc","Sub"] ]
           ,[["payPrin","distAcc",["A"]] # actions if deal is in Amortizing status
            ,["payPrin","distAcc",["Sub"]]
            ,["payFeeResidual", "distAcc", "bmwFee"]]]]
     ,"endOfCollection":[["calcFee","serviceFee"]] # accure fee by end of collection period
     ,"cleanUp":[["sellAsset", ["Current|Defaulted",1.0,0], "distAcc"]
                 ,["payInt","distAcc",["A"]]
                 ,["payPrin","distAcc",["A"]]
                 ,["payPrin","distAcc",["Sub"]]
                 ,["payFeeResidual", "distAcc", "bmwFee"]]
     }
    ,(["CollectedInterest","distAcc"]
      ,["CollectedPrincipal","distAcc"]
      ,["CollectedPrepayment","distAcc"]
      ,["CollectedRecoveries","distAcc"])
    ,None
    ,None
    ,None
    ,{"BeforeDistribution":[
        {"condition":["any"
                      ,[">=","2024-05-26"]
                      ,[("cumPoolDefaultedRate",),">",0.016]]
        ,"effects":("newStatus","Amortizing")
        ,"status":False
        ,"curable":False}]
     ,"InDistribution":[
        {"condition":[("accountBalance","distAcc"),">",("bondBalance","A")]
        ,"effects":("newReserveBalance","cashReserve",{"fixReserve":0}) # if was triggered, change reserve account amount to 0
        ,"status":False
        ,"curable":False}
     ]
     }
    ,"Revolving"  # start deal with "Revolving" status
)

# %%
jpg = viz(BMW202301)

# %%
import graphviz  # dot.render(outfile='spam.svg')

# %%
jpg.render(outfile="bmw_viz.svg",engine='dot')
# Out:
# 'bmw_viz.svg'

# %%
jpg.save("~/Downloads/bmw_viz.png")
# Out:
# '~/Downloads/bmw_viz.png'
