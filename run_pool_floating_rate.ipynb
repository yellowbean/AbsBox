# %%
from absbox import API,EnginePath

run_assump = [('EURIBOR3M', 
               [  ['2024-07-31', 1]
                , ['2024-08-31', 1]
                , ['2024-09-30', 1]
                , ['2024-10-31', 1]
                , ['2024-11-30', 1]
                , ['2024-12-31', 1]
                , ['2025-01-31', 1]
                , ['2025-02-28', 1]
                , ['2025-03-31', 1]
                , ['2025-04-30', 1]
                , ['2025-05-31', 1]
                , ['2025-06-30', 1]
                , ['2025-07-31', 1]
                , ['2025-08-31', 1]
                , ['2025-09-30', 1]
                , ['2025-10-31', 1]
                , ['2025-11-30', 1]
                , ['2025-12-31', 1]
                , ['2026-01-31', 1]
                , ['2026-02-28', 1]
                , ['2026-03-31', 1]
                , ['2026-04-30', 1]
                , ['2026-05-31', 1]
                , ['2026-06-30', 1]
                , ['2026-07-31', 1]
                , ['2028-06-30', 1]
                , ['2028-10-31', 1]])]

pool = {'assets': [
                ['Loan', {'originBalance': 21886.73, 
                             'originRate': ['floater', 0.01, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}], 
                             'originTerm': 3, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-07-08'}, 
                             {'currentBalance': 21886.73, 'currentRate': 0.01, 'remainTerm': 3, 'status': 'Current'}], 
                             
                ['Loan', {'originBalance': 217597.47, 
                        'originRate': ['floater', 0, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}], 
                        'originTerm': 4, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-05-09'}, 
                        {'currentBalance': 217597.47, 'currentRate': 0, 'remainTerm': 2, 'status': 'Current'}], 
                                       
                ['Loan', {'originBalance': 6648.02, 
                          'originRate': ['floater', 0, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}],
                            'originTerm': 2, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-07-02'}, 
                            {'currentBalance': 6648.02, 'currentRate': 0, 'remainTerm': 2, 'status': 'Current'}], 
                            
                ['Loan', {'originBalance': 10435.93, 
                          'originRate': ['floater', 0, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}],
                            'originTerm': 3, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-07-08'}, 
                            {'currentBalance': 10435.93, 'currentRate': 0, 'remainTerm': 3, 'status': 'Current'}], 
                            
                ['Loan', {'originBalance': 320.22, 'originRate': ['floater', 0, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}],
                           'originTerm': 4, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-05-09'}, 
                           {'currentBalance': 320.22, 'currentRate': 0, 'remainTerm': 2, 'status': 'Current'}], 
                           
                ['Loan', {'originBalance': 388.21, 
                        'originRate': ['floater', 0, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}], 
                        'originTerm': 4, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-05-09'},
                        {'currentBalance': 388.21, 'currentRate': 0, 'remainTerm': 2, 'status': 'Current'}], 
                        
                ['Loan', {'originBalance': 9787.87, 'originRate': ['floater', 0, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}], 
                          'originTerm': 3, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-06-03'}, 
                          {'currentBalance': 9787.87, 'currentRate': 0, 'remainTerm': 1, 'status': 'Current'}], 
                          
                ['Loan', {'originBalance': 423.5, 'originRate': ['floater', 0, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}], 
                          'originTerm': 2, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-07-18'}, 
                          {'currentBalance': 423.5, 'currentRate': 0, 'remainTerm': 2, 'status': 'Current'}], 
                          
                ['Loan', {'originBalance': 4817.0, 'originRate': ['floater', 0, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}], 
                          'originTerm': 3, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-06-27'}, 
                          {'currentBalance': 4817.0, 'currentRate': 0, 'remainTerm': 2, 'status': 'Current'}], 
                          
                ['Loan', {'originBalance': 73.81, 'originRate': ['floater', 0, {'index': 'EURIBOR3M', 'spread': 0.25, 'reset': 'MonthEnd'}], 
                          'originTerm': 3, 'freq': 'Monthly', 'type': 'i_p', 'originDate': '2024-07-31'}, 
                          {'currentBalance': 73.81, 'currentRate': 0, 'remainTerm': 3, 'status': 'Current'}]]
        ,'cutoffDate':'2024-07-01'}

# %%
from lenses import lens

# %%
localAPI = API(EnginePath.DEV,lang='english')
r = localAPI.runPool(
        pool & lens['assets'].modify(lambda xs: [xs[0]])
        , rateAssump=run_assump, read=True
        )

r['PoolConsol'][0]
# Out:
# Connecting engine server -> https://absbox.org/api/dev
# ✅Connected, local lib:0.28.7, server:0.28.20
#              Balance  Principal  Interest  Prepayment  Default  Recovery  \
# Date
# 2024-07-08  21886.73       0.00      0.00           0        0         0
# 2024-08-08  21886.73       0.00     18.58           0        0         0
# 2024-09-08  21886.73       0.00   2323.59           0        0         0
# 2024-10-08      0.00   21886.73   2248.63           0        0         0
#
#             Loss   WAC  CumPrincipal  CumPrepay  CumDelinq  CumDefault  \
# Date
# 2024-07-08     0  0.01          0.00          0          0           0
# 2024-08-08     0  0.01          0.00          0          0           0
# 2024-09-08     0  1.25          0.00          0          0           0
# 2024-10-08     0  1.25      21886.73          0          0           0
#
#             CumRecovery  CumLoss
# Date
# 2024-07-08            0        0
# 2024-08-08            0        0
# ...

# %%
21886.73 * (23+8)/365 * 1.25
# Out:
# 2323.591198630137

# %%
localAPI = API(EnginePath.LOCAL,lang='english')
r = localAPI.runPool(
        pool & lens['assets'].modify(lambda xs: [xs[0]])
        , rateAssump=run_assump, read=True
        )

r['PoolConsol'][0]
# Out:
# Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.28.7, server:0.28.19
#              Balance  Principal  Interest  Prepayment  Default  Recovery  \
# Date
# 2024-08-08  21886.73       0.00     18.58           0        0         0
# 2024-09-08  21886.73       0.00   2323.59           0        0         0
# 2024-10-08      0.00   21886.73   2248.63           0        0         0
#
#             Loss   WAC  CumPrincipal  CumPrepay  CumDelinq  CumDefault  \
# Date
# 2024-08-08     0  0.01          0.00          0          0           0
# 2024-09-08     0  1.25          0.00          0          0           0
# 2024-10-08     0  1.25      21886.73          0          0           0
#
#             CumRecovery  CumLoss
# Date
# 2024-08-08            0        0
# 2024-09-08            0        0
# 2024-10-08            0        0
