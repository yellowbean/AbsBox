# %%
from absbox import API, mkDeal

# %%
library_url = "http://localhost:5008"
localAPI = API("https://absbox.org/api/dev",check=False)
# Out:
# Connecting engine server -> https://absbox.org/api/dev
# ✅Connected, local lib:0.28.7, server:0.29.4

# %%
localAPI.loginLibrary("xyz","h0ll3bby",deal_library=library_url)
# Out:
# ✅ login successfully, Login successfully with expire at 2099-01-01

# %%
localAPI.fetchLibraryData(report_ids=["18NONGYING05_1.json"],deal_library=library_url)
# Out:
# ✅ fetch success
# {'data': [{'bondStat': {'interestPayments': [{'利息支付金额': '24526027.40',
#       '应支付利息金额': '24526027.40',
#       '总支付金额': '1332526027.40',
#       '本金支付金额': '1308000000.00',
#       '每100元支付利息': '0.61',
#       '每100元支付本金': '32.70',
#       '证券名称': '优先A-1档',
#       '证券执行利率': '3.73%'},
#      {'利息支付金额': '39452054.79',
#       '应支付利息金额': '39452054.79',
#       '总支付金额': '39452054.79',
#       '本金支付金额': '0.00',
#       '每100元支付利息': '0.79',
#       '每100元支付本金': '0.00',
#       '证券名称': '优先A-2档',
#       '证券执行利率': '4.80%'},
#      {'利息支付金额': '0.00',
#       '应支付利息金额': '0.00',
#       '总支付金额': '0.00',
#       '本金支付金额': '0.00',
#       '每100元支付利息': '0.00',
#       '每100元支付本金': '0.00',
#       '证券名称': '次级档',
#       '证券执行利率': '—'},
#      {'利息支付金额': '63978082.19',
#       '应支付利息金额': '63978082.19',
#       '总支付金额': '1371978082.19',
#       '本金支付金额': '1308000000.00',
#       '每100元支付利息': '—',
#       '每100元支付本金': '—',
#       '证券名称': '总计',
#       '证券执行利率': '—'}],
# ...

# %%
NY = localAPI.fetchLibraryData(deal_ids=["18NONGYING05"],deal_library=library_url)
# Out:
# ✅ fetch success

# %%
NY['data'][0]
# Out:
# [{'bondStat': {'interestPayments': [{'利息支付金额': '3975137.64',
#      '应支付利息金额': '3975137.64',
#      '总支付金额': '160375137.64',
#      '本金支付金额': '156400000.00',
#      '每100元支付利息': '0.10',
#      '每100元支付本金': '3.91',
#      '证券名称': '优先A-1档',
#      '证券执行利率': '3.73%'},
#     {'利息支付金额': '20383561.64',
#      '应支付利息金额': '20383561.64',
#      '总支付金额': '20383561.64',
#      '本金支付金额': '0.00',
#      '每100元支付利息': '0.41',
#      '每100元支付本金': '0.00',
#      '证券名称': '优先A-2档',
#      '证券执行利率': '4.80%'},
#     {'利息支付金额': '0.00',
#      '应支付利息金额': '0.00',
#      '总支付金额': '0.00',
#      '本金支付金额': '0.00',
#      '每100元支付利息': '0.00',
#      '每100元支付本金': '0.00',
#      '证券名称': '次级档',
#      '证券执行利率': '—'},
#     {'利息支付金额': '24358699.28',
#      '应支付利息金额': '24358699.28',
#      '总支付金额': '180758699.28',
#      '本金支付金额': '156400000.00',
#      '每100元支付利息': '—',
#      '每100元支付本金': '—',
#      '证券名称': '总计',
#      '证券执行利率': '—'}],
#    'principalPayments': [{'信托生效日余额': '4000000000.00',
# ...
