# %%
# %load_ext autoreload
# %autoreload 2

# %%
from absbox.local.china import SPV
from absbox import API
localAPI = API("http://localhost:8081",'chinese')

#remoteAPI = API("https://absbox.org/api/latest",'chinese')


mypool = {'清单':[
          ["按揭贷款"
           ,{"放款金额":1000,"放款利率":["固定",0.01],"初始期限":12
            ,"频率":"每月","类型":"等额本息","放款日":"2021-02-01"}
            ,{"当前余额":600 ,"当前利率":0.03,"剩余期限":8,"状态":("违约","2022-02-01")}]],
          '封包日':"2021-04-04"}

#myAssump = [{"CDR":0.06},{"CPR":0.03}]
myAssump = [{"已违约回收":[0.5,4,[0.5,0.2,0.3]]}]

p = localAPI.runPool(mypool,assumptions=myAssump)
p
# Out:
#              余额  本金  利息  早偿金额  违约金额  回收金额  损失金额    利率 债务人数量
# 日期
# 2022-03-01  600   0   0     0     0     0     0  0.03  None
# 2022-04-01  600   0   0     0     0     0     0  0.03  None
# 2022-05-01  600   0   0     0     0     0     0  0.03  None
# 2022-06-01  600   0   0     0     0     0     0  0.03  None
# 2022-07-01  600   0   0     0     0   150     0  0.03  None
# 2022-08-01  450   0   0     0     0    60     0  0.03  None
# 2022-09-01  390   0   0     0     0    90     0  0.03  None

# %%
from absbox.local.china import SPV
from absbox import API
localAPI = API("http://localhost:8081",'chinese')

#remoteAPI = API("https://absbox.org/api/latest",'chinese')


mypool = {'清单':[["Installment"
                 ,{"originBalance": 1000.0
                  ,"feeRate": ["fix",0.01]
                  ,"originTerm": 12
                  ,"freq": "Monthly"
                  ,"type": "f_p"
                  ,"originDate": "2022-01-01"}
                  ,{"status": "current"
                    ,"currentBalance":500
                    ,"remainTerm":10}]
           ],
          '封包日':"2021-04-04"}

#myAssump = [{"CDR":0.06},{"CPR":0.03}]
myAssump = [{"已违约回收":[0.5,4,[0.5,0.2,0.3]]}]

p = localAPI.runPool(mypool,assumptions=myAssump)
p
# Out:
#                 余额     本金    利息  早偿金额  违约金额  回收金额  损失金额  利率
# 日期
# 2022-04-01  458.71  41.29  4.95     0     0     0     0   0
# 2022-05-01  417.42  41.29  4.95     0     0     0     0   0
# 2022-06-01  376.13  41.29  4.95     0     0     0     0   0
# 2022-07-01  334.35  41.78  5.01     0     0     0     0   0
# 2022-08-01  292.57  41.78  5.01     0     0     0     0   0
# 2022-09-01  250.79  41.78  5.01     0     0     0     0   0
# 2022-10-01  209.01  41.78  5.01     0     0     0     0   0
# 2022-11-01  167.23  41.78  5.01     0     0     0     0   0
# 2022-12-01  125.45  41.78  5.01     0     0     0     0   0
# 2023-01-01   83.67  41.78  5.01     0     0     0     0   0

# %%
from absbox.local.china import SPV
from absbox import API
localAPI = API("http://localhost:8081",'chinese')

#remoteAPI = API("https://absbox.org/api/latest",'chinese')


mypool = {'清单':[["Installment"
                 ,{"originBalance": 1000.0
                  ,"feeRate": ["fix",0.01]
                  ,"originTerm": 12
                  ,"freq": "Monthly"
                  ,"type": "f_p"
                  ,"originDate": "2022-01-01"}
                  ,{"status": "current"
                    ,"currentBalance":1000
                    ,"remainTerm":12}]
           ],
          '封包日':"2022-01-04"}

#myAssump = [{"CDR":0.06},{"CPR":0.03}]
myAssump = [{"已违约回收":[0.5,4,[0.5,0.2,0.3]]}]

p = localAPI.runPool(mypool,assumptions=myAssump)
p
# Out:
#                 余额     本金  利息  早偿金额  违约金额  回收金额  损失金额  利率
# 日期
# 2022-02-01  916.67  83.33  10     0     0     0     0   0
# 2022-03-01  833.34  83.33  10     0     0     0     0   0
# 2022-04-01  750.01  83.33  10     0     0     0     0   0
# 2022-05-01  666.68  83.33  10     0     0     0     0   0
# 2022-06-01  583.35  83.33  10     0     0     0     0   0
# 2022-07-01  500.02  83.33  10     0     0     0     0   0
# 2022-08-01  416.69  83.33  10     0     0     0     0   0
# 2022-09-01  333.36  83.33  10     0     0     0     0   0
# 2022-10-01  250.03  83.33  10     0     0     0     0   0
# 2022-11-01  166.70  83.33  10     0     0     0     0   0
# 2022-12-01   83.37  83.33  10     0     0     0     0   0
# 2023-01-01    0.04  83.33  10     0     0     0     0   0

# %%
from absbox import API
localAPI = API("https://absbox.org/api/latest")
#localAPI = API("http://localhost:8081")

mypool = {'assets':[["Installment"
                 ,{"originBalance": 1000.0
                  ,"feeRate": ["fix",0.01]
                  ,"originTerm": 12
                  ,"freq": "Monthly"
                  ,"type": "f_p"
                  ,"originDate": "2022-01-01"}
                  ,{"status": ("defaulted","2022-07-01")
                    ,"currentBalance":418
                    ,"remainTerm":6}]
           ],
          'cutoffDate':"2022-01-04"}

myAssump = [{"DefaultedRecovery":[0.5,4,[0.5,0.2,0.3]]}]

p = localAPI.runPool(mypool,assumptions=myAssump)
p
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /usr/lib/python3.10/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /usr/lib/python3.10/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File /usr/lib/python3.10/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
# ...

# %%
1000 / 12
# Out:
# 83.33333333333333

# %%
from absbox.local.china import SPV
from absbox import API
localAPI = API("http://localhost:8081",'chinese')

#remoteAPI = API("https://absbox.org/api/latest",'chinese')


mypool = {'清单':[["Installment"
                 ,{"originBalance": 1000.0
                  ,"feeRate": ["fix",0.01]
                  ,"originTerm": 12
                  ,"freq": "Monthly"
                  ,"type": "f_p"
                  ,"originDate": "2022-01-01"}
                  ,{"status": "current"
                    ,"currentBalance":800
                    ,"remainTerm":8}]
           ],
          '封包日':"2022-01-04"}

#myAssump = [{"CDR":0.06},{"CPR":0.03}]
myAssump = []

p = localAPI.runPool(mypool,assumptions=myAssump)
p
# Out:
#                 余额     本金    利息  早偿金额  违约金额  回收金额  损失金额    利率
# 日期
# 2022-06-01  694.18  99.16  11.9     0     0     0     0  0.01
# 2022-07-01  595.02  99.16  11.9     0     0     0     0  0.01
# 2022-08-01  495.86  99.16  11.9     0     0     0     0  0.01
# 2022-09-01  396.69  99.16  11.9     0     0     0     0  0.01
# 2022-10-01  297.53  99.16  11.9     0     0     0     0  0.01
# 2022-11-01  198.37  99.16  11.9     0     0     0     0  0.01
# 2022-12-01   99.21  99.16  11.9     0     0     0     0  0.01
# 2023-01-01    0.04  99.16  11.9     0     0     0     0  0.01
