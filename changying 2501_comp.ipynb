# %% [markdown]
# ### 长盈2025年第一期个人汽车抵押贷款

# %%
from absbox import Generic,readAeson

CHANGYING2501 = Generic(
    "CHANGYING2501/长盈2025年第一期个人汽车抵押贷款"
    ,{"cutoff":"2024-10-01","closing":"2025-01-09","firstPay":"2025-02-26","firstCollect":'2024-10-31'
     ,"payFreq":["DayOfMonth",26],"poolFreq":"MonthEnd","stated":"2032-10-26"
     ,"cust":{"buy":"2025-02-01"}}
    ,{'发行':{'资产池规模':2_902_361_192.68}
      ,'清单':[]
      ,'归集表':[['2024-10-31', 2807531499.13, 94829693.55, 12717534.27],
                 ['2024-11-30', 2712138885.92, 95392613.21, 12983154.05],
                 ['2024-12-31', 2623011194.2, 89127691.72, 12682000.3],
                 ['2025-01-31', 2534889563.58, 88121630.62, 12381969.17],
                 ['2025-02-28', 2447214530.08, 87675033.5, 12084760.77],
                 ['2025-03-31', 2359530062.5, 87684467.58, 11788815.78],
                 ['2025-04-30', 2272092276.36, 87437786.14, 11492185.43],
                 ['2025-05-31', 2184835409.06, 87256867.3, 11196015.0],
                 ['2025-06-30', 2097774019.1, 87061389.96, 10899799.42],
                 ['2025-07-31', 2011116932.27, 86657086.83, 10603505.5],
                 ['2025-08-31', 1924800370.2, 86316562.07, 10308213.41],
                 ['2025-09-30', 1838926467.88, 85873902.32, 10013875.56],
                 ['2025-10-31', 1753540655.55, 85385812.33, 9720530.48],
                 ['2025-11-30', 1668649897.52, 84890758.03, 9428000.63],
                 ['2025-12-31', 1590276332.52, 78373565.0, 9135263.35],
                 ['2026-01-31', 1516329393.61, 73946938.91, 8843805.37],
                 ['2026-02-28', 1447582370.15, 68747023.46, 8553394.22],
                 ['2026-03-31', 1381160556.56, 66421813.59, 8266476.45],
                 ['2026-04-30', 1317190823.17, 63969733.39, 7979823.11],
                 ['2026-05-31', 1255325954.88, 61864868.29, 7694167.55],
                 ['2026-06-30', 1196817279.83, 58508675.05, 7409438.24],
                 ['2026-07-31', 1141604845.82, 55212434.01, 7126097.27],
                 ['2026-08-31', 1089528852.69, 52075993.13, 6843292.1],
                 ['2026-09-30', 1039635381.08, 49893471.61, 6560875.33],
                 ['2026-10-31', 989978847.43, 49656533.65, 6279237.08],
                 ['2026-11-30', 940420262.78, 49558584.65, 5997447.4],
                 ['2026-12-31', 892869686.65, 47550576.13, 5715550.85],
                 ['2027-01-31', 847785376.21, 45084310.44, 5443177.49],
                 ['2027-02-28', 806016845.9, 41768530.31, 5182700.65],
                 ['2027-03-31', 765268032.77, 40748813.13, 4938915.37],
                 ['2027-04-30', 726277779.28, 38990253.49, 4700020.0],
                 ['2027-05-31', 688893572.13, 37384207.15, 4470101.13],
                 ['2027-06-30', 652979957.48, 35913614.65, 4248834.58],
                 ['2027-07-31', 618863203.46, 34116754.02, 4035513.85],
                 ['2027-08-31', 586536783.99, 32326419.47, 3830692.15],
                 ['2027-09-30', 555567524.36, 30969259.63, 3633793.65],
                 ['2027-10-31', 524588346.45, 30979177.91, 3443602.95],
                 ['2027-11-30', 493508004.62, 31080341.83, 3253276.83],
                 ['2027-12-31', 462586466.13, 30921538.49, 3062195.61],
                 ['2028-01-31', 431705298.24, 30881167.89, 2872001.81],
                 ['2028-02-28', 400961553.7, 30743744.54, 2681975.97],
                 ['2028-03-31', 370126509.23, 30835044.47, 2492606.42],
                 ['2028-04-30', 339311719.16, 30814790.07, 2302512.02],
                 ['2028-05-31', 308508915.19, 30802803.97, 2112376.38],
                 ['2028-06-30', 277689555.38, 30819359.81, 1922189.09],
                 ['2028-07-31', 246862833.36, 30826722.02, 1731747.88],
                 ['2028-08-31', 216104149.21, 30758684.15, 1541073.13],
                 ['2028-09-30', 185464651.32, 30639497.89, 1350724.8],
                 ['2028-10-31', 154757404.5, 30707246.82, 1161117.68],
                 ['2028-11-30', 124016296.93, 30741107.57, 971424.45],
                 ['2028-12-31', 97005492.69, 27010804.24, 781033.49],
                 ['2029-01-31', 74607025.26, 22398467.43, 613477.46],
                 ['2029-02-28', 56574919.03, 18032106.23, 473033.38],
                 ['2029-03-31', 40428420.62, 16146498.41, 359097.52],
                 ['2029-04-30', 26732804.0, 13695616.62, 257083.7],
                 ['2029-05-31', 15590826.65, 11141977.35, 170157.06],
                 ['2029-06-30', 7599880.29, 7990946.36, 99080.39],
                 ['2029-07-31', 2418340.01, 5181540.28, 48524.22],
                 ['2029-08-31', 76036.26, 2342303.75, 15517.23],
                 ['2029-09-30', 0.0, 76036.26, 514.92]]
     }
    ,(("收入账户",{"balance":0}),("本金账户",{"balance":0})
      ,("储备账户",{"balance":29_023_611.92
                   ,"type":{"when":[
                               [("isOutstanding","优先级"),True]
                              ,("target",("max",("factor",("poolBalance",),0.01),("factor",("originalPoolBalance",),0.005)))
                              ,{"fixReserve":0}]
                           }}
                ))
    ,(("优先级",{"balance":2_460_000_000.0
             ,"rate":0.017
             ,"originBalance":2_460_000_000.0
             ,"originRate":0.017
             ,"startDate":"2025-01-09"
             ,"rateType":{"Fixed":0.017}
             ,"maturityDate":"2028-04-26" 
             ,"bondType":"Sequential"})
      ,("次级",{"balance":270_000_000
             ,"rate":0.0
             ,"originBalance":270_000_000
             ,"originRate":0.00
             ,"startDate":"2025-01-09"
              ,"maturityDate":"2028-12-26" 
             ,"rateType":{"Fixed":0.00}
             ,"bondType":"Equity"
             }))
    ,(("增值税",{"type":{"targetBalanceFee":[("*",("资产池累计",None,"利息"),0.0326)
                                   ,("feeTxnAmt",None,"增值税")]}})
      ,("受托机构费用",{"type":{"annualPctFee":[("资产池余额",),0.0002]}})
      ,("服务商费用",{"type":{"annualPctFee":[("资产池余额",),0.0002]}})
     )
    ,{"default":[
         # 收入账户
         ["transfer","储备账户","收入账户",{"ds":("reserveExcess","储备账户")}]
         ,["calcAndPayFee","收入账户",['增值税'],{"support":["support",["account","储备账户"],["account","本金账户",("Debit","ABCD")]]}]
         ,["calcAndPayFee","收入账户",['受托机构费用'],{"limit":{"balCapAmt":50000},"support":["support",["account","储备账户"],["account","本金账户",("Debit","ABCD")]]}]
         ,["accrueAndPayInt","收入账户",["优先级"],{"support":["support",["account","储备账户"],["account","本金账户",("Debit","ABCD")]]}]
         ,["transfer","收入账户","储备账户",{"ds":("reserveGap","储备账户")}]
         ,["transfer","收入账户","本金账户",{"ds":("ledgerBalance","Debit","ABCD")},"book","Credit","ABCD"]
         ,["calcAndPayFee","收入账户",['服务商费用']]
         ,["payFee","收入账户",['受托机构费用'],]  
         ,["IfElse",["status", "Accelerated"]
            ,[["transfer","收入账户","本金账户"]]
            ,[["if",["status", "Amortizing"]
                ,["payIntResidual","收入账户","次级"]]
            ]
          ]
         # 本金账户
         ,["payPrin","本金账户",["优先级"]]
         ,["payPrin","本金账户",["次级"]]
         ,["payIntResidual","本金账户","次级"]
         ,["payIntResidual","收入账户","次级"]]
      ,"cleanUp":[
          ["transferM",["收入账户","储备账户"],"本金账户"]
          ,["calcAndPayFee","本金账户",['增值税','服务商费用','受托机构费用'],]
          ,["accrueAndPayInt","本金账户",["优先级"]]
          ,["payPrinBySeq","本金账户",["优先级","次级"]]
          ,["payIntResidual","本金账户","次级"]
      ]
      ,"endOfCollection":[
          ["bookBy", ["formula","ABCD","Debit",("curPoolCollection", None, "Defaults")]]
      ]
      ,("custom","buy"):[["buyAsset",["Current|Defaulted", 1.0, 0],"本金账户"]]
     }
    ,[["CollectedInterest","收入账户"]
      ,["CollectedPrincipal","本金账户"]
      ,["CollectedPrepayment","本金账户"]
      ,["CollectedRecoveries","本金账户"]]
    ,None
    ,None
    ,None
    ,{"AfterCollect":
       {"trg01":{"condition":["periodRateCurve", ("cumPoolDefaultedRate",)
                                       , ">", ("dealStat","int","BondPaidPeriod")
                                       ,[[0,0.02]
                                        ,[12,0.05]]
                             ]
                ,"effects":("newStatus","Defaulted")
                ,"status":False
                ,"curable":False}}}
    ,("PreClosing","Amortizing")
    ,None
    ,{"ABCD":{"balance":0}}
    ,None
    )

revol_asset = ["Mortgage"
                ,{"originBalance":2200,"originRate":["fix",0.055],"originTerm":46
                  ,"freq":"Monthly","type":"Level","originDate":"2021-02-01"}
                  ,{"currentBalance":2200
                  ,"currentRate":0.055
                  ,"remainTerm":40
                  ,"status":"current"}]

# %%
from absbox import API,EnginePath,compResult
localAPI = API(EnginePath.LOCAL,check=False)
# Out:
# Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.28.7, server:0.43.0

# %%
# %load_ext autoreload
# %autoreload 2

revol_asset = ["Mortgage"
                ,{"originBalance":2200,"originRate":["fix",0.055],"originTerm":46
                  ,"freq":"Monthly","type":"Level","originDate":"2021-02-01"}
                  ,{"currentBalance":2200
                  ,"currentRate":0.055
                  ,"remainTerm":40
                  ,"status":"current"}]

# %%
r1 = localAPI.run(CHANGYING2501
                 ,runAssump = [("revolving"
                                 ,["constant",revol_asset]
                                 ,("Pool",("Mortgage",{"CDR":0.33143830048815853},None,None,None)
                                           ,None
                                           ,None))
                              ]
                 ,poolAssump = ("Pool",("Mortgage",{"CDR":0.11081276682938618},None,None,None)
                                       ,None
                                       ,None)
                 ,read=True)

r2 = localAPI.run(CHANGYING2501
                 ,runAssump = [("revolving"
                                 ,["constant",revol_asset]
                                 ,("Pool",("Mortgage",{"CDR":0.0143},None,None,None)
                                           ,None
                                           ,None))
                              ]
                 ,poolAssump = ("Pool",("Mortgage",{"CDR":0.11081276682938618},None,None,None)
                                       ,None
                                       ,None)
                 ,read=True)
# Out:
# Warning Message from server:
# Bond 次级 is not paid off
# Fee 服务商费用 is not paid off
# Warning Message from server:
# Bond 次级 is not paid off
# Fee 服务商费用 is not paid off

# %%
dif = compResult(r1,r2,names=("highCDR","lowCDR"))

# %%
dif['bond']['次级'][['balance','cash']]
# Out:
#                  balance                                     cash  \
#                  highCDR        lowCDR          diff      highCDR
# date
# 2028-07-26  2.700000e+08  2.696383e+08  3.617319e+05         0.00
# 2028-08-26  2.700000e+08  2.344061e+08  3.559390e+07         0.00
# 2028-09-26  2.700000e+08  2.140507e+08  5.594928e+07         0.00
# 2028-10-26  2.700000e+08  1.940804e+08  7.591962e+07         0.00
# 2028-11-26  2.700000e+08  1.743799e+08  9.562013e+07         0.00
# 2028-12-26  2.700000e+08  1.549603e+08  1.150397e+08         0.00
# 2029-01-26  2.700000e+08  1.381091e+08  1.318909e+08         0.00
# 2029-02-26  2.700000e+08  1.242939e+08  1.457061e+08         0.00
# 2029-03-26  2.700000e+08  1.132836e+08  1.567164e+08         0.00
# 2029-04-26  2.700000e+08  1.035593e+08  1.664407e+08         0.00
# 2029-05-26  2.700000e+08  9.541714e+07  1.745829e+08         0.00
# 2029-06-26  2.700000e+08  8.888066e+07  1.811193e+08         0.00
# ...

# %%
r1['fees']['服务商费用']
# Out:
#               balance  payment  due
# date
# 2025-02-26   30707.41        0    0
# 2025-03-26   33771.60        0    0
# 2025-04-26   41143.31        0    0
# 2025-05-26   46767.31        0    0
# 2025-06-26   53462.45        0    0
# 2025-07-26   58556.15        0    0
# 2025-08-26   64603.71        0    0
# 2025-09-26   70338.82        0    0
# 2025-10-26   74682.44        0    0
# 2025-11-26   79815.63        0    0
# 2025-12-26   83690.62        0    0
# 2026-01-26   88253.03        0    0
# 2026-02-26   92554.98        0    0
# 2026-03-26   94177.78        0    0
# 2026-04-26   98010.57        0    0
# 2026-05-26  100904.20        0    0
# 2026-06-26  104315.33        0    0
# 2026-07-26  106886.54        0    0
# 2026-08-26  109915.76        0    0
# 2026-09-26  112771.12        0    0
# 2026-10-26  114924.66        0    0
# 2026-11-26  117462.31        0    0
# 2026-12-26  119371.87        0    0
# 2027-01-26  121612.11        0    0
# 2027-02-26  123712.78        0    0
# ...

# %%
def compDf(x, y):
    #return pd.merge(x, y, on="Date", how='outer').sort_index().sort_index(axis=1)
    return x.compare(y, result_names=("Left","Right"))

import pandas as pd

df = r1['pool']['flow']['PoolConsol']-r2['pool']['flow']['PoolConsol']
df
# Out:
#                 Balance   Principal   Interest  Prepayment      Default  \
# Date
# 2025-01-09         0.00        0.00       0.00           0         0.00
# 2025-01-31         0.00        0.00       0.00           0         0.00
# 2025-02-28         0.00        0.00       0.00           0         0.00
# 2025-03-31 -10275492.58  -240130.11  -48193.10           0  10515622.69
# 2025-04-30 -20775117.67  -499448.26  -97501.34           0  10999073.35
# 2025-05-31 -30068517.65  -744152.89 -141214.47           0  10037552.87
# 2025-06-30 -38851770.60  -990559.84 -182597.40           0   9773812.79
# 2025-07-31 -46534512.12 -1223205.11 -218873.61           0   8905946.63
# 2025-08-31 -53735214.67 -1457441.88 -252947.94           0   8658144.43
# 2025-09-30 -60183433.50 -1685747.18 -283546.46           0   8133966.01
# 2025-10-31 -65674436.22 -1901486.71 -309700.45           0   7392489.43
# 2025-11-30 -70722844.82 -2118662.04 -333832.63           0   7167070.64
# ...

# %%
import pandas as pd

data1 = {
  "calories": [420, 380,300.1],
  "duration": [True, False,True]
}

data2 = {
  "calories": [300, 210, 390],
  "duration": [True, True, True]
}

#load data into a DataFrame object:
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

diff = df1.compare(df2)
diff
# Out:
#   calories       duration
#       self other     self other
# 0    420.0   300      NaN   NaN
# 1    380.0   210    False  True
# 2    300.1   390      NaN   NaN

# %%
result = diff.copy()

for column in diff.columns.levels[0]:
    print("column", column,type(diff[column]['self']),diff[column]['self'].dtype)
    result[column, '_diff'] = diff[column]['self'].fillna(0) - diff[column]['other'].fillna(0)

result
# Out:
# column calories <class 'pandas.core.series.Series'> float64
# column duration <class 'pandas.core.series.Series'> object
#   calories       duration       calories duration
#       self other     self other    _diff    _diff
# 0    420.0   300      NaN   NaN    120.0        0
# 1    380.0   210    False  True    170.0       -1
# 2    300.1   390      NaN   NaN    -89.9        0

# %%
result.sort_index(axis=1,ascending=False)
# Out:
#   duration               calories
#       self  other  _diff     self other _diff
# 0      NaN    NaN    0.0      420   300   120
# 1      NaN    NaN    0.0      380   210   170
# 2     10.0  145.0 -135.0      300   390   -90

# %%
diff.columns
# Out:
# MultiIndex([('calories',  'self'),
#             ('calories', 'other'),
#             ('duration',  'self'),
#             ('duration', 'other')],
#            )

# %%
def compDf(x, y):
    (nameA,namesB) = ("Left","Right")
    cmp = x.compare(y, result_names=(nameA,namesB))
    result = cmp.copy()
    for column in cmp.columns.levels[0]:
        result[column, '_diff'] = cmp[column][nameA].fillna(0) - cmp[column][namesB].fillna(0)
    return result.sort_index(axis=1,ascending=False)

# %%
df1 = df1.compare(df2, result_names=("Left","Right"))

result = df1.copy()

# Add differences in one go using MultiIndex
new_columns = pd.MultiIndex.from_tuples(
    [(col, 'diff') for col in df1.columns.levels[0]]
)
diff_values = df1.xs('Left', level=1, axis=1) - df2.xs('Right', level=1, axis=1)
result = pd.concat([result, diff_values.set_axis(new_columns, axis=1)], axis=1)

# Sort columns for better readability (optional)
result = result.sort_index(axis=1)

print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/pb/0lsr_g9s0x340sd74jhjdhj40000gn/T/ipykernel_4658/2685204672.py in ?()
#       5 # Add differences in one go using MultiIndex
#       6 new_columns = pd.MultiIndex.from_tuples(
#       7     [(col, 'diff') for col in df1.columns.levels[0]]
#       8 )
# ----> 9 diff_values = df1.xs('Left', level=1, axis=1) - df2.xs('Right', level=1, axis=1)
#      10 result = pd.concat([result, diff_values.set_axis(new_columns, axis=1)], axis=1)
#      11
#      12 # Sort columns for better readability (optional)
#
# ~/Projects/PyABS/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis, level, drop_level)
#    4269             raise TypeError("list keys are not supported in xs, pass a tuple instead")
#    4270
#    4271         if level is not None:
#    4272             if not isinstance(labels, MultiIndex):
# ...
