# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
from absbox import API,LIBRARY,readFeesCf,Generic,readBondsCf,readInspect,Generic,readAeson,compResult
localAPI = API("http://localhost:8081",check=False)
# Out:
#  Connecting engine server -> http://localhost:8081
# ✅Connected, local lib:0.43.0, server:0.44.1

# %%
library_url = "http://localhost:8082/api"
library = LIBRARY(library_url)
library.login("chinapublisher","imthere1")
# Out:
# ✅ Connected to library server
# absbox version:0.43.0
# Hastructure:{'active': {'local': 'http://localhost:8081 : 0.44.1'}, 'default': 'local', 'inactive': {}}
# ✅ login successfully, user -> chinapublisher,group -> china

# %%
JSD_AUTO_2025_1 = Generic(
    "吉时代2025年第一期个人汽车抵押贷款资产支持证券"
    ,{"封包日":"2024-12-31","起息日":"2025-03-14","首次兑付日":"2025-04-26"
     ,"法定到期日":"2032-05-26","收款频率":"月末","付款频率":["每月",26]} 
    ,{'发行':{'资产池规模':4_500_002_170.78}
      ,'清单':[]
      ,'归集表':[['2025-01-31', 4240952638.64, 259049532.14, 3906469.16],
                 ['2025-02-28', 3984977497.42, 255975141.22, 7170295.04],
                 ['2025-03-31', 3731465199.95, 253512297.47, 6738886.87],
                 ['2025-04-30', 3482111064.88, 249354135.07, 6311620.99],
                 ['2025-05-31', 3235665095.51, 246445969.37, 5892528.78],
                 ['2025-06-30', 3000244838.29, 235420257.22, 5478946.39],
                 ['2025-07-31', 2781200523.32, 219044314.97, 5096929.93],
                 ['2025-08-31', 2576758715.69, 204441807.63, 4760854.25],
                 ['2025-09-30', 2386782244.68, 189976471.01, 4467757.41],
                 ['2025-10-31', 2207420937.19, 179361307.49, 4212038.66],
                 ['2025-11-30', 2040971821.65, 166449115.54, 3993603.02],
                 ['2025-12-31', 1878578166.09, 162393655.56, 3812075.68],
                 ['2026-01-31', 1719572603.51, 159005562.58, 3633167.05],
                 ['2026-02-28', 1563131011.24, 156441592.27, 3457647.06],
                 ['2026-03-31', 1408896485.76, 154234525.48, 3284822.85],
                 ['2026-04-30', 1256130348.19, 152766137.57, 3113650.99],
                 ['2026-05-31', 1104875597.93, 151254750.26, 2944314.36],
                 ['2026-06-30', 955371868.5, 149503729.43, 2776157.65],
                 ['2026-07-31', 806933247.8, 148438620.7, 2610217.06],
                 ['2026-08-31', 660146595.45, 146786652.35, 2446812.98],
                 ['2026-09-30', 516248594.28, 143898001.17, 2286958.63],
                 ['2026-10-31', 398763073.0, 117485521.28, 2137322.04],
                 ['2026-11-30', 329814453.75, 68948619.25, 2001110.26],
                 ['2026-12-31', 309257794.77, 20556658.98, 1883092.34],
                 ['2027-01-31', 290308949.8, 18948844.97, 1779189.9],
                 ['2027-02-28', 273233392.84, 17075556.96, 1684821.6],
                 ['2027-03-31', 256885450.72, 16347942.12, 1601829.41],
                 ['2027-04-30', 241429719.14, 15455731.58, 1523291.3],
                 ['2027-05-31', 226614176.62, 14815542.52, 1450155.23],
                 ['2027-06-30', 211824322.93, 14789853.69, 1380960.16],
                 ['2027-07-31', 197051458.72, 14772864.21, 1311710.29],
                 ['2027-08-31', 182249403.31, 14802055.41, 1242424.0],
                 ['2027-09-30', 167499213.41, 14750189.9, 1172814.43],
                 ['2027-10-31', 154048536.32, 13450677.09, 1103325.23],
                 ['2027-11-30', 143936024.5, 10112511.82, 1035798.31],
                 ['2027-12-31', 137616713.32, 6319311.18, 980283.55],
                 ['2028-01-31', 131311306.47, 6305406.85, 938403.97],
                 ['2028-02-29', 124992866.42, 6318440.05, 896581.76],
                 ['2028-03-31', 118655358.04, 6337508.38, 854647.63],
                 ['2028-04-30', 112293251.43, 6362106.61, 812547.41],
                 ['2028-05-31', 105913690.16, 6379561.27, 770249.91],
                 ['2028-06-30', 99504694.07, 6408996.09, 727769.89],
                 ['2028-07-31', 93056715.51, 6447978.56, 685062.82],
                 ['2028-08-31', 86578216.92, 6478498.59, 642066.65],
                 ['2028-09-30', 80068809.64, 6509407.28, 598832.54],
                 ['2028-10-31', 73593845.69, 6474963.95, 555360.46],
                 ['2028-11-30', 67469628.4, 6124217.29, 512080.66],
                 ['2028-12-31', 61628911.93, 5840716.47, 469914.33],
                 ['2029-01-31', 55795962.69, 5832949.24, 429354.8],
                 ['2029-02-28', 49973332.82, 5822629.87, 388840.31],
                 ['2029-03-31', 44150374.1, 5822958.72, 348357.49],
                 ['2029-04-30', 38305793.46, 5844580.64, 307847.55],
                 ['2029-05-31', 32431024.07, 5874769.39, 267167.26],
                 ['2029-06-30', 26516826.56, 5914197.51, 226267.27],
                 ['2029-07-31', 20569272.85, 5947553.71, 185084.43],
                 ['2029-08-31', 14585048.88, 5984223.97, 143657.59],
                 ['2029-09-30', 8564336.12, 6020712.76, 101968.97],
                 ['2029-10-31', 2965886.32, 5598449.8, 60029.99],
                 ['2029-11-30', 0.0, 2965886.32, 21021.36]]
     }
    ,(("信托收付账户",{"balance":0 })
      ,("流动性储备",{"balance": 36_000_017.37
                    ,"type":("when"
                              ,["date","<=","2025-06-30"]
                              ,("fix",36_000_017.37)
                              ,("target",("sum"
                                             ,("bondDueIntTotal","优先A1","优先A2")
                                             ,("feeDue",'服务商费用','增值税')
                                         )
                                        ,2.0)
                            )})
     )
    ,(("优先A1",{"当前余额":1_600_000_000.00
             ,"当前利率":0.0183
             ,"初始余额":1_600_000_000.00
             ,"初始利率":0.0183
             ,"起息日":"2025-03-14"
             ,"到期日":"2026-03-26"
             ,"利率":{"固定":0.0183}
             ,"债券类型":{"PAC":[['2025-04-26', 1600000000.0],
                                    ['2025-05-26', 1600000000.0],
                                    ['2025-06-26', 1600000000.0],
                                    ['2025-07-26', 1376000000.0],
                                    ['2025-08-26', 1152000000.0],
                                    ['2025-09-26', 928000000.0],
                                    ['2025-10-26', 704000000.0],
                                    ['2025-11-26', 480000000.0],
                                    ['2025-12-26', 360000000.0],
                                    ['2026-01-26', 240000000.0],
                                    ['2026-02-26', 120000000.0],
                                    ['2026-03-26', 0.0]]
                         ,"anchorBonds":["优先A2"]}})
                 
      ,("优先A2",{"当前余额":2_320_000_000.00
             ,"当前利率":0.0195
             ,"初始余额":2_320_000_000.00
             ,"初始利率":0.0195
             ,"起息日":"2025-03-14"
             ,"到期日":"2026-12-26"
             ,"利率":{"固定":0.0195}
             ,"债券类型":"Seq"
             })
      ,("次级",{"当前余额":580_002_170.78
             ,"当前利率":0.0
             ,"初始余额":580_002_170.78
             ,"初始利率":0.0
             ,"起息日":"2025-03-14"
             ,"到期日":"2030-05-26"
             ,"利率":{"固定":0.00}
             ,"债券类型":"Equity"
             })
     )
    ,(("增值税",{"type":{"targetBalanceFee":[("*",("cumPoolCollection", None, "Interest"),0.0326)
                                            ,("feeTxnAmt",None,"增值税")]
                       }})
      ,("服务商费用",{"type":{"annualPctFee":[("poolBalance",),0.0012]}}),
      #,("报销",{"类型":{"周期费用":["每月",60000]}})
     )
    ,{"default":[
         ["calcInt","优先A1","优先A2"]
         ,["transfer","流动性储备","信托收付账户",{"DS":('reserveExcess',"流动性储备")}]
         ,["支付费用","信托收付账户",["增值税"]]
         ,["支付费用","信托收付账户",["服务商费用"]]
         
         #,["支付费用限额",["收入分账户"],["报销"],{"应计费用上限":50000}]
         ,["payInt","信托收付账户",["优先A1","优先A2"]]
         #,["transfer","信托收付账户","流动性储备",{"DS":('reserveGap',"流动性储备")}]
         ,["if",["status", "Revolving"]
               ,["buyAsset",["正常|违约",1.0,0.0], "信托收付账户"]
            ]
         ,["支付本金","信托收付账户",["优先A1"]]
         ,["支付本金","信托收付账户",["优先A2"]]
         ,["支付本金","信托收付账户",["优先A1"]]
        #,["支付费用限额",["收入分账户"],["报销"],{"应计费用上限":50000}]
         ,["支付本金","信托收付账户",["次级"]]
         ,["支付收益","信托收付账户","次级"]
      ]
     ,"endOfCollection":[
                         ["计提费用","服务商费用","增值税"]
                        ]
     ,"cleanUp":[
                 ["出售资产",["正常|违约",1.0,0.0],"信托收付账户"]
                 ,["transfer","流动性储备","信托收付账户"]
                 ,["支付费用","信托收付账户",["服务商费用","增值税"]]
                ,["计提支付利息","信托收付账户",["优先A1"]]
                ,["支付本金","信托收付账户",["优先A2"]]
                ,["支付本金","信托收付账户",["次级"]]
                ,["支付收益","信托收付账户","次级"]
             ]
     }
    ,(["利息回款","信托收付账户"]
      ,["本金回款","信托收付账户"]
      ,["早偿回款","信托收付账户"]
      ,["回收回款","信托收付账户"])
    ,None
    ,None
    ,None
    ,{"BeforeDistribution":
         {"toAmort":
             {"condition":["date", ">=", "2025-06-30" ]
                      ,"effects":("newStatus","Amortizing")
                      ,"status":False
                      ,"curable":False}
         }
     }
    ,"Revolving"
)

# %%
revol_asset = ["Mortgage"
                ,{"originBalance":2200,"originRate":["fix",0.02],"originTerm":48
                  ,"freq":"Monthly","type":"Level","originDate":"2021-02-01"}
                  ,{"currentBalance":2200
                  ,"currentRate":0.02
                  ,"remainTerm":40
                  ,"status":"current"}]

r = localAPI.run(JSD_AUTO_2025_1
                 ,runAssump = [#("callWhen", ("if", [("isPaidOff","优先A2"),True]))
                               ("pricing"
                                  ,{"date":"2025-03-14"
                                    ,"curve":[["2021-01-01",0.017]
                                             ,["2028-08-01",0.017]]})
                              ,("revolving",["constant",revol_asset]
                                           ,("Pool",("Mortgage",{"CDR":0.0},None,None,None)
                                                   ,None
                                                   ,None))
                              ]
                 ,read=True)
# Out:
# Warning Message from server:

# %%
r['pricing']['summary']
# Out:
#            pricing        face   WAL  duration  convexity  accure interest
# 优先A1  1.601476e+09  100.092228  0.64  0.645658   0.000273    -1.431110e+08
# 优先A2  2.328669e+09  100.373660  1.44  1.420282   0.000290    -2.204985e+08
# 次级    6.496735e+08  112.012253  3.00  3.168390   0.000000     0.000000e+00

# %%
readBondsCf(r['bonds']).xs("interest",axis=1,level=1)
# Out:
#                   优先A1        优先A2           次级
# date
# 2025-04-26  3449424.65  5329643.83         0.00
# 2025-05-26  2406575.34  3718356.16         0.00
# 2025-06-26  2486794.52  3842301.36         0.00
# 2025-07-26  2406575.34  3718356.16         0.00
# 2025-08-26  2138643.28  3744558.85         0.00
# 2025-09-26  1790492.05  3699034.56         0.00
# 2025-10-26  1395813.69  3558331.77         0.00
# 2025-11-26  1095019.42  3676942.82         0.00
# 2025-12-26   740770.24  3558331.77         0.00
# 2026-01-26   559528.76  3565075.92         0.00
# 2026-02-26   373019.17  3440280.41         0.00
# 2026-03-26   168460.27  2999020.24         0.00
# 2026-04-26         NaN  3202589.09         0.00
# 2026-05-26         NaN  2799109.44         0.00
# 2026-06-26         NaN  2582896.72         0.00
# 2026-07-26         NaN  2202900.06         0.00
# 2026-08-26         NaN  1971669.21         0.00
# 2026-09-26         NaN  1669169.93         0.00
# ...

# %% [markdown]
# ### Publish Deal

# %%
library.add(JSD_AUTO_2025_1, **{"stage":"draft","tags":["china","auto"]})
# Out:
# ✅ add success with deal id=3, name=吉时代2025年第一期个人汽车抵押贷款资产支持证券

# %% [markdown]
# ### Validation

# %%
i,r = library.run(("name","吉时代2025年第一期个人汽车抵押贷款资产支持证券")
            ,runAssump= [("revolving"
                         ,["constant",revol_asset]
                         ,("Pool",("Mortgage",{"CDR":0.00},None,None,None)
                                   ,None
                                   ,None))
                       ]
            ,read=True)
# Out:
# ✅ run success with deal: 吉时代2025年第一期个人汽车抵押贷款资产支持证券|3

# %%
i
# Out:
# {'time': {'load': '2.732 ms', 'run': '31.736 ms'},
#  'engine': 'http://localhost:8081 | 0.43.0',
#  'deal': {'name': '吉时代2025年第一期个人汽车抵押贷款资产支持证券', 'id': 3}}

# %%
library.cmd({'publish':{'id':3}})
# Out:
# {'id': 3, 'stage': 'published'}

# %%
library.query(("tag","auto"))
# Out:
# ✅ query success
#    ID                       name  period  stage        tags permission  group
# 0   3  吉时代2025年第一期个人汽车抵押贷款资产支持证券       0      1  auto,china        700  china

# %%
library.cmd({"comment":{"id":3,"comment":"service fee TBD"}})
# Out:
# {}

# %%
library.cmd({"comment":{"id":3}})
# Out:
# {'comments': [{'comment': 'service fee TBD',
#    'date': '2025-03-15 02:23:31.029659',
#    'user': 3}]}
